# %%
import os

db_dir_L = os.environ["DATA"] + "PatImgXAI_data/db3.0.0_L/"
db_dir_S = os.environ["DATA"] + "PatImgXAI_data/db3.0.0_S/"
db_dir_M = os.environ["DATA"] + "PatImgXAI_data/db3.0.0_M/"
db_patterns_dir = os.environ["DATA"] + "PatImgXAI_data/db3.0.0/patterns/"

interface_dir = os.environ["DATA"] + "webinterfaces/int05_prototype/"
model_dir_root = os.environ["DATA"] + "models/db3.0.0/01_protov5/"
output_json_dir = "/home/jleguy/Documents/postdoc/git_repos/WebXAII/functions/data/"
output_assets_dir = "/home/jleguy/Documents/postdoc/git_repos/WebXAII/src/assets/"

XAI_names = []

users = {
    "H" : ["H" + str(i) for i in range(1, 101)],
    # "AI": ["TESTA" + str(i) for i in range(1, 101)],
    # "XAI_SHAP": ["TESTS" + str(i) for i in range(1, 101)],
    # "XAI_CF": ["TESTC" + str(i) for i in range(1, 101)],
    # # "XAI_LLM": ["XAI_LLM" + str(i) for i in range(1, 101)]
}

# %%
CONDITIONS = ["H"]# , "AI", "XAI_SHAP", "XAI_CF"]

DISCOVERY_TRAINING_TASKS = []
# DISCOVERY_TRAINING_TASKS = ["disc_1_triangle_all", "disc_1_triangle_all_2", "disc_1_triangle_all_3"]

EASY_TRAINING_TASKS = []
EASY_TASKS = ["easy1_find_pattern_rot", "easy2_yellow_triangle_even", "easy3_find_pattern_rot", "easy4_purple_circle_even"]
EASY_TASKS = ["med1_find_pattern_rot", "med2_yellow_square_even", "med3_find_pattern_rot", "med4_blue_triangle_even"]
DIFFICULT_TRAINING_TASKS = []
DIFFICULT_TASKS = ["hard1_find_pattern_rot", "hard2_blue_circle_even", "hard3_find_pattern_rot", "hard4_purple_square_even"]

TIME_TRAINING = 45
TIME_MILD = 12
TIME_STRONG = 7

JSON_PATH_CONSENT_FORM = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/000_consent_form.json"
JSON_PATH_INTRO_FORM = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/010_introduction.json"
JSON_PATH_INTRO_DISCOVERY_FORM = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/015_intro_discovery.json"
JSON_PATH_INTRO_FURTHER_INFO_FORM = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/017_intro_further_info.json"

JSON_PATH_INSTRUCTIONS_AI_FORM = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/020_instructions_AI.json"
JSON_PATH_INSTRUCTIONS_XAI_SHAP_FORM = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/020_instructions_XAI_SHAP.json"
JSON_PATH_INSTRUCTIONS_XAI_CF_FORM = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/020_instructions_XAI_CF.json"
JSON_PATH_INSTRUCTIONS_XAI_LLM_FORM = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/020_instructions_XAI_LLM.json"
JSON_PATH_INTRO_ACCLIM_1 = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/030_intro_acclim_1.json"
JSON_PATH_INTRO_ACCLIM_1_AI = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/030_intro_acclim_1_AI.json"
JSON_PATH_INTRO_ACCLIM_2 = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/032_intro_acclim_2.json"
JSON_PATH_INTRO_MAIN_TRAINING = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/035_intro_main_training.json"
JSON_PATH_INTRO_MAIN_TRAINING_AI = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/035_intro_main_training_AI.json"

JSON_PATH_MAIN_EXP_START = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/040_main_experiment_start.json"
JSON_PATH_SESSION_1_INTRO = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/042_session_1_introduction.json"
JSON_PATH_SESSION_1_PART2 = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/043_session_1_part2_intro.json"
JSON_PATH_SESSION_1_END = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/044_session_1_end.json"
JSON_PATH_SESSION_2_INTRO = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/046_session_2_introduction.json"
JSON_PATH_SESSION_2_PART2 = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/047_session_2_part2_intro.json"
JSON_PATH_SESSION_2_END = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/048_session_2_end.json"

JSON_PATH_TASK_END_QUEST_AI = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/060_task_end_quest_AI.json"
JSON_PATH_TASK_END_QUEST_XAI = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/060_task_end_quest_XAI.json"
JSON_PATH_TASK_END_COGLOAD = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/070_task_end_quest_cogload.json"
JSON_PATH_FINAL_QUEST_INTRO = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/080_final_quest_introduction.json"
JSON_PATH_FINAL_QUEST_DEMOGRAPHICS = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/090_final_quest_demographics.json"
JSON_PATH_FINAL_QUEST_TRUST_AI_1 = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/092_final_quest_trust1_AI.json"
JSON_PATH_FINAL_QUEST_TRUST_XAI_1 = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/092_final_quest_trust1_XAI.json"
JSON_PATH_FINAL_QUEST_TRUST_AI_2 = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/093_final_quest_trust2_AI.json"
JSON_PATH_FINAL_QUEST_TRUST_XAI_2 = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/093_final_quest_trust2_XAI.json"
JSON_PATH_FINAL_QUEST_STRATEGY = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/095_final_quest_strategy.json"
JSON_PATH_FINAL_QUEST_JUSTIF_USE_XAI = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/094_final_quest_use_justif_XAI.json"
JSON_PATH_FINAL_QUEST_NFC = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/100_final_quest_nfc.json"
JSON_PATH_END_SCORE = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/110_end_score.json"
JSON_PATH_END_LEAVE = os.environ["DATA"] + "webinterfaces/int04_prototype/res/interface_views/112_end_leave.json"

# %%
# Number of images generated
NBGEN = 1000000

# Grid division for full image
X_DIVISIONS_L = 15
Y_DIVISIONS_L = 15
X_DIVISIONS_S = 10
Y_DIVISIONS_S = 10

# Grid division of patterns
X_DIVISIONS_PATTERNS = 2
Y_DIVISIONS_PATTERNS = 2

# Size of the images in pixels
img_size = (700, 700)

# Probability to generate a geometrical shape at each position in the grid
SHAPE_PROB = 0.5

# Define available shapes
SHAPES = ['circle', 'square', 'triangle']
COLORS  = ["#A33E9A", "#E0B000", "#0C90C0"]

# %%
from xaipatimg.datagen.dbimg import load_db

db_patterns = load_db(db_patterns_dir)

# %%
pattern_3sym_2col_keys = []

# Extracting list of patterns that contain 3 symbols and 2 colors
for k, v in db_patterns.items():
    print(v)
    if len(v["content"]) == 3:
        img_col_d = {}
        for entry in v["content"]:
            img_col_d[entry["color"]] = True
        print(img_col_d)

        if len(img_col_d.keys()) == 2:
            pattern_3sym_2col_keys.append(k)
# Out:
# {'path': 'img/24868164b5db11f0b9fae22d0422f8a8.png', 'division': [2, 2], 'size': [300, 300], 'content': [{'shape': 'square', 'pos': [0, 1], 'color': '#A33E9A'}, {'shape': 'triangle', 'pos': [1, 1], 'color': '#0C90C0'}]}
# {'path': 'img/248689f2b5db11f0b9fae22d0422f8a8.png', 'division': [2, 2], 'size': [300, 300], 'content': [{'shape': 'triangle', 'pos': [0, 0], 'color': '#0C90C0'}, {'shape': 'triangle', 'pos': [0, 1], 'color': '#E0B000'}, {'shape': 'circle', 'pos': [1, 0], 'color': '#E0B000'}, {'shape': 'circle', 'pos': [1, 1], 'color': '#0C90C0'}]}
# {'path': 'img/24868d12b5db11f0b9fae22d0422f8a8.png', 'division': [2, 2], 'size': [300, 300], 'content': [{'shape': 'square', 'pos': [1, 0], 'color': '#0C90C0'}, {'shape': 'circle', 'pos': [1, 1], 'color': '#0C90C0'}]}
# {'path': 'img/24868ed4b5db11f0b9fae22d0422f8a8.png', 'division': [2, 2], 'size': [300, 300], 'content': [{'shape': 'square', 'pos': [0, 0], 'color': '#0C90C0'}]}
# ...

# %%
from xaipatimg.datagen.gendataset import generic_rule_pattern_exactly_1_time_exclude_more, \
    generic_rule_shape_color_even

rules_data_L = [

    {"name": "hard1_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_L,
                                                                                                     "y_division_full": Y_DIVISIONS_L,
                                                                                                     "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                     "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                     "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.9, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[0]},

    {"name": "hard2_blue_circle_even", "gen_fun": generic_rule_shape_color_even, "gen_kwargs": {"x_division": X_DIVISIONS_L,
                                                                                                "y_division": Y_DIVISIONS_L,
                                                                                                "shape": "circle",
                                                                                                "color": "#0C90C0"},
     "question": "Is the number of blue circles an even number?", "target_acc" : 0.9, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

    {"name": "hard3_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_L,
                                                                                                     "y_division_full": Y_DIVISIONS_L,
                                                                                                     "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                     "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                     "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.9, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[1]},

    {"name": "hard4_purple_square_even", "gen_fun": generic_rule_shape_color_even, "gen_kwargs": {"x_division": X_DIVISIONS_L,
                                                                                                "y_division": Y_DIVISIONS_L,
                                                                                                "shape": "square",
                                                                                                "color": "#A33E9A"},
     "question": "Is the number of purple squares an even number?", "target_acc" : 0.9, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},
]

# %%
from xaipatimg.datagen.gendataset import generic_rule_pattern_exactly_1_time_exclude_more, \
    generic_rule_shape_color_even

rules_data_S = [

    {"name": "easy1_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_S,
                                                                                                     "y_division_full": Y_DIVISIONS_S,
                                                                                                     "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                     "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                     "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.9, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[2]},

    {"name": "easy2_yellow_triangle_even", "gen_fun": generic_rule_shape_color_even, "gen_kwargs": {"x_division": X_DIVISIONS_S,
                                                                                                "y_division": Y_DIVISIONS_S,
                                                                                                "shape": "triangle",
                                                                                                "color": "#E0B000"},
     "question": "Is the number of yellow triangles an even number?", "target_acc" : 0.9, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

    {"name": "easy3_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_S,
                                                                                                     "y_division_full": Y_DIVISIONS_S,
                                                                                                     "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                     "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                     "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.9, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[3]},

    {"name": "easy4_purple_circle_even", "gen_fun": generic_rule_shape_color_even, "gen_kwargs": {"x_division": X_DIVISIONS_S,
                                                                                                  "y_division": Y_DIVISIONS_S,
                                                                                                  "shape": "circle",
                                                                                                  "color": "#A33E9A"},
     "question": "Is the number of purple circles an even number?", "target_acc" : 0.9, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},
]

# %%
from xaipatimg.datagen.gendataset import generic_rule_pattern_exactly_1_time_exclude_more, \
    generic_rule_shape_color_even

rules_data_M = [

    {"name": "med1_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_L,
                                                                                                     "y_division_full": Y_DIVISIONS_L,
                                                                                                     "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                     "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                     "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.1, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[4]},

    {"name": "med2_yellow_square_even", "gen_fun": generic_rule_shape_color_even, "gen_kwargs": {"x_division": X_DIVISIONS_L,
                                                                                                "y_division": Y_DIVISIONS_L,
                                                                                                "shape": "square",
                                                                                                "color": "#E0B000"},
     "question": "Is the number of yellow squares an even number?", "target_acc" : 0.1, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

    {"name": "med3_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_L,
                                                                                                     "y_division_full": Y_DIVISIONS_L,
                                                                                                     "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                     "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                     "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.1, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[5]},

    {"name": "med4_blue_triangle_even", "gen_fun": generic_rule_shape_color_even, "gen_kwargs": {"x_division": X_DIVISIONS_L,
                                                                                                "y_division": Y_DIVISIONS_L,
                                                                                                "shape": "triangle",
                                                                                                "color": "#0C90C0"},
     "question": "Is the number of blue triangles an even number?", "target_acc" : 0.1, "shown_acc" : 0.5, "samples_interface": 10, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},
]

# %%
from xaipatimg.webxaii_binding.bind import generate_resources_dir

generate_resources_dir(db_dir_L, interface_dir, model_dir_root, [row["name"] for row in rules_data_L], [row["question"] for row in rules_data_L],
                       shown_accuracy_list=[row["shown_acc"] for row in rules_data_L], XAI_names_list=XAI_names,
                       samples_nb_interface_list=[row["samples_interface"] for row in rules_data_L], random_seed=42)

generate_resources_dir(db_dir_S, interface_dir, model_dir_root, [row["name"] for row in rules_data_S], [row["question"] for row in rules_data_S],
                       shown_accuracy_list=[row["shown_acc"] for row in rules_data_S], XAI_names_list=XAI_names,
                       samples_nb_interface_list=[row["samples_interface"] for row in rules_data_S], random_seed=42)

generate_resources_dir(db_dir_M, interface_dir, model_dir_root, [row["name"] for row in rules_data_M], [row["question"] for row in rules_data_M],
                       shown_accuracy_list=[row["shown_acc"] for row in rules_data_M], XAI_names_list=XAI_names,
                       samples_nb_interface_list=[row["samples_interface"] for row in rules_data_M], random_seed=42)

# %%
import shutil

# Copying pattern images
for row in rules_data_L:
    if "pattern_id" in row:
        shutil.copyfile(os.path.join(db_patterns_dir, "img", row["pattern_id"] + ".png"),
                    os.path.join(interface_dir, "res", "tasks", row["pattern_id"] + ".png"))

# Copying pattern images
for row in rules_data_S:
    if "pattern_id" in row:
        shutil.copyfile(os.path.join(db_patterns_dir, "img", row["pattern_id"] + ".png"),
                    os.path.join(interface_dir, "res", "tasks", row["pattern_id"] + ".png"))

# Copying pattern images
for row in rules_data_M:
    if "pattern_id" in row:
        shutil.copyfile(os.path.join(db_patterns_dir, "img", row["pattern_id"] + ".png"),
                    os.path.join(interface_dir, "res", "tasks", row["pattern_id"] + ".png"))

# %%
import csv

def load_json(json_path, set_id=None):
    with open(json_path) as json_data:
        d = json.load(json_data)
        json_data.close()

    if set_id is not None:
        d["view_id"] = set_id

    return d

def load_task_csv(csv_path):
    return list(csv.DictReader(open(csv_path), delimiter=','))

# %%
def gen_page_new_rule(rule_text, pos_example_path, neg_example_path, pattern_path=None, training=False, is_new_question=True, view_id=None, time_limit=-1):

    pattern_img_html = f"<div class='container-fluid text-center'> <img src='{pattern_path}' class='img-fluid w-30' alt='Pattern to search for'> </div><p>" if pattern_path is not None else ""

    return {
        "type": "p-instruction",
        "view_id": view_id,
        "title": f"<h3>New task ({("training" if training else "evaluated")})<h3>",
        "body_text": f"{"⚠️ New question ⚠️<br/>" if is_new_question else ""}<br/><div class='text-start'><p>The question for the task is : <b>{rule_text}</b> </p>{pattern_img_html} {"For this task, there is no time limit to answer the questions." if time_limit==-1 else f"For this task, you will have <b>{time_limit} seconds</b> at most to answer each question."}</p><br/><br/><div class='container-fluid text-center'> <div class='row justify-content-center'> <div class='col-12 col-md-5 d-flex flex-column align-items-center'> <img src='{pos_example_path}' class='img-fluid w-70' alt='Example of image with answer Yes'> Example of image with answer <b>Yes</b> </div> <div class='col-12 col-md-5 d-flex flex-column align-items-center'> <img src='{neg_example_path}' class='img-fluid w-100' alt='Example of image with answer No'> Example of image with answer <b>No</b> </div> </div> </div>",
        "with_button": True,
        "button_text": f"Start the task ({("training" if training else "evaluated")})",
    }

def get_column_csv_xai(condition):
    if condition == "XAI_SHAP":
        return "xai_shap"
    elif condition == "XAI_CF":
        return "xai_cf"
    # elif condition == "XAI_LLM":
    #     return "xai_llm"
    elif condition == "AI":
        return "AI"
    else:
        return ""

def generate_task_instances(rule_csv_path, condition):

    output_instances_d = []

    csv_content = load_task_csv(rule_csv_path)

    for idx in range(len(csv_content)):

        model_d = {
            "is_image": True,
            "label": os.path.join("assets/", csv_content[idx][get_column_csv_xai(condition)]),
            "title": "AI"
        } if "ai" in condition.lower() else {}

        input_d = {
            "is_image": True,
            "label": os.path.join("assets", csv_content[idx]["source"]),
            "title": "Image to analyze"
        }

        curr_instance_d = {
                "input": input_d,
                "expected" : 0 if csv_content[idx]["target"] == "1" else 1,
        }
        if model_d:
            curr_instance_d["model"] = model_d

        output_instances_d.append(
            curr_instance_d
        )

    return output_instances_d

def generate_task_page(rule_txt, rule_csv_path, condition, time_limit, pattern_path, activate_feedback_answer=False, is_training=False, view_id=None):

    pattern_img_html = f"<div class='container-fluid text-center'> <img src='{pattern_path}' class='img-fluid w-30' alt='Pattern to search for'> </div>" if pattern_path is not None else ""

    return {
      "type": "p-task",
      "view_id": view_id,
      # "title": "Answer the question related to the image to analyze, before the timer ends." if time_limit != -1 else "Answer the question related to the image to analyze.",
      "desc" : f"<div style='font-size:1.2em'> {"Training task" if is_training else "Task"} question: <b>{rule_txt} </b></div></br>"
               f"{pattern_img_html}",
      "show_progression_bar": True,
      "randomize": True,
      "timer": time_limit,
      "time_exceeded_timer": 3,
      "feedback_answer_activated": activate_feedback_answer,
      "feedback_answer_correct": "This is the right answer",
      "feedback_answer_wrong": "This is not the right answer",
      "feedback_answer_show_expected": False,
      "feedback_answer_expected_text": "Expected answer : ",
      "instances": generate_task_instances(rule_csv_path, condition),
      "question": {
        "type": "button",
        "primary_text" : "<div style='font-size:0.8em'>Select the answer using the buttons below, before the timer ends.</div>" if time_limit != -1 else "<div style='font-size:0.8em'>Select the answer using the buttons below.</div>",
        # "secondary_text": f"<div style='font-size:1.2em'> <b>{rule_txt} </b></div><br>",
        "answers": [
          "Yes",
          "No"
        ],
        "options": {
            "css_class_colors": ['btn-success', 'btn-danger']
        }
      }
    }

def generate_page_score(final_score=False, view_id=None):
    return {
        "type": 'p-instruction',
        "view_id": view_id,
        "title": f"{'<h3>Final score</h3>' if final_score else '<h3>Task end</h3>'}",
        "body_text" : f"{'During the main experimental phase, you achieved a score of' if final_score else 'You achieved a score of'}",
        "with_button": True,
        "button_text": f"{'Leave' if final_score else 'Next'}",
        "score" : True
    }

# %%
def generate_instructions_page(title, content, button_text=None, view_id=None):
    return {
      "type": "p-instruction",
      "view_id": view_id,
      "title": f"<h3>{title}</h3>",
      "body_text": content,
      "button_text": button_text if button_text else "Next",
      "with_button": True
    }

# %%
def generate_task(task, condition, time, display_is_training, activate_feedback_answer, score_page, is_new_question, view_id_prefix, pattern_id):

    task_d = load_json(os.path.join(interface_dir, "res", "tasks", task+".json"))
    rule_text = task_d["question"]
    pos_example_path = task_d["pos_example"]
    neg_example_path = task_d["neg_example"]
    rule_csv_path = os.path.join(interface_dir, "res", "tasks", task+"_content.csv")

    task_json_list = []
    task_json_list.append(gen_page_new_rule(rule_text, pos_example_path, neg_example_path,
                                            os.path.join("assets", "res", "tasks", pattern_id+".png") if pattern_id else None,
                                            display_is_training, is_new_question, view_id=view_id_prefix+"_rule", time_limit=time))
    task_json_list.append(generate_task_page(rule_text, rule_csv_path, condition, time,
                                             pattern_path=os.path.join("assets", "res", "tasks", pattern_id+".png") if pattern_id else None,
                                             activate_feedback_answer=activate_feedback_answer,
                                             is_training=display_is_training, view_id=view_id_prefix+"_task"))
    if score_page:
        task_json_list.append(generate_page_score())
    return task_json_list

def generate_end_of_session_questionnaire(condition, view_id_prefix):
    task_json_list = []

    if "xai" in condition.lower():
        task_json_list.append(load_json(JSON_PATH_TASK_END_QUEST_XAI, set_id=view_id_prefix + "_reliance"))

    elif "ai" in condition.lower():
        task_json_list.append(load_json(JSON_PATH_TASK_END_QUEST_AI, set_id=view_id_prefix + "_reliance"))

    task_json_list.append(load_json(JSON_PATH_TASK_END_COGLOAD, set_id=view_id_prefix + "_cogload"))

    return task_json_list

def create_protocol_json(condition, discovery_training_tasks, easy_training_tasks, difficult_training_tasks, easy_tasks, difficult_tasks, time_mild,
                         time_strong, time_training):
    """
    :param condition: Either "H", "AI", "XAI_SHAP", "XAI_CF", "XAI_LLM"
    :return:
    """
    full_list = []

    # full_list.append(load_json(JSON_PATH_CONSENT_FORM))
    # full_list.append(load_json(JSON_PATH_INTRO_FORM))
    # full_list.append(load_json(JSON_PATH_INTRO_DISCOVERY_FORM))
    # full_list.extend(generate_task(discovery_training_tasks[0], "H", -1, display_is_training=True, activate_feedback_answer=True, score_page=True,
    #                                is_new_question=False, view_id_prefix="intro_discovery"))
    # full_list.append(load_json(JSON_PATH_INTRO_FURTHER_INFO_FORM))
    #
    # if condition == "AI":
    #     full_list.append(load_json(JSON_PATH_INSTRUCTIONS_AI_FORM))
    # elif condition == "XAI_SHAP":
    #     full_list.append(load_json(JSON_PATH_INSTRUCTIONS_XAI_SHAP_FORM))
    # elif condition == "XAI_CF":
    #     full_list.append(load_json(JSON_PATH_INSTRUCTIONS_XAI_CF_FORM))
    # elif condition == "XAI_LLM":
    #     full_list.append(load_json(JSON_PATH_INSTRUCTIONS_XAI_LLM_FORM))
    #
    # if "AI" in condition:
    #     full_list.append(load_json(JSON_PATH_INTRO_ACCLIM_1_AI))
    # else:
    #     full_list.append(load_json(JSON_PATH_INTRO_ACCLIM_1))
    # full_list.extend(generate_task(discovery_training_tasks[1], condition, -1, display_is_training=True, activate_feedback_answer=True, score_page=True,
    #                                is_new_question=False, view_id_prefix="intro_acclim_1"))

    # if "AI" in condition:
    #     full_list.append(load_json(JSON_PATH_INTRO_MAIN_TRAINING_AI))
    # else:
    #     full_list.append(load_json(JSON_PATH_INTRO_MAIN_TRAINING))
    # full_list.extend(generate_task(easy_training_tasks[0], condition, time_training, display_is_training=True, activate_feedback_answer=False, score_page=True,
    #                                is_new_question=True, view_id_prefix="intro_training_1"))
    # full_list.extend(generate_task(difficult_training_tasks[0], condition, time_training, display_is_training=True, activate_feedback_answer=False, score_page=True,
    #                                is_new_question=True, view_id_prefix="intro_training_3"))
    #

    # Session 1
    full_list.append(load_json(JSON_PATH_MAIN_EXP_START))
    full_list.append(load_json(JSON_PATH_SESSION_1_INTRO))
    full_list.extend(generate_task(easy_tasks[0], condition, time_mild, display_is_training=False, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="mainexp_easy1_rot", pattern_id=rules_data_M[0]["pattern_id"]))
    full_list.extend(generate_task(easy_tasks[1], condition, time_mild, display_is_training=False, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="mainexp_easy2_even", pattern_id=None))
    full_list.extend(generate_task(easy_tasks[2], condition, time_strong, display_is_training=False, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="mainexp_easy3_rot", pattern_id=rules_data_M[2]["pattern_id"]))
    full_list.extend(generate_task(easy_tasks[3], condition, time_strong, display_is_training=False, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="mainexp_easy4_even", pattern_id=None))


    # full_list.extend(generate_task(easy_tasks[1], condition, time_mild, display_is_training=False, activate_feedback_answer=False, score_page=False,
    #                                is_new_question=True, view_id_prefix="mainexp_easy_mild_2"))s
    # full_list.extend(generate_end_of_session_questionnaire(condition, view_id_prefix="mainexp_easy_mild"))
    # full_list.append(load_json(JSON_PATH_SESSION_1_PART2))
    # full_list.extend(generate_task(easy_tasks[2], condition, time_strong, display_is_training=False, activate_feedback_answer=False, score_page=False,
    #                                is_new_question=True, view_id_prefix="mainexp_easy_strong_1"))
    # full_list.extend(generate_task(easy_tasks[3], condition, time_strong, display_is_training=False, activate_feedback_answer=False, score_page=False,
    #                                is_new_question=True, view_id_prefix="mainexp_easy_strong_2"))
    # full_list.extend(generate_end_of_session_questionnaire(condition, view_id_prefix="mainexp_easy_strong"))
    # full_list.append(load_json(JSON_PATH_SESSION_1_END))

    # Session 2


    full_list.append(load_json(JSON_PATH_SESSION_2_INTRO))

    full_list.extend(generate_task(difficult_tasks[0], condition, time_mild, display_is_training=False, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="mainexp_hard1_rot", pattern_id=rules_data_L[0]["pattern_id"]))
    full_list.extend(generate_task(difficult_tasks[1], condition, time_mild, display_is_training=False, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="mainexp_hard2_even", pattern_id=None))
    full_list.extend(generate_task(difficult_tasks[2], condition, time_strong, display_is_training=False, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="mainexp_hard3_rot", pattern_id=rules_data_L[2]["pattern_id"]))
    full_list.extend(generate_task(difficult_tasks[3], condition, time_strong, display_is_training=False, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="mainexp_hard4_even", pattern_id=None))

    # full_list.extend(generate_task(difficult_tasks[0], condition, time_mild, display_is_training=False, activate_feedback_answer=False, score_page=False,
    #                                is_new_question=True, view_id_prefix="mainexp_hard_mild_1"))
    # full_list.extend(generate_task(difficult_tasks[1], condition, time_mild, display_is_training=False, activate_feedback_answer=False, score_page=False,
    #                                is_new_question=True, view_id_prefix="mainexp_hard_mild_2"))
    # full_list.extend(generate_end_of_session_questionnaire(condition, view_id_prefix="mainexp_hard_mild"))
    # full_list.append(load_json(JSON_PATH_SESSION_2_PART2))
    # full_list.extend(generate_task(difficult_tasks[2], condition, time_strong, display_is_training=False, activate_feedback_answer=False, score_page=False,
    #                                is_new_question=True, view_id_prefix="mainexp_hard_strong_1"))
    # full_list.extend(generate_task(difficult_tasks[3], condition, time_strong, display_is_training=False, activate_feedback_answer=False, score_page=False,
    #                                is_new_question=True, view_id_prefix="mainexp_hard_strong_2"))
    # full_list.extend(generate_end_of_session_questionnaire(condition, view_id_prefix="mainexp_hard_strong"))
    # full_list.append(load_json(JSON_PATH_SESSION_2_END))
    #
    # full_list.append(load_json(JSON_PATH_FINAL_QUEST_INTRO))
    # full_list.append(load_json(JSON_PATH_FINAL_QUEST_NFC, set_id="closing_quest_nfc"))
    # if "XAI" in condition:
    #     full_list.append(load_json(JSON_PATH_FINAL_QUEST_TRUST_XAI_1, set_id="closing_quest_trust_1"))
    #     full_list.append(load_json(JSON_PATH_FINAL_QUEST_TRUST_XAI_2, set_id="closing_quest_trust_2"))
    #     full_list.append(load_json(JSON_PATH_FINAL_QUEST_JUSTIF_USE_XAI, set_id="closing_quest_use_xai"))
    #     full_list.append(load_json(JSON_PATH_FINAL_QUEST_STRATEGY, set_id="closing_quest_strategy"))
    #
    # elif "AI" in condition:
    #     full_list.append(load_json(JSON_PATH_FINAL_QUEST_TRUST_AI_1, set_id="closing_quest_trust_1"))
    #     full_list.append(load_json(JSON_PATH_FINAL_QUEST_TRUST_AI_2, set_id="closing_quest_trust_2"))
    #     full_list.append(load_json(JSON_PATH_FINAL_QUEST_STRATEGY, set_id="closing_quest_strategy"))
    #
    full_list.append(load_json(JSON_PATH_END_SCORE))
    full_list.append(generate_page_score(final_score=True))
    # full_list.append(load_json(JSON_PATH_END_LEAVE))
    return full_list

# %%
import shutil
import json

def create_users_json(conditions, users):
    output_dict = {}

    for condition in conditions:
        for user in users[condition]:
            output_dict[user] = {"roles": "user", "protocol": condition+".json"}

    return output_dict

def deploy(output_json_dir, output_assets_dir, users):

    protocols_path = os.path.join(output_json_dir, "protocols")
    users_path = os.path.join(output_json_dir, "users.json")
    assets_output_path = os.path.join(output_assets_dir, "res")

    # Removing former installation
    shutil.rmtree(protocols_path, ignore_errors=True)
    try:
        os.remove(users_path)
    except FileNotFoundError:
        pass

    os.makedirs(protocols_path)

    for condition in CONDITIONS:
        # Writing of JSON protocol files
        protocol_json = create_protocol_json(condition, DISCOVERY_TRAINING_TASKS, EASY_TRAINING_TASKS, DIFFICULT_TRAINING_TASKS, EASY_TASKS, DIFFICULT_TASKS, TIME_MILD, TIME_STRONG, TIME_TRAINING)
        with open(os.path.join(protocols_path, condition+".json"), 'w') as f:
            json.dump(protocol_json, f, indent=4)

    # Writing users json file
    users_json = create_users_json(CONDITIONS, users)
    with open(users_path, 'w') as f:
        json.dump(users_json, f, indent=4)

    # Copy assets
    shutil.rmtree(assets_output_path, ignore_errors=True)
    shutil.copytree(os.path.join(interface_dir, "res"), assets_output_path)

# %%
deploy(output_json_dir, output_assets_dir, users)

# %%
treatments = ["H", "AI", "SHAP", "LLM", "CF", "CF"]

# %%
import numpy as np
np.random.choice(treatments, replace=False, size=6)
# Out:
# array(['H', 'SHAP', 'CF', 'AI', 'LLM', 'CF'], dtype='<U4')
