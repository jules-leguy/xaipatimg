# %%
import os

db_S_dir = os.environ["DATA"] + "PatImgXAI_data/db3.2.0/S/"
db_L_dir = os.environ["DATA"] + "PatImgXAI_data/db3.2.0/L/"
db_M_dir = os.environ["DATA"] + "PatImgXAI_data/db3.2.0/M/"
db_XS_dir = os.environ["DATA"] + "PatImgXAI_data/db3.2.0/XS/"
db_patterns_dir = os.environ["DATA"] + "PatImgXAI_data/db3.2.0/patterns/"

interface_dir = os.environ["DATA"] + "webinterfaces/exp02/"
model_dir_root = os.environ["DATA"] + "models/db3.2.0/01_expv1/"
output_json_dir = "/home/jleguy/Documents/postdoc/git_repos/WebXAII/functions/data/"
output_assets_dir = "/home/jleguy/Documents/postdoc/git_repos/WebXAII/src/assets/"

XAI_names = ["shap", "cf"]
# XAI_names = ["shap"]

N_PROTOCOL_FILES = {
    # "H": 20,
    "AI": 12,
    "XAI_SHAP": 12,
    "XAI_CF": 13
}

# %%
# CONDITIONS = ["H"]
# CONDITIONS = ["H", "AI", "XAI_SHAP", "XAI_CF"]
CONDITIONS = ["AI", "XAI_SHAP", "XAI_CF"]

INTRO_TASKS = ["easy1_find_pattern_rot", "easy3_find_pattern_rot"]
COMPREHENSION_TEST_TASKS = ["xeasy1_find_pattern_rot"]

EASY_TASKS = ["med1_find_pattern_rot", "med3_find_pattern_rot"]
DIFFICULT_TASKS = ["hard1_find_pattern_rot", "hard3_find_pattern_rot"]

TIME_TRAINING = 45
TIME_MILD = 20
TIME_STRONG = 10

JSON_PATH_CONSENT_FORM = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/000_consent_form.json"
JSON_PATH_INTRO_DISCOVERY_FORM = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/015_intro_discovery.json"
JSON_PATH_INTRO_PAGE_ADJUSTMENT_FORM = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/015bis_page_adjustment.json"
JSON_PATH_INTRO_PATTERN_TASK_FORM = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/016_intro_discovery_pattern_tasks.json"
JSON_PATH_INTRO_FURTHER_INFO_FORM = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/017_intro_further_info.json"
JSON_PATH_INTRO_COMPREHENSION_INTRO = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/019_intro_comprehension_test.json"

JSON_PATH_INSTRUCTIONS_AI_FORM = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/020_instructions_AI.json"
JSON_PATH_INSTRUCTIONS_XAI_SHAP_FORM = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/020_instructions_XAI_SHAP.json"
JSON_PATH_INSTRUCTIONS_XAI_CF_FORM = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/020_instructions_XAI_CF.json"
JSON_PATH_INSTRUCTIONS_XAI_LLM_FORM = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/020_instructions_XAI_LLM.json"

JSON_PATH_INTRO_MAIN_TRAINING = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/035_intro_main_training.json"
JSON_PATH_INTRO_MAIN_TRAINING_AI = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/035_intro_main_training_AI.json"

JSON_PATH_MAIN_EXP_START = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/040_main_experiment_start.json"
JSON_PATH_SESSION_1_INTRO = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/042_session_1_introduction.json"
JSON_PATH_SESSION_1_PART2 = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/043_session_1_part2_intro.json"
JSON_PATH_SESSION_1_END = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/044_session_1_end.json"
JSON_PATH_SESSION_2_INTRO = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/046_session_2_introduction.json"
JSON_PATH_SESSION_2_PART2 = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/047_session_2_part2_intro.json"
JSON_PATH_SESSION_2_END = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/048_session_2_end.json"

JSON_PATH_TASK_END_QUEST_AI = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/060_task_end_quest_AI.json"
JSON_PATH_TASK_END_QUEST_XAI = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/060_task_end_quest_XAI.json"
JSON_PATH_TASK_END_COGLOAD = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/070_task_end_quest_cogload.json"

JSON_PATH_FINAL_QUEST_INTRO = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/080_final_quest_introduction.json"
JSON_PATH_FINAL_QUEST_NOAI_NOQUEST = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/080_no_AI_no_quest.json"

JSON_PATH_FINAL_QUEST_TRUST_AI_1 = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/092_final_quest_trust1_AI.json"
JSON_PATH_FINAL_QUEST_TRUST_XAI_1 = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/092_final_quest_trust1_XAI.json"
JSON_PATH_FINAL_QUEST_TRUST_AI_2 = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/093_final_quest_trust2_AI.json"
JSON_PATH_FINAL_QUEST_TRUST_XAI_2 = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/093_final_quest_trust2_XAI.json"
JSON_PATH_FINAL_QUEST_STRATEGY = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/095_final_quest_strategy.json"
JSON_PATH_FINAL_QUEST_JUSTIF_USE_XAI = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/094_final_quest_use_justif_XAI.json"
JSON_PATH_FINAL_QUEST_NFC = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/100_final_quest_nfc.json"
JSON_PATH_END_SCORE = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/110_end_score.json"
JSON_PATH_END_LEAVE = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/112_end_leave.json"

JSON_PATH_ATTENTIONCHECK1 = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/050_attentioncheck.json"
JSON_PATH_ATTENTIONCHECK2 = os.environ["DATA"] + "webinterfaces/exp01/res/interface_views/081_attentioncheck.json"

# %%
# Number of images generated
NBGEN_full_per_size = 5000000
NBGEN_patterns = 1000

# Grid division for full image
X_DIVISIONS_L = 15
Y_DIVISIONS_L = 15
X_DIVISIONS_S = 8
Y_DIVISIONS_S = 8
X_DIVISIONS_M = 11
Y_DIVISIONS_M = 11
X_DIVISIONS_XS = 6
Y_DIVISIONS_XS = 6

# Grid division of patterns
X_DIVISIONS_PATTERNS = 2
Y_DIVISIONS_PATTERNS = 2

# Size of the images in pixels
img_size = (700, 700)
img_size_patterns = (300, 300)

# Probability to generate a geometrical shape at each position in the grid
SHAPE_PROB = 0.5

# Define available shapes
SHAPES = ['c', 's', 't']
COLORS  = ["p", "y", "b"]

# %%
from xaipatimg.datagen.dbimg import load_db

db_patterns = load_db(db_patterns_dir)

# %%
import numpy as np

pattern_3sym_2col_keys = []

# Extracting list of patterns that contain 3 symbols of 3 different shapes and 2 different colors. The two items of the same color cannot be
# on a diagonal.
for k, v in db_patterns.items():
    if len(v["cnt"]) == 3:
        img_col_d = {}
        img_shape_d = {}
        color_matrix = np.full((2, 2), "", dtype="U100")
        for entry in v["cnt"]:
            img_col_d[entry["col"]] = True
            img_shape_d[entry["shp"]] = True
            color_matrix[entry["pos"][0]][entry["pos"][1]] = entry["col"]

        same_color_on_diagonal = color_matrix[0][0] == color_matrix[1][1] or color_matrix[0][1] == color_matrix[1][0]

        if len(img_col_d.keys()) == 2 and len(img_shape_d.keys()) == 3 and not same_color_on_diagonal:
            pattern_3sym_2col_keys.append(k)

# %%
from xaipatimg.datagen.gendataset import generic_rule_pattern_exactly_1_time_exclude_more, \
    generic_rule_N_times_color_shape_exactly, generic_rule_shape_in_every_row

rules_data_L = [

    {"name": "hard1_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_L,
                                                                                                                   "y_division_full": Y_DIVISIONS_L,
                                                                                                                   "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                                   "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                                   "consider_rotations": True},
     "question": "Is the pattern or any of its right of left rotations in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[0]},

    {"name": "hard3_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_L,
                                                                                                                   "y_division_full": Y_DIVISIONS_L,
                                                                                                                   "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                                   "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                                   "consider_rotations": True},
     "question": "Is the pattern or any of its right of left rotations in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[1]},

    #
    # {"name": "hard2_blue_circle_N", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {"x_division": X_DIVISIONS_L,
    #                                                                                                     "y_division": Y_DIVISIONS_L,
    #                                                                                                     "shape": "c",
    #                                                                                                     "color": "b",
    #                                                                                                     "N": 13,
    #                                                                                                     "restrict_plus_minus_1": True},
    #  "question": "Does the number of blue circles equal to 13 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "The image contains 13 blue circles. They are highlighted below. | A1;B1;C1;B2;C2;D2;E4;F4;G5;A6;B6;E6;D7", "neg_llm_scaffold": "The image contains 12 blue circles instead of 13. They are highlighted below. | A2;B3;D3;B3;C3;D3;E5;F6;A7;B7;E7;H9"},

    # {"name": "hard2bis_blue_circle_N_norestrict", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {"x_division": X_DIVISIONS_L,
    #                                                                                                                   "y_division": Y_DIVISIONS_L,
    #                                                                                                                   "shape": "c",
    #                                                                                                                   "color": "b",
    #                                                                                                                   "N": 13,
    #                                                                                                                   "restrict_plus_minus_1": False},
    #  "question": "Does the number of blue circles equal to 13 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

    #
    # {"name": "hard4_purple_triangle_N", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {"x_division": X_DIVISIONS_L,
    #                                                                                                         "y_division": Y_DIVISIONS_L,
    #                                                                                                         "shape": "t",
    #                                                                                                         "color": "p",
    #                                                                                                         "N": 13,
    #                                                                                                         "restrict_plus_minus_1": True},
    #  "question": "Does the number of purple triangles equal to 13 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},
    # #
    # {"name": "hard4bis_purple_triangle_N_norestrict", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {
    #     "x_division": X_DIVISIONS_L,
    #     "y_division": Y_DIVISIONS_L,
    #     "shape": "t",
    #     "color": "p",
    #     "N": 13,
    #     "restrict_plus_minus_1": False},
    #  "question": "Does the number of purple triangles equal to 13 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

]

# %%
from xaipatimg.datagen.gendataset import generic_rule_pattern_exactly_1_time_exclude_more, \
    generic_rule_N_times_color_shape_exactly

rules_data_S = [

    {"name": "easy1_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_S,
                                                                                                                   "y_division_full": Y_DIVISIONS_S,
                                                                                                                   "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                                   "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                                   "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 4, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[2]},

    # {"name": "easy2_yellow_triangle_N", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {"x_division": X_DIVISIONS_S,
    #                                                                                                         "y_division": Y_DIVISIONS_S,
    #                                                                                                         "shape": "t",
    #                                                                                                         "color": "y",
    #                                                                                                         "N": 6,
    #                                                                                                         "restrict_plus_minus_1": True},
    #  "question": "Does the number of yellow triangles equal to 6 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 6, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},
    #
    # {"name": "easy2bis_yellow_triangle_N_norestrict", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {
    #     "x_division": X_DIVISIONS_S,
    #     "y_division": Y_DIVISIONS_S,
    #     "shape": "t",
    #     "color": "y",
    #     "N": 6,
    #     "restrict_plus_minus_1": False},
    #  "question": "Does the number of yellow triangles equal to 6 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 6, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

    {"name": "easy3_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_S,
                                                                                                                   "y_division_full": Y_DIVISIONS_S,
                                                                                                                   "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                                   "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                                   "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 6, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[3]},
    #
    # {"name": "easy4_purple_circle_N", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {"x_division": X_DIVISIONS_S,
    #                                                                                                       "y_division": Y_DIVISIONS_S,
    #                                                                                                       "shape": "c",
    #                                                                                                       "color": "p",
    #                                                                                                       "N": 6,
    #                                                                                                       "restrict_plus_minus_1": True},
    #  "question": "Does the number of purple circles equal to 6 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 6, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},
    #
    # {"name": "easy4bis_purple_circle_N_norestrict", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {
    #     "x_division": X_DIVISIONS_S,
    #     "y_division": Y_DIVISIONS_S,
    #     "shape": "c",
    #     "color": "p",
    #     "N": 6,
    #     "restrict_plus_minus_1": False},
    #  "question": "Does the number of purple circles equal to 6 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 6, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

    {"name": "easy5_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_S,
                                                                                                                   "y_division_full": Y_DIVISIONS_S,
                                                                                                                   "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                                   "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                                   "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 6, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[6]},

]

# %%
pattern_3sym_2col_keys
# Out:
# ['140f282cd25511f088b412a439d55952',
#  '140f4c08d25511f088b412a439d55952',
#  '140f863cd25511f088b412a439d55952',
#  '140fce94d25511f088b412a439d55952',
#  '141040a4d25511f088b412a439d55952',
#  '14104ff4d25511f088b412a439d55952',
#  '14328164d25511f088b412a439d55952',
#  '1432cdf4d25511f088b412a439d55952',
#  '1432f6dad25511f088b412a439d55952',
#  '1432fa7cd25511f088b412a439d55952',
#  '14330850d25511f088b412a439d55952',
#  '14331a98d25511f088b412a439d55952',
#  '14335026d25511f088b412a439d55952',
#  '1433df82d25511f088b412a439d55952',
#  '143476b8d25511f088b412a439d55952',
#  '1434bbfad25511f088b412a439d55952',
#  '143513acd25511f088b412a439d55952',
#  '14354ea8d25511f088b412a439d55952',
#  '143559d4d25511f088b412a439d55952',
#  '1435d1c0d25511f088b412a439d55952',
#  '143630c0d25511f088b412a439d55952',
#  '14363ec6d25511f088b412a439d55952',
#  '14365244d25511f088b412a439d55952',
#  '1436bc8ed25511f088b412a439d55952',
#  '1437842ad25511f088b412a439d55952',
# ...

# %%
from xaipatimg.datagen.gendataset import generic_rule_pattern_exactly_1_time_exclude_more, \
    generic_rule_N_times_color_shape_exactly
rules_data_M = [

    {"name": "med1_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_M,
                                                                                                                  "y_division_full": Y_DIVISIONS_M,
                                                                                                                  "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                                  "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                                  "consider_rotations": True},
     "question": "Is the pattern or any of its right of left rotations in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[4]},

    {"name": "med3_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_M,
                                                                                                                  "y_division_full": Y_DIVISIONS_M,
                                                                                                                  "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                                  "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                                  "consider_rotations": True,
                                                                                                                  },
     "question": "Is the pattern or any of its right of left rotations in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[5]},

    #
    # {"name": "med2_yellow_square_N", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {"x_division": X_DIVISIONS_M,
    #                                                                                                      "y_division": Y_DIVISIONS_M,
    #                                                                                                      "shape": "s",
    #                                                                                                      "color": "y",
    #                                                                                                      "N": 8,
    #                                                                                                      "restrict_plus_minus_1": True},
    #  "question": "Does the number of yellow squares equal to 8 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

    #
    # {"name": "med2bis_yellow_square_N_norestrict", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {"x_division": X_DIVISIONS_M,
    #                                                                                                                    "y_division": Y_DIVISIONS_M,
    #                                                                                                                    "shape": "s",
    #                                                                                                                    "color": "y",
    #                                                                                                                    "N": 8,
    #                                                                                                                    "restrict_plus_minus_1": False},
    #  "question": "Does the number of yellow squares equal to 8 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

    #

    #
    # {"name": "med4_blue_triangle_N", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {"x_division": X_DIVISIONS_M,
    #                                                                                                      "y_division": Y_DIVISIONS_M,
    #                                                                                                      "shape": "t",
    #                                                                                                      "color": "b",
    #                                                                                                      "N": 8,
    #                                                                                                      "restrict_plus_minus_1": True},
    #  "question": "Does the number of blue triangles equal to 8 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

    # {"name": "med4bis_blue_triangle_N_norestrict", "gen_fun": generic_rule_N_times_color_shape_exactly, "gen_kwargs": {
    #     "x_division": X_DIVISIONS_M,
    #     "y_division": Y_DIVISIONS_M,
    #     "shape": "t",
    #     "color": "b",
    #     "N": 8,
    #     "restrict_plus_minus_1": False},
    #  "question": "Does the number of blue triangles equal to 8 in the image?", "target_acc" : 0.85, "shown_acc" : 0.85, "samples_interface": 13, "pos_llm_scaffold": "", "neg_llm_scaffold": ""},

]

# %%
from xaipatimg.datagen.gendataset import generic_rule_pattern_exactly_1_time_exclude_more, \
    generic_rule_N_times_color_shape_exactly, generic_rule_shape_in_every_row

rules_data_XS = [
    {"name": "xeasy1_find_pattern_rot", "gen_fun": generic_rule_pattern_exactly_1_time_exclude_more, "gen_kwargs": {"x_division_full": X_DIVISIONS_XS,
                                                                                                                    "y_division_full": Y_DIVISIONS_XS,
                                                                                                                    "x_division_pattern": X_DIVISIONS_PATTERNS,
                                                                                                                    "y_division_pattern": Y_DIVISIONS_PATTERNS,
                                                                                                                    "consider_rotations": True},
     "question": "Is the pattern or any of its left or right rotations in the image?", "target_acc" : 0.5, "shown_acc" : 0.5, "samples_interface": 6, "pos_llm_scaffold": "", "neg_llm_scaffold": "", "pattern_id": pattern_3sym_2col_keys[7]},

]

# %%
from xaipatimg.webxaii_binding.bind import generate_resources_dir

generate_resources_dir(os.path.join(db_L_dir, "min/"), interface_dir, model_dir_root, [row["name"] for row in rules_data_L],
                       [row["question"] for row in rules_data_L],
                       shown_accuracy_list=[row["shown_acc"] for row in rules_data_L], XAI_names_list=XAI_names,
                       samples_nb_interface_list=[row["samples_interface"] for row in rules_data_L], random_seed=42,
                       balanced_fn_fp_errors=True)

generate_resources_dir(os.path.join(db_S_dir, "min/"), interface_dir, model_dir_root, [row["name"] for row in rules_data_S],
                       [row["question"] for row in rules_data_S],
                       shown_accuracy_list=[row["shown_acc"] for row in rules_data_S], XAI_names_list=XAI_names,
                       samples_nb_interface_list=[row["samples_interface"] for row in rules_data_S], random_seed=42,
                       balanced_fn_fp_errors=False)

generate_resources_dir(os.path.join(db_M_dir, "min/"), interface_dir, model_dir_root, [row["name"] for row in rules_data_M],
                       [row["question"] for row in rules_data_M],
                       shown_accuracy_list=[row["shown_acc"] for row in rules_data_M], XAI_names_list=XAI_names,
                       samples_nb_interface_list=[row["samples_interface"] for row in rules_data_M], random_seed=42,
                       balanced_fn_fp_errors=True)

generate_resources_dir(os.path.join(db_XS_dir, "min/"), interface_dir, model_dir_root, [row["name"] for row in rules_data_XS],
                       [row["question"] for row in rules_data_XS],
                       shown_accuracy_list=[row["shown_acc"] for row in rules_data_XS], XAI_names_list=XAI_names,
                       samples_nb_interface_list=[row["samples_interface"] for row in rules_data_XS], random_seed=2,
                       balanced_fn_fp_errors=False)
# Out:
# hard1_find_pattern_rot
# hard3_find_pattern_rot
# easy1_find_pattern_rot
# easy3_find_pattern_rot
# easy5_find_pattern_rot
# med1_find_pattern_rot
# med3_find_pattern_rot
# xeasy1_find_pattern_rot
# ...

# %%
from PIL import Image, ImageDraw, ImageFont

def concat_images(i1, i2, i3,
                  spacing_after_first=20,
                  padding=20,
                  symbol_font_size=130,
                  or_font_size=90):

    # Assume all images already have the same size
    img_w, img_h = i1.size

    # Fonts
    try:
        sym_font = ImageFont.truetype("DejaVuSans.ttf", symbol_font_size)
        or_font = ImageFont.truetype("DejaVuSans.ttf", or_font_size)
    except:
        sym_font = or_font = ImageFont.load_default()

    sym2 = "↻"
    sym3 = "↺"
    or_text = "OR"

    # Text size helper
    def text_size(draw, text, font):
        l, t, r, b = draw.textbbox((0, 0), text, font=font)
        return r - l, b - t

    tmp = Image.new("RGB", (10, 10))
    tmp_draw = ImageDraw.Draw(tmp)

    or_w, or_h = text_size(tmp_draw, or_text, or_font)
    s2_w, s2_h = text_size(tmp_draw, sym2, sym_font)
    s3_w, s3_h = text_size(tmp_draw, sym3, sym_font)

    content_height = max(img_h, or_h, s2_h, s3_h)
    final_h = content_height + padding * 2

    final_w = (
            padding
            + img_w
            + spacing_after_first
            + or_w + padding + s2_w + padding
            + img_w
            + padding
            + or_w + padding + s3_w + padding
            + img_w
            + padding
    )

    out = Image.new("RGBA", (final_w, final_h), (255, 255, 255, 255))
    draw = ImageDraw.Draw(out)

    y_img = (final_h - img_h) // 2
    y_or = (final_h - or_h) // 2
    y_s2 = (final_h - s2_h) // 2
    y_s3 = (final_h - s3_h) // 2

    # Image 1
    x = padding
    out.paste(i1, (x, y_img), i1 if i1.mode == "RGBA" else None)

    # OR + ↻
    x += img_w + spacing_after_first
    draw.text((x, y_or), or_text, font=or_font, fill="black")

    x += or_w + padding
    draw.text((x, y_s2), sym2, font=sym_font, fill="black")

    # Image 2
    x += s2_w + padding
    out.paste(i2, (x, y_img), i2 if i2.mode == "RGBA" else None)

    # OR + ↺
    x += img_w + padding
    draw.text((x, y_or), or_text, font=or_font, fill="black")

    x += or_w + padding
    draw.text((x, y_s3), sym3, font=sym_font, fill="black")

    # Image 3
    x += s3_w + padding
    out.paste(i3, (x, y_img), i3 if i3.mode == "RGBA" else None)

    return out

# %%
from xaipatimg.datagen.genimg import gen_img
import tempfile
from xaipatimg.datagen.utils import rotate


def gen_displayed_pattern_img(rules_data, patterns_db, interface_dir, X_DIVISIONS, Y_DIVISIONS):
    for row in rules_data:
        if "pattern_id" in row:
            img_content = patterns_db[row["pattern_id"]]["cnt"]
            img_content_right_rot = rotate(img_content, 2, 2, direction=1)
            img_content_left_rot = rotate(img_content, 2, 2, direction=-1)

            img = gen_img(None, img_content, division=(2, 2), draw_coordinates=False, empty_cell_as_question_mark=True,
                          return_image=True)
            img_right_rot = gen_img(None, img_content_right_rot, division=(2, 2), draw_coordinates=False,
                                    empty_cell_as_question_mark=True, return_image=True)

            img_left_rot = gen_img(None, img_content_left_rot, division=(2, 2), draw_coordinates=False,
                                    empty_cell_as_question_mark=True, return_image=True)


            concat_img = concat_images(img, img_right_rot, img_left_rot)
            concat_img.save(os.path.join(os.path.join(interface_dir, "res", "tasks", row["pattern_id"] + ".png")))

# %%
gen_displayed_pattern_img(rules_data_L, db_patterns, interface_dir, X_DIVISIONS_L, Y_DIVISIONS_L)
gen_displayed_pattern_img(rules_data_S, db_patterns, interface_dir, X_DIVISIONS_S, Y_DIVISIONS_S)
gen_displayed_pattern_img(rules_data_M, db_patterns, interface_dir, X_DIVISIONS_M, Y_DIVISIONS_M)
gen_displayed_pattern_img(rules_data_XS, db_patterns, interface_dir, X_DIVISIONS_XS, Y_DIVISIONS_XS)

# %%
import csv

def load_json(json_path, set_id=None):
    with open(json_path) as json_data:
        d = json.load(json_data)
        json_data.close()

    if set_id is not None:
        d["view_id"] = set_id

    return d

def load_task_csv(csv_path):
    return list(csv.DictReader(open(csv_path), delimiter=','))

# %%
def gen_page_new_rule(rule_text, pos_example_path, neg_example_path, pattern_path=None, training=False, is_new_question=True, view_id=None, time_limit=-1):

    pattern_img_html = f"<div class='container-fluid text-center'> <div class='row justify-content-center'> <div class='col-12 col-md-5 d-flex flex-column align-items-center'><img src='{pattern_path}' class='img-fluid' alt='Pattern to search for'> </div> </div> </div><p>" if pattern_path is not None else ""

    return {
        "type": "p-instruction",
        "view_id": view_id,
        "title": f"<h3>New task ({("training" if training else "evaluated")})<h3>",
        "body_text": f"{"⚠️ New question ⚠️<br/>" if is_new_question else ""}<br/><div class='text-start'><p>The question is : <b>{rule_text}</b> </p>{pattern_img_html} {"For this task, there is no time limit to answer the questions." if time_limit==-1 else f"For this task, you will have <b>{time_limit} seconds</b> at most to answer each question."}</p><br/><br/><div class='container-fluid text-center'> <div class='row justify-content-center'> <div class='col-12 col-md-5 d-flex flex-column align-items-center'> <img src='{pos_example_path}' class='img-fluid w-70' alt='Example of image with answer Yes'> Example of image with answer <b>Yes</b> </div> <div class='col-12 col-md-5 d-flex flex-column align-items-center'> <img src='{neg_example_path}' class='img-fluid w-100' alt='Example of image with answer No'> Example of image with answer <b>No</b> </div> </div> </div>",
        "with_button": True,
        "button_text": f"Start the task ({("training" if training else "evaluated")})",
    }

def get_column_csv_xai(condition):
    if condition == "XAI_SHAP":
        return "xai_shap"
    elif condition == "XAI_CF":
        return "xai_cf"
    # elif condition == "XAI_LLM":
    #     return "xai_llm"
    elif condition == "AI":
        return "AI"
    else:
        return ""

def generate_task_instances(rule_csv_path, condition):

    output_instances_d = []

    csv_content = load_task_csv(rule_csv_path)

    for idx in range(len(csv_content)):

        expl_d = [{
            "is_image": True,
            "label": os.path.join("assets/", csv_content[idx][get_column_csv_xai(condition)]),
            "title": "AI"
        }] if "ai" in condition.lower() else []

        input_d = {
            "is_image": True,
            "label": os.path.join("assets", csv_content[idx]["source"]),
            "title": "Image to analyze"
        }

        curr_instance_d = {
                "input": input_d,
                "expected" : 0 if csv_content[idx]["target"] == "1" else 1,
        }
        if expl_d:
            curr_instance_d["explanations"] = expl_d

        output_instances_d.append(
            curr_instance_d
        )

    return output_instances_d

def generate_task_page(rule_txt, rule_csv_path, condition, time_limit, pattern_path, activate_feedback_answer=False, is_training=False, view_id=None):

    pattern_img_html = f"<div class='container-fluid text-center'> <div class='row justify-content-center'> <div class='col-9 col-md-3 d-flex flex-column align-items-center'><img src='{pattern_path}' class='img-fluid' alt='Pattern to search for'> </div> </div> </div>" if pattern_path is not None else ""

    return {
      "type": "p-task",
      "view_id": view_id,
      # "title": "Answer the question related to the image to analyze, before the timer ends." if time_limit != -1 else "Answer the question related to the image to analyze.",
      "desc" : f"<div style='font-size:1.2em'> {"Training task" if is_training else "Task"} question: <b>{rule_txt} </b></div>"
               f"{pattern_img_html}",
      "show_progression_bar": True,
      "randomize": True,
      "timer": time_limit,
      "time_exceeded_timer": 3,
      "feedback_answer_activated": activate_feedback_answer,
      "feedback_answer_correct": "This is the correct answer. Please remind to adjust the zoom of the page in case all elements are not visible at once (using ctrl and mouse scroll or ctrl and +/- keys).",
      "feedback_answer_wrong": "This is not the correct answer. Please remind to adjust the zoom of the page in case all elements are not visible at once (using ctrl and mouse scroll or ctrl and +/- keys).",
      "feedback_answer_show_expected": False,
      "feedback_answer_expected_text": "Expected answer : ",
      "instances": generate_task_instances(rule_csv_path, condition),
      "question": {
        "type": "button",
        "primary_text" : "<div style='font-size:0.8em'>Select the answer using the buttons below, before the timer ends.</div>" if time_limit != -1 else "<div style='font-size:0.8em'>Select the answer using the buttons below.</div>",
        # "secondary_text": f"<div style='font-size:1.2em'> <b>{rule_txt} </b></div><br>",
        "answers": [
          "Yes",
          "No"
        ],
        "options": {
            "css_class_colors": ['btn-success', 'btn-danger']
        }
      }
    }

def generate_page_score(final_score=False, view_id=None):
    return {
        "type": 'p-instruction',
        "view_id": view_id,
        "title": f"{'<h3>Final score</h3>' if final_score else '<h3>Task score</h3>'}",
        "body_text" : f"{'During the main experimental phase, you achieved a score of' if final_score else 'On the previous task, you achieved a score of'}",
        "with_button": True,
        "button_text": f"{'Leave' if final_score else 'Next'}",
        "score" : True
    }

# %%
def generate_instructions_page(title, content, button_text=None, view_id=None):
    return {
      "type": "p-instruction",
      "view_id": view_id,
      "title": f"<h3>{title}</h3>",
      "body_text": content,
      "button_text": button_text if button_text else "Next",
      "with_button": True
    }

# %%
def generate_task(task, condition, time, display_is_training, activate_feedback_answer, is_new_question, view_id_prefix, pattern_id, score_page=False):

    task_d = load_json(os.path.join(interface_dir, "res", "tasks", task+".json"))
    rule_text = task_d["question"]
    pos_example_path = task_d["pos_example"]
    neg_example_path = task_d["neg_example"]
    rule_csv_path = os.path.join(interface_dir, "res", "tasks", task+"_content.csv")

    task_json_list = []
    task_json_list.append(gen_page_new_rule(rule_text, pos_example_path, neg_example_path,
                                            os.path.join("assets", "res", "tasks", pattern_id+".png") if pattern_id else None,
                                            display_is_training, is_new_question, view_id=view_id_prefix+"_rule", time_limit=time))
    task_json_list.append(generate_task_page(rule_text, rule_csv_path, condition, time,
                                             pattern_path=os.path.join("assets", "res", "tasks", pattern_id+".png") if pattern_id else None,
                                             activate_feedback_answer=activate_feedback_answer,
                                             is_training=display_is_training, view_id=view_id_prefix+"_task"))

    if score_page:
        task_json_list.append(generate_page_score())

    return task_json_list

def generate_end_of_session_questionnaire(condition, view_id_prefix):
    task_json_list = []

    if "xai" in condition.lower():
        task_json_list.append(load_json(JSON_PATH_TASK_END_QUEST_XAI, set_id=view_id_prefix + "_reliance"))

    elif "ai" in condition.lower():
        task_json_list.append(load_json(JSON_PATH_TASK_END_QUEST_AI, set_id=view_id_prefix + "_reliance"))

    task_json_list.append(load_json(JSON_PATH_TASK_END_COGLOAD, set_id=view_id_prefix + "_cogload"))

    return task_json_list

def generate_session_easy(easy_tasks, condition, time_mild, time_strong, mid_session_json):
    views_list = []
    views_list.extend(generate_task(easy_tasks[0], condition, time_mild, display_is_training=False, activate_feedback_answer=False,
                                   is_new_question=True, view_id_prefix="mainexp_easy1_patrot", score_page=False,
                                   pattern_id=rules_data_M[0]["pattern_id"]))

    views_list.extend(generate_end_of_session_questionnaire(condition, view_id_prefix="mainexp_easy_mild"))
    views_list.append(generate_page_score())

    views_list.append(load_json(mid_session_json))

    views_list.extend(generate_task(easy_tasks[1], condition, time_strong, display_is_training=False, activate_feedback_answer=False,
                                   is_new_question=True, view_id_prefix="mainexp_easy2_patrot", score_page=False,
                                   pattern_id=rules_data_M[1]["pattern_id"]))
    views_list.extend(generate_end_of_session_questionnaire(condition, view_id_prefix="mainexp_easy_strong"))
    views_list.append(generate_page_score())
    return views_list

def generate_session_hard(difficult_tasks, condition, time_mild, time_strong, mid_session_json):
    views_list = []
    views_list.extend(generate_task(difficult_tasks[0], condition, time_mild, display_is_training=False, activate_feedback_answer=False,
                                   is_new_question=True, view_id_prefix="mainexp_hard1_patrot", score_page=False,
                                   pattern_id=rules_data_L[0]["pattern_id"]))

    views_list.extend(generate_end_of_session_questionnaire(condition, view_id_prefix="mainexp_hard_mild"))
    views_list.append(generate_page_score())

    views_list.append(load_json(mid_session_json))

    views_list.extend(generate_task(difficult_tasks[1], condition, time_strong, display_is_training=False, activate_feedback_answer=False,
                                   is_new_question=True, view_id_prefix="mainexp_hard2_patrot", score_page=False,
                                   pattern_id=rules_data_L[1]["pattern_id"]))

    views_list.extend(generate_end_of_session_questionnaire(condition, view_id_prefix="mainexp_hard_strong"))
    views_list.append(generate_page_score())
    return views_list

def create_protocol_json(condition, intro_tasks, compr_test_tasks, easy_tasks, difficult_tasks, time_mild, time_strong, time_training):
    """
    :param condition: Either "H", "AI", "XAI_SHAP", "XAI_CF", "XAI_LLM"
    :return:
    """
    full_list = []

    full_list.append(load_json(JSON_PATH_CONSENT_FORM))
    full_list.append(load_json(JSON_PATH_INTRO_DISCOVERY_FORM))
    full_list.append(load_json(JSON_PATH_INTRO_PATTERN_TASK_FORM))
    full_list.append(load_json(JSON_PATH_INTRO_PAGE_ADJUSTMENT_FORM))

    full_list.extend(generate_task(intro_tasks[0], "H", -1, display_is_training=True, activate_feedback_answer=True, score_page=True,
                                   is_new_question=True, view_id_prefix="intro_discovery", pattern_id=rules_data_S[0]["pattern_id"]))

    full_list.append(load_json(JSON_PATH_INTRO_FURTHER_INFO_FORM))
    full_list.append(load_json(JSON_PATH_INTRO_COMPREHENSION_INTRO))

    full_list.extend(generate_task(compr_test_tasks[0], "H", -1, display_is_training=False, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="intro_comprehension", pattern_id=rules_data_XS[0]["pattern_id"]))

    if condition == "AI":
        full_list.append(load_json(JSON_PATH_INSTRUCTIONS_AI_FORM))
    elif condition == "XAI_SHAP":
        full_list.append(load_json(JSON_PATH_INSTRUCTIONS_XAI_SHAP_FORM))
    elif condition == "XAI_CF":
        full_list.append(load_json(JSON_PATH_INSTRUCTIONS_XAI_CF_FORM))
    # elif condition == "XAI_LLM":
    #     full_list.append(load_json(JSON_PATH_INSTRUCTIONS_XAI_LLM_FORM))

    if "AI" in condition:
        full_list.append(load_json(JSON_PATH_INTRO_MAIN_TRAINING_AI))
    else:
        full_list.append(load_json(JSON_PATH_INTRO_MAIN_TRAINING))

    full_list.extend(generate_task(intro_tasks[1], condition, time_training, display_is_training=True, activate_feedback_answer=False, score_page=True,
                                   is_new_question=True, view_id_prefix="intro_training_1", pattern_id=rules_data_S[1]["pattern_id"]))

    first_difficulty = np.random.choice(["easy", "hard"])
    print(first_difficulty)

    # Session 1
    full_list.append(load_json(JSON_PATH_MAIN_EXP_START))
    full_list.append(load_json(JSON_PATH_SESSION_1_INTRO))
    if first_difficulty == "easy":
        full_list.extend(generate_session_easy(easy_tasks, condition, time_mild, time_strong, mid_session_json=JSON_PATH_SESSION_1_PART2))
    else:
        full_list.extend(generate_session_hard(difficult_tasks, condition, time_mild, time_strong, mid_session_json=JSON_PATH_SESSION_1_PART2))
    full_list.append(load_json(JSON_PATH_ATTENTIONCHECK1, set_id="attentioncheck_1"))
    full_list.append(load_json(JSON_PATH_SESSION_1_END))

    # Session 2
    full_list.append(load_json(JSON_PATH_SESSION_2_INTRO))
    if first_difficulty == "easy":
        full_list.extend(generate_session_hard(difficult_tasks, condition, time_mild, time_strong, mid_session_json=JSON_PATH_SESSION_2_PART2))
    else:
        full_list.extend(generate_session_easy(easy_tasks, condition, time_mild, time_strong, mid_session_json=JSON_PATH_SESSION_2_PART2))
    full_list.append(load_json(JSON_PATH_SESSION_2_END))


    # full_list.append(load_json(JSON_PATH_FINAL_QUEST_NFC, set_id="closing_quest_nfc"))
    if "XAI" in condition:
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_INTRO))
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_TRUST_XAI_1, set_id="closing_quest_trust_1"))
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_TRUST_XAI_2, set_id="closing_quest_trust_2"))
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_JUSTIF_USE_XAI, set_id="closing_quest_use_xai"))
        full_list.append(load_json(JSON_PATH_ATTENTIONCHECK2, set_id="attentioncheck_2"))
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_STRATEGY, set_id="closing_quest_strategy"))

    elif "AI" in condition:
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_INTRO))
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_TRUST_AI_1, set_id="closing_quest_trust_1"))
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_TRUST_AI_2, set_id="closing_quest_trust_2"))
        full_list.append(load_json(JSON_PATH_ATTENTIONCHECK2))
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_STRATEGY, set_id="closing_quest_strategy"))
    else:
        full_list.append(load_json(JSON_PATH_ATTENTIONCHECK2, set_id="attentioncheck2"))
        full_list.append(load_json(JSON_PATH_FINAL_QUEST_NOAI_NOQUEST))
    #
    # full_list.append(load_json(JSON_PATH_END_SCORE))
    # full_list.append(generate_page_score(final_score=True))
    full_list.append(load_json(JSON_PATH_END_LEAVE))
    return full_list

# %%
import shutil
import json


def deploy(output_json_dir, output_assets_dir):

    protocols_path = os.path.join(output_json_dir, "protocols")
    users_path = os.path.join(output_json_dir, "users.json")
    assets_output_path = os.path.join(output_assets_dir, "res")

    # Removing former installation
    shutil.rmtree(protocols_path, ignore_errors=True)
    try:
        os.remove(users_path)
    except FileNotFoundError:
        pass

    os.makedirs(protocols_path)

    users_json = {}
    for condition in CONDITIONS:
        for protocol_idx in range(N_PROTOCOL_FILES[condition]):
            # Writing of JSON protocol files
            protocol_json = create_protocol_json(condition, INTRO_TASKS, COMPREHENSION_TEST_TASKS, EASY_TASKS, DIFFICULT_TASKS, TIME_MILD, TIME_STRONG, TIME_TRAINING)
            protocol_filename = condition+f"_{protocol_idx}.json"
            with open(os.path.join(protocols_path, protocol_filename), 'w') as f:
                json.dump(protocol_json, f, indent=4)
            users_json[f"{condition}_{protocol_idx}"] = {"roles": "user", "protocol": protocol_filename}

    with open(users_path, 'w') as f:
        json.dump(users_json, f, indent=4)

    # Copy assets
    shutil.rmtree(assets_output_path, ignore_errors=True)
    shutil.copytree(os.path.join(interface_dir, "res"), assets_output_path)

# %%
deploy(output_json_dir, output_assets_dir)
# Out:
# easy
# easy
# hard
# hard
# hard
# hard
# easy
# easy
# easy
# easy
# hard
# easy
# hard
# easy
# easy
# easy
# easy
# easy
# easy
# easy
# easy
# easy
# easy
# hard
# easy
# hard
# easy
# easy
# easy
# hard
# easy
# easy
# hard
# easy
# easy
# hard
# hard

# %%
treatments = ["H", "AI", "SHAP", "LLM", "CF", "CF"]

# %%
import numpy as np
np.random.choice(treatments, replace=False, size=6)
# Out:
# array(['CF', 'LLM', 'H', 'SHAP', 'CF', 'AI'], dtype='<U4')

# %%
import secrets
import string

def generate_id(length=8):
    alphabet = string.ascii_letters + string.digits
    return ''.join(secrets.choice(alphabet) for _ in range(length))

# Example
for i in range(10):
    print(generate_id().lower())
# Out:
# msbvnp3o
# zjsjtgh2
# yoyljjqk
# tl3mxbt2
# meofaqri
# xfeiw6l4
# bdwqx7zt
# ab20bide
# kjrubhfg
# sxh03qis

# %%
import secrets
import string

def generate_id(length=8):
    alphabet = string.ascii_letters + string.digits
    return ''.join(secrets.choice(alphabet) for _ in range(length))

# Example
for i in range(50):
    print("aa"+generate_id().lower())
# Out:
# aaxwikkttt
# aagpztsbic
# aar1dlwwd8
# aavurp9rj6
# aapeodagzf
# aatm7tnss0
# aaw4wfkprs
# aaecn7gltl
# aahqjzybmc
# aa8awp5st9
# aahoyduigy
# aazytjr4o8
# aakwqfotd3
# aa0dizxo7r
# aadfigesz0
# aa0xc6uzkp
# aazcamuf43
# aaeq0entmo
# aa7nyrpde1
# aab30iwcnh
# aaktx125wj
# aazuosgz8s
# aab5dqf6a4
# aadwrixyhd
# aa4r3v4tas
# aal9ayt5z3
# aaib3c9usz
# aa1yv4gxk3
# aat2nauybl
# aac7bq8d83
# aazhv1lbjv
# aacocksqzn
# aahe3vfjr5
# aaoiskwkom
# aae6pqbhdy
# aatebbtecm
# aazpel1hfk
# aabrxj6k09
# aar6rwfkhc
# aaa85ksa0y
# aashwiujhr
# aazjd7yont
# aaailrpp4q
# aaha009pg0
# aaysdgbazg
# aabkyhatoi
# aae3eu3rav
# aadk0ecapl
# aacwg5vzww
# aa7gwb2vzk

# %%
import secrets
import secrets
import string

def generate_id(length=8):
    alphabet = string.ascii_letters + string.digits
    return ''.join(secrets.choice(alphabet) for _ in range(length))

# Example
for i in range(70):
    print("bb"+generate_id().lower())
# Out:
# bbxn7gonma
# bbek1v27km
# bbbmxgetmz
# bbsqrusmni
# bbnqxdh17t
# bbhmjojfnu
# bbbl2l7vbf
# bbpwjspild
# bbcquclmmj
# bbssrbmazy
# bboce1h83v
# bb58rme9pu
# bbd4xhf8tj
# bbjwy8xqqi
# bbig8rry2a
# bbtwaqdhmq
# bbywzxf3kq
# bbhgbleidh
# bbycco68df
# bbznqttwgt
# bbmyt5w4xu
# bbsm0qhurp
# bbltqvrq0s
# bb6p6pxheb
# bb6xyrzwia
# bbzqzrxrqq
# bbgn30jdm1
# bbw6yun7ur
# bb86luxeip
# bbbft9zjvx
# bb1i2ifngc
# bbgiwjkjpu
# bbga8gqog5
# bbzpf15pf3
# bbana2ufia
# bb7ftnpxrr
# bbclijw59f
# bbxsreprcr
# bbqsu8gf9h
# bb9ucogrw3
# bbigssblwi
# bb7hnpn5ys
# bblzdrr7vs
# bbc32pflkk
# bboijkos8z
# bbrugf22ab
# bbo2pefmxn
# bbwmlilzsp
# bbuuyjotw4
# bbfjfm0vbd
# bbihkoniyc
# bbofl1lufi
# bb11cskp67
# bbv5hzeoq2
# bbcsjpitnc
# bbukg36rak
# bbnqrfflvm
# bbloai6eub
# bb6gi8fpjp
# bb3vgqzo3s
# bbxuze3nd4
# bbvngy53mt
# bbtzczuamc
# bbrxidu0mx
# bblil5wdbo
# bby5252a9k
# bbr1xvvslo
# bbzdo5cun7
# bby4wepcyl
# bbtfffrdk3

# %%
pattern_3sym_2col_keys[3]
# Out:
# '140fce94d25511f088b412a439d55952'
