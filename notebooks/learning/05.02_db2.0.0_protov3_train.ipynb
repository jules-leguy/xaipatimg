# %%
import os

db_dir = os.environ["DATA"] + "PatImgXAI_data/db2.0.0/"
model_dir_root = os.environ["DATA"] + "models/db2.0.0/02_protov3/"
datasets_dir = os.environ["DATA"] + "PatImgXAI_data/db2.0.0/datasets/02_protov3/"
devices = ["cuda:0", "cuda:1"]
INTERVAL_BATCH = 1

# %%
# Number of images generated
NBGEN = 1000000

# Grid division of each image
X_DIVISIONS = 6
Y_DIVISIONS = 6

# Size of the images in pixels
img_size = (700, 700)

# Probability to generate a geometrical shape at each position in the grid
SHAPE_PROB = 0.5

# Define available shapes
SHAPES = ['circle', 'square', 'triangle']
COLORS  = ["#A33E9A", "#E0B000", "#0C90C0"]

# %%
from xaipatimg.datagen.gendataset import generic_rule_exist_row_with_only_shape, generic_rule_N_times_color_exactly, \
    generic_rule_shape_color_plus_shape_equals_N, generic_rule_shape_in_every_row, generic_rule_shape_color_times_2_shape_equals_shape

rules_data = [
    # {"name": "disc_1_triangle_all", "gen_fun": generic_rule_shape_in_every_row, "gen_kwargs": {"shape": "triangle", "y_division": Y_DIVISIONS}, "question": "In the image, is there a triangle in every row (1, ..., 6)?", "target_acc" : 1.0, "shown_acc" : 1.0, "samples_interface": 5, "pos_llm_scaffold": "The AI predicts |YES| because every row contains at least one triangle : \n - Row 1 : XX, XX, XX\n- Row 2 : XX, XX, XX\n- Row 3 : XX, XX, XX\n- Row 4 : XX, XX, XX\n- Row 5 : XX, XX, XX\n- Row 5 : XX, XX, XX", "neg_llm_scaffold": "The AI predicts |NO| because the rows X and X do not contain any triangle."},
    #
    # {"name": "disc_1_triangle_all_2", "gen_fun": generic_rule_shape_in_every_row, "gen_kwargs": {"shape": "triangle", "y_division": Y_DIVISIONS}, "question": "In the image, is there a triangle in every row (1, ..., 6)?", "target_acc" : 1.0, "shown_acc" : 1.0, "samples_interface": 5, "pos_llm_scaffold": "The AI predicts |YES| because every row contains at least one triangle : \n - Row 1 : XX, XX, XX\n- Row 2 : XX, XX, XX\n- Row 3 : XX, XX, XX\n- Row 4 : XX, XX, XX\n- Row 5 : XX, XX, XX\n- Row 5 : XX, XX, XX", "neg_llm_scaffold": "The AI predicts |NO| because the rows X and X do not contain any triangle."},
    #
    # {"name": "disc_1_triangle_all_3", "gen_fun": generic_rule_shape_in_every_row, "gen_kwargs": {"shape": "triangle", "y_division": Y_DIVISIONS}, "question": "In the image, is there a triangle in every row (1, ..., 6)?", "target_acc" : 1.0, "shown_acc" : 1.0, "samples_interface": 5, "pos_llm_scaffold": "The AI predicts |YES| because every row contains at least one triangle : \n - Row 1 : XX, XX, XX\n- Row 2 : XX, XX, XX\n- Row 3 : XX, XX, XX\n- Row 4 : XX, XX, XX\n- Row 5 : XX, XX, XX\n- Row 5 : XX, XX, XX", "neg_llm_scaffold": "The AI predicts |NO| because the rows X and X do not contain any triangle."},
    #
    #
    # {"name": "easy_1_6_blue", "gen_fun": generic_rule_N_times_color_exactly, "gen_kwargs": {"color": "#0C90C0", "N": 6, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}, "question": "In the image, are there exactly 6 blue symbols?", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because there is exactly 6 blue symbols, which are located at :\n- XX\n- XX\n- XX\n- XX\n- XX\n- XX", "neg_llm_scaffold": "The AI predicts |NO| because there is X blue symbols instead of 6. They are located at : \n- XX\n- XX\n- XX\n- XX\n- XX."},
    #
    # {"name": "easy_2_row_circle", "gen_fun": generic_rule_exist_row_with_only_shape, "gen_kwargs": {"shape": "circle", "y_division": Y_DIVISIONS},
    #  "question": "In the image, is there at least one row (1, ..., 6) containing only circles?", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because there is at least one row which contains only circles : \nRow X contains only circles which are located at XX, XX, XX", "neg_llm_scaffold": "The AI predicts |NO| because there is not a single row containing only circles :\nRow 1 contains a non-circle symbol at XX\nRow 2 contains non-circle symbols at XX, XX, XX.\nRow 3 does not contain any symbol at all\n ..."},
    #
    # {"name": "easy_3_7_purple", "gen_fun": generic_rule_N_times_color_exactly, "gen_kwargs": {"color": "#A33E9A", "N": 7, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}, "question": "In the image, are there exactly 7 purple symbols?", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because there is exactly 7 purple symbols, which are located at :\n- XX\n- XX\n- XX\n- XX\n- XX\n- XX\n- XX", "neg_llm_scaffold": "The AI predicts |NO| because there is X purple symbols instead of 7. They are located at : \n- XX\n- XX\n- XX\n- XX\n- XX\n- XX."},
    #
    # {"name": "easy_4_row_triangle", "gen_fun": generic_rule_exist_row_with_only_shape, "gen_kwargs": {"shape": "triangle", "y_division": Y_DIVISIONS},
    #  "question": "In the image, is there at least one row (1, ..., 6) containing only triangles?", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because there is at least one row which contains only triangles : \nRow X contains only triangles which are located at XX, XX, XX", "neg_llm_scaffold": "The AI predicts |NO| because there is not a single row containing only triangles :\nRow 1 contains a non-triangle symbol at XX\nRow 2 contains non-triangle symbols at XX, XX, XX.\nRow 3 does not contain any symbol at all\n ..."},
    #
    # {"name": "easy_5_5_yellow", "gen_fun": generic_rule_N_times_color_exactly, "gen_kwargs": {"color": "#E0B000", "N": 5, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}, "question": "In the image, are there exactly 5 yellow symbols?", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10,  "pos_llm_scaffold": "The AI predicts |YES| because there is exactly 5 yellow symbols, which are located at :\n- XX\n- XX\n- XX\n- XX\n- XX", "neg_llm_scaffold": "The AI predicts |NO| because there is X yellow symbols instead of 5, which are located at : \n- XX\n- XX\n- XX\n- XX\n- XX\n- XX."},
    #
    # {"name": "easy_6_row_square", "gen_fun": generic_rule_exist_row_with_only_shape, "gen_kwargs": {"shape": "square", "y_division": Y_DIVISIONS},
    #  "question": "In the image, is there at least one row (1, ..., 6) containing only squares?", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because there is at least one row which contains only squares : \nRow X contains only squares which are located at XX, XX, XX", "neg_llm_scaffold": "The AI predicts |NO| because there is not a single row containing only squares :\nRow 1 contains a non-square symbol at XX\nRow 2 contains non-square symbols at XX, XX, XX.\nRow 3 does not contain any symbol at all\n ..."},
    #
    #
    # {"name": "hard_1_blue_square_plus_circle_8", "gen_fun": generic_rule_shape_color_plus_shape_equals_N, "gen_kwargs": {"color1": "#0C90C0", "shape1": "square", "shape2": "circle", "N": 8, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS,},
    #  "question": "In the image, does the number of blue squares plus (+) the number of circles equal to 8?", "question_llm": "In the image, does the number of blue squares plus (+) the number of circles of any color equal to 8", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because \n\n There is a total of X blue squares at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X circles at positions : \n- XX\n- XX\n- XX\n- XX\n\n X + X = 8", "neg_llm_scaffold": "The AI predicts |NO| because \n\n There is a total of X blue squares at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X circles at positions : \n- XX\n- XX\n- XX\n- XX\n X + X = X ≠ 8"},
    #
    # {"name": "hard_2_yellow_triangles_times2_squares", "gen_fun": generic_rule_shape_color_times_2_shape_equals_shape, "gen_kwargs": {"color1": "#E0B000", "shape1": "triangle", "shape2": "square", "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS,},
    #  "question": "In the image, does the number of yellow triangles multiplied by 2 (×2) equal to the number of squares?", "question_llm": "In the image, does the number of yellow triangles multiplied by 2 (×2) equal to the number of squares of any color ?", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because \n\n There is a total of X yellow triangles at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X squares at positions : \n- XX\n- XX\n- XX\n- XX\n\n X × 2 = X", "neg_llm_scaffold": "There is a total of X yellow triangles at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X squares at positions : \n- XX\n- XX\n- XX\n- XX\n\n X × 2 = X ≠ X"},
    #
    # {"name": "hard_3_yellow_circle_plus_triangle_9", "gen_fun": generic_rule_shape_color_plus_shape_equals_N, "gen_kwargs": {"color1": "#E0B000", "shape1": "circle", "shape2": "triangle", "N": 9, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS},
    #  "question": "In the image, does the number of yellow circles plus (+) the number of triangles equal to 9?",
    #  "question_llm": "In the image, does the number of yellow circles plus (+) the number of triangles of any color equal to 9?","target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because \n\n There is a total of X yellow circles at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X triangles at positions : \n- XX\n- XX\n- XX\n- XX\n\n X + X = 9", "neg_llm_scaffold": "The AI predicts |NO| because \n\n There is a total of X yellow circles at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X triangles at positions : \n- XX\n- XX\n- XX\n- XX\n X + X = X ≠ 9"},
    # #
    # {"name": "hard_4_purple_squares_times2_circles", "gen_fun": generic_rule_shape_color_times_2_shape_equals_shape, "gen_kwargs": {"color1": "#A33E9A", "shape1": "square", "shape2": "circle", "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS,},
    #  "question": "In the image, does the number of purple squares multiplied by 2 (×2) equal to the number of circles?",
    #  "question_llm": "In the image, does the number of purple squares multiplied by 2 (×2) equal to the number of circles of any color?", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because \n\n There is a total of X purple squares at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X circles at positions : \n- XX\n- XX\n- XX\n- XX\n\n X × 2 = X", "neg_llm_scaffold": "There is a total of X purple squares at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X circles at positions : \n- XX\n- XX\n- XX\n- XX\n\n X × 2 = X ≠ X"},
    #
    # {"name": "hard_5_purple_triangle_plus_square_7", "gen_fun": generic_rule_shape_color_plus_shape_equals_N, "gen_kwargs": {"color1": "#A33E9A", "shape1": "triangle", "shape2": "square", "N": 7, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS},
    #  "question": "In the image, does the number of purple triangles plus (+) the number of squares equal to 7?",
    #  "question_llm": "In the image, does the number of purple triangles plus (+) the number of squares of any color equal to 7?", "target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because \n\n There is a total of X purple triangles at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X squares at positions : \n- XX\n- XX\n- XX\n- XX\n\n X + X = 7", "neg_llm_scaffold": "The AI predicts |NO| because \n\n There is a total of X purple triangles at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X squares at positions : \n- XX\n- XX\n- XX\n- XX\n X + X = X ≠ 7"},

    {"name": "hard_6_blue_circles_times2_triangles", "gen_fun": generic_rule_shape_color_times_2_shape_equals_shape, "gen_kwargs": {"color1": "#0C90C0", "shape1": "circle", "shape2": "triangle", "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS,},
     "question": "In the image, does the number of blue circles multiplied by 2 (×2) equal to the number of triangles?", "question_llm": "In the image, does the number of blue circles multiplied by 2 (×2) equal to the number of triangles of any color?","target_acc": 0.9, "shown_acc": 0.8, "samples_interface": 10, "pos_llm_scaffold": "The AI predicts |YES| because \n\n There is a total of X blue circles at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X triangles at positions : \n- XX\n- XX\n- XX\n- XX\n\n X × 2 = X", "neg_llm_scaffold": "There is a total of X blue circles at positions : \n- XX\n- XX\n- XX\n- XX\n \nThere is a total of X triangles at positions : \n- XX\n- XX\n- XX\n- XX\n\n X × 2 = X ≠ X"},
]

# %%
from xaipatimg.ml.learning import train_resnet18_model, compute_resnet18_model_scores


def _train_model(db_dir, datasets_dir_path, train_dataset_filename, valid_dataset_filename, test_dataset_filename, model_dir, target_accuracy, interval_batch, device):
    train_resnet18_model(db_dir, datasets_dir_path, train_dataset_filename, valid_dataset_filename, model_dir, target_accuracy=target_accuracy,
                         interval_batch=interval_batch, device=device)
    compute_resnet18_model_scores(db_dir, datasets_dir_path, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)

# %%
from tqdm import tqdm
from joblib import Parallel, delayed

for rule_idx in tqdm(range(0, len(rules_data), 2)):

    if rule_idx + 1 == len(rules_data):
        offsets = [0]
    else:
        offsets = [0, 1]

    Parallel(n_jobs=len(devices))(delayed(_train_model)(
        db_dir, # db_dir
        datasets_dir,
        rules_data[rule_idx + offset]["name"] + "_train.csv", # train_dataset_filename
        rules_data[rule_idx + offset]["name"] + "_valid.csv", # valid_dataset_filename
        rules_data[rule_idx + offset]["name"] + "_test.csv", # test_dataset_filename
        os.path.join(model_dir_root, rules_data[rule_idx + offset]["name"]), # model_dir
        rules_data[rule_idx + offset]["target_acc"], # target_accuracy,
        INTERVAL_BATCH if rules_data[rule_idx + offset]["target_acc"] < 1.0 else 50, # interval_batch (higher if the target accuracy is the best possible performance)
        devices[offset]) for offset in offsets)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset content for hard_6_blue_circles_times2_triangles_train.csv
# 100%|██████████| 8000/8000 [01:48<00:00, 74.07it/s]
# Train dataset statistics : [0.9429498314857483, 0.9417825937271118, 0.9383774399757385] [0.1690707802772522, 0.15095970034599304, 0.17640256881713867]
# Loading dataset content for hard_6_blue_circles_times2_triangles_train.csv
#  51%|█████     | 4062/8000 [00:41<00:38, 102.44it/s]
# LOSS train 0.7032 valid 0.7295
# Accuracy cap NOT hit at Step 76 : 0.508 < 0.9
# LOSS train 0.7657 valid 0.7182
# Accuracy cap NOT hit at Step 77 : 0.51 < 0.9
# LOSS train 0.7584 valid 0.7044
# Accuracy cap NOT hit at Step 78 : 0.505 < 0.9
# LOSS train 0.6808 valid 0.6993
# Accuracy cap NOT hit at Step 79 : 0.495 < 0.9
# LOSS train 0.6756 valid 0.7041
# Accuracy cap NOT hit at Step 80 : 0.5 < 0.9
# LOSS train 0.7012 valid 0.7173
# Accuracy cap NOT hit at Step 81 : 0.5 < 0.9
# LOSS train 0.7272 valid 0.7230
# Accuracy cap NOT hit at Step 82 : 0.5 < 0.9
# LOSS train 0.7456 valid 0.7150
# Accuracy cap NOT hit at Step 83 : 0.5 < 0.9
# LOSS train 0.6650 valid 0.7092
# Accuracy cap NOT hit at Step 84 : 0.5 < 0.9
# LOSS train 0.7172 valid 0.6974
# Accuracy cap NOT hit at Step 85 : 0.5 < 0.9
# LOSS train 0.7173 valid 0.6938
# Accuracy cap NOT hit at Step 86 : 0.518 < 0.9
# LOSS train 0.6783 valid 0.7123
# Accuracy cap NOT hit at Step 87 : 0.561 < 0.9
# LOSS train 0.7426 valid 0.7326
# Accuracy cap NOT hit at Step 88 : 0.548 < 0.9
# LOSS train 0.6830 valid 0.7526
# Accuracy cap NOT hit at Step 89 : 0.535 < 0.9
# LOSS train 0.6948 valid 0.7671
# Accuracy cap NOT hit at Step 90 : 0.56 < 0.9
# LOSS train 0.7427 valid 0.7624
# Accuracy cap NOT hit at Step 91 : 0.549 < 0.9
# LOSS train 0.7121 valid 0.7627
# Accuracy cap NOT hit at Step 92 : 0.523 < 0.9
# LOSS train 0.7833 valid 0.7477
# Accuracy cap NOT hit at Step 93 : 0.526 < 0.9
# LOSS train 0.8090 valid 0.7144
# Accuracy cap NOT hit at Step 94 : 0.509 < 0.9
# LOSS train 0.7286 valid 0.7069
# Accuracy cap NOT hit at Step 95 : 0.499 < 0.9
# LOSS train 0.7295 valid 0.7288
# Accuracy cap NOT hit at Step 96 : 0.5 < 0.9
# LOSS train 0.7019 valid 0.7614
# Accuracy cap NOT hit at Step 97 : 0.5 < 0.9
# LOSS train 0.7329 valid 0.7724
# Accuracy cap NOT hit at Step 98 : 0.5 < 0.9
# LOSS train 0.7533 valid 0.7564
# Accuracy cap NOT hit at Step 99 : 0.5 < 0.9
# LOSS train 0.7118 valid 0.7373
# Accuracy cap NOT hit at Step 100 : 0.504 < 0.9
# LOSS train 0.7310 valid 0.7176
# Accuracy cap NOT hit at Step 101 : 0.553 < 0.9
# LOSS train 0.7116 valid 0.7003
# Accuracy cap NOT hit at Step 102 : 0.517 < 0.9
# LOSS train 0.6960 valid 0.6943
# Accuracy cap NOT hit at Step 103 : 0.495 < 0.9
# LOSS train 0.7121 valid 0.6993
# Accuracy cap NOT hit at Step 104 : 0.5 < 0.9
# LOSS train 0.7187 valid 0.7051
# Accuracy cap NOT hit at Step 105 : 0.5 < 0.9
# LOSS train 0.6975 valid 0.7079
# Accuracy cap NOT hit at Step 106 : 0.5 < 0.9
# LOSS train 0.6604 valid 0.7107
# Accuracy cap NOT hit at Step 107 : 0.5 < 0.9
# LOSS train 0.7007 valid 0.7110
# Accuracy cap NOT hit at Step 108 : 0.504 < 0.9
# LOSS train 0.7336 valid 0.7079
# Accuracy cap NOT hit at Step 109 : 0.544 < 0.9
# LOSS train 0.6942 valid 0.7046
# Accuracy cap NOT hit at Step 110 : 0.57 < 0.9
# LOSS train 0.6598 valid 0.7048
# Accuracy cap NOT hit at Step 111 : 0.552 < 0.9
# LOSS train 0.7861 valid 0.6977
# Accuracy cap NOT hit at Step 112 : 0.522 < 0.9
# LOSS train 0.6688 valid 0.6973
# Accuracy cap NOT hit at Step 113 : 0.526 < 0.9
# LOSS train 0.6785 valid 0.6986
# Accuracy cap NOT hit at Step 114 : 0.513 < 0.9
# LOSS train 0.7273 valid 0.6990
# Accuracy cap NOT hit at Step 115 : 0.505 < 0.9
# LOSS train 0.7026 valid 0.6980
# Accuracy cap NOT hit at Step 116 : 0.51 < 0.9
# LOSS train 0.6969 valid 0.6980
# Accuracy cap NOT hit at Step 117 : 0.518 < 0.9
# LOSS train 0.6670 valid 0.6989
# Accuracy cap NOT hit at Step 118 : 0.524 < 0.9
# LOSS train 0.7258 valid 0.6982
# Accuracy cap NOT hit at Step 119 : 0.527 < 0.9
# LOSS train 0.7748 valid 0.6941
# Accuracy cap NOT hit at Step 120 : 0.528 < 0.9
# LOSS train 0.6847 valid 0.6920
# Accuracy cap NOT hit at Step 121 : 0.531 < 0.9
# LOSS train 0.6934 valid 0.6902
# Accuracy cap NOT hit at Step 122 : 0.532 < 0.9
# LOSS train 0.6918 valid 0.6891
# Accuracy cap NOT hit at Step 123 : 0.549 < 0.9
# LOSS train 0.7017 valid 0.6889
# Accuracy cap NOT hit at Step 124 : 0.553 < 0.9
# LOSS train 0.6916 valid 0.6898
# Accuracy cap NOT hit at Step 125 : 0.567 < 0.9
# LOSS train 0.6903 valid 0.6909
# Accuracy cap NOT hit at Step 126 : 0.535 < 0.9
# LOSS train 0.6785 valid 0.6922
# Accuracy cap NOT hit at Step 127 : 0.507 < 0.9
# LOSS train 0.6709 valid 0.6948
# Accuracy cap NOT hit at Step 128 : 0.501 < 0.9
# LOSS train 0.6841 valid 0.6978
# Accuracy cap NOT hit at Step 129 : 0.5 < 0.9
# LOSS train 0.7017 valid 0.6989
# Accuracy cap NOT hit at Step 130 : 0.5 < 0.9
# LOSS train 0.7101 valid 0.6996
# Accuracy cap NOT hit at Step 131 : 0.5 < 0.9
# LOSS train 0.7290 valid 0.6977
# Accuracy cap NOT hit at Step 132 : 0.496 < 0.9
# LOSS train 0.6480 valid 0.6988
# Accuracy cap NOT hit at Step 133 : 0.501 < 0.9
# LOSS train 0.7123 valid 0.6989
# Accuracy cap NOT hit at Step 134 : 0.5 < 0.9
# LOSS train 0.6829 valid 0.6989
# Accuracy cap NOT hit at Step 135 : 0.5 < 0.9
# LOSS train 0.7159 valid 0.6972
# Accuracy cap NOT hit at Step 136 : 0.5 < 0.9
# LOSS train 0.6985 valid 0.6948
# Accuracy cap NOT hit at Step 137 : 0.499 < 0.9
# LOSS train 0.6483 valid 0.6938
# Accuracy cap NOT hit at Step 138 : 0.504 < 0.9
# LOSS train 0.7012 valid 0.6921
# Accuracy cap NOT hit at Step 139 : 0.523 < 0.9
# LOSS train 0.7252 valid 0.6891
# Accuracy cap NOT hit at Step 140 : 0.561 < 0.9
# LOSS train 0.6921 valid 0.6883
# Accuracy cap NOT hit at Step 141 : 0.55 < 0.9
# LOSS train 0.7009 valid 0.6907
# Accuracy cap NOT hit at Step 142 : 0.515 < 0.9
# LOSS train 0.6781 valid 0.6950
# Accuracy cap NOT hit at Step 143 : 0.495 < 0.9
# LOSS train 0.7062 valid 0.6969
# Accuracy cap NOT hit at Step 144 : 0.5 < 0.9
# LOSS train 0.7097 valid 0.6934
# Accuracy cap NOT hit at Step 145 : 0.506 < 0.9
# LOSS train 0.6770 valid 0.6906
# Accuracy cap NOT hit at Step 146 : 0.498 < 0.9
# LOSS train 0.7157 valid 0.6899
# Accuracy cap NOT hit at Step 147 : 0.525 < 0.9
# LOSS train 0.6954 valid 0.6928
# Accuracy cap NOT hit at Step 148 : 0.532 < 0.9
# LOSS train 0.6516 valid 0.7002
# Accuracy cap NOT hit at Step 149 : 0.53 < 0.9
# LOSS train 0.7164 valid 0.7079
# Accuracy cap NOT hit at Step 150 : 0.532 < 0.9
# LOSS train 0.7373 valid 0.7118
# Accuracy cap NOT hit at Step 151 : 0.535 < 0.9
# LOSS train 0.7039 valid 0.7126
# Accuracy cap NOT hit at Step 152 : 0.535 < 0.9
# LOSS train 0.7091 valid 0.7069
# Accuracy cap NOT hit at Step 153 : 0.53 < 0.9
# LOSS train 0.7279 valid 0.7003
# Accuracy cap NOT hit at Step 154 : 0.534 < 0.9
# LOSS train 0.6814 valid 0.6948
# Accuracy cap NOT hit at Step 155 : 0.536 < 0.9
# LOSS train 0.6687 valid 0.6904
# Accuracy cap NOT hit at Step 156 : 0.539 < 0.9
# LOSS train 0.6941 valid 0.6876
# Accuracy cap NOT hit at Step 157 : 0.543 < 0.9
# LOSS train 0.6821 valid 0.6866
# Accuracy cap NOT hit at Step 158 : 0.545 < 0.9
# LOSS train 0.7070 valid 0.6854
# Accuracy cap NOT hit at Step 159 : 0.568 < 0.9
# LOSS train 0.6701 valid 0.6853
# Accuracy cap NOT hit at Step 160 : 0.568 < 0.9
# LOSS train 0.6736 valid 0.6851
# Accuracy cap NOT hit at Step 161 : 0.567 < 0.9
# LOSS train 0.6766 valid 0.6870
# Accuracy cap NOT hit at Step 162 : 0.554 < 0.9
# LOSS train 0.6898 valid 0.6881
# Accuracy cap NOT hit at Step 163 : 0.555 < 0.9
# LOSS train 0.6800 valid 0.6954
# Accuracy cap NOT hit at Step 164 : 0.54 < 0.9
# LOSS train 0.6952 valid 0.7009
# Accuracy cap NOT hit at Step 165 : 0.52 < 0.9
# LOSS train 0.7022 valid 0.7053
# Accuracy cap NOT hit at Step 166 : 0.509 < 0.9
# LOSS train 0.7182 valid 0.7039
# Accuracy cap NOT hit at Step 167 : 0.513 < 0.9
# LOSS train 0.7037 valid 0.6985
# Accuracy cap NOT hit at Step 168 : 0.532 < 0.9
# LOSS train 0.7133 valid 0.6889
# Accuracy cap NOT hit at Step 169 : 0.548 < 0.9
# LOSS train 0.6750 valid 0.6848
# Accuracy cap NOT hit at Step 170 : 0.56 < 0.9
# LOSS train 0.7039 valid 0.6852
# Accuracy cap NOT hit at Step 171 : 0.565 < 0.9
# LOSS train 0.6777 valid 0.6907
# Accuracy cap NOT hit at Step 172 : 0.556 < 0.9
# LOSS train 0.7013 valid 0.6979
# Accuracy cap NOT hit at Step 173 : 0.544 < 0.9
# LOSS train 0.6851 valid 0.7009
# Accuracy cap NOT hit at Step 174 : 0.546 < 0.9
# LOSS train 0.6368 valid 0.7102
# Accuracy cap NOT hit at Step 175 : 0.541 < 0.9
# LOSS train 0.6473 valid 0.7327
# Accuracy cap NOT hit at Step 176 : 0.542 < 0.9
# LOSS train 0.7222 valid 0.7416
# Accuracy cap NOT hit at Step 177 : 0.531 < 0.9
# LOSS train 0.6702 valid 0.7481
# Accuracy cap NOT hit at Step 178 : 0.526 < 0.9
# LOSS train 0.6488 valid 0.7513
# Accuracy cap NOT hit at Step 179 : 0.525 < 0.9
# LOSS train 0.6792 valid 0.7461
# Accuracy cap NOT hit at Step 180 : 0.533 < 0.9
# LOSS train 0.6960 valid 0.7318
# Accuracy cap NOT hit at Step 181 : 0.54 < 0.9
# LOSS train 0.7458 valid 0.7060
# Accuracy cap NOT hit at Step 182 : 0.554 < 0.9
# LOSS train 0.6474 valid 0.6952
# Accuracy cap NOT hit at Step 183 : 0.573 < 0.9
# LOSS train 0.7382 valid 0.6840
# Accuracy cap NOT hit at Step 184 : 0.586 < 0.9
# LOSS train 0.7122 valid 0.6799
# Accuracy cap NOT hit at Step 185 : 0.563 < 0.9
# LOSS train 0.7058 valid 0.6833
# Accuracy cap NOT hit at Step 186 : 0.55 < 0.9
# LOSS train 0.6852 valid 0.6880
# Accuracy cap NOT hit at Step 187 : 0.521 < 0.9
# LOSS train 0.6959 valid 0.6912
# Accuracy cap NOT hit at Step 188 : 0.518 < 0.9
# LOSS train 0.6779 valid 0.6981
# Accuracy cap NOT hit at Step 189 : 0.51 < 0.9
# LOSS train 0.7825 valid 0.6984
# Accuracy cap NOT hit at Step 190 : 0.51 < 0.9
# LOSS train 0.6961 valid 0.6922
# Accuracy cap NOT hit at Step 191 : 0.519 < 0.9
# LOSS train 0.7232 valid 0.6860
# Accuracy cap NOT hit at Step 192 : 0.523 < 0.9
# LOSS train 0.6244 valid 0.6840
# Accuracy cap NOT hit at Step 193 : 0.536 < 0.9
# LOSS train 0.6521 valid 0.6816
# Accuracy cap NOT hit at Step 194 : 0.551 < 0.9
# LOSS train 0.6568 valid 0.6797
# Accuracy cap NOT hit at Step 195 : 0.556 < 0.9
# LOSS train 0.6866 valid 0.6786
# Accuracy cap NOT hit at Step 196 : 0.559 < 0.9
# LOSS train 0.6733 valid 0.6852
# Accuracy cap NOT hit at Step 197 : 0.576 < 0.9
# LOSS train 0.6684 valid 0.6984
# Accuracy cap NOT hit at Step 198 : 0.589 < 0.9
# LOSS train 0.7085 valid 0.7089
# Accuracy cap NOT hit at Step 199 : 0.584 < 0.9
# LOSS train 0.6984 valid 0.7327
# Accuracy cap NOT hit at Step 200 : 0.578 < 0.9
# LOSS train 0.7454 valid 0.7409
# Accuracy cap NOT hit at Step 201 : 0.558 < 0.9
# LOSS train 0.7437 valid 0.7397
# Accuracy cap NOT hit at Step 202 : 0.558 < 0.9
# LOSS train 0.7422 valid 0.7253
# Accuracy cap NOT hit at Step 203 : 0.559 < 0.9
# LOSS train 0.6707 valid 0.7122
# Accuracy cap NOT hit at Step 204 : 0.56 < 0.9
# LOSS train 0.6370 valid 0.7069
# Accuracy cap NOT hit at Step 205 : 0.56 < 0.9
# LOSS train 0.7508 valid 0.6927
# Accuracy cap NOT hit at Step 206 : 0.565 < 0.9
# LOSS train 0.6633 valid 0.6856
# Accuracy cap NOT hit at Step 207 : 0.575 < 0.9
# LOSS train 0.6751 valid 0.6824
# Accuracy cap NOT hit at Step 208 : 0.582 < 0.9
# LOSS train 0.6752 valid 0.6804
# Accuracy cap NOT hit at Step 209 : 0.587 < 0.9
# LOSS train 0.6684 valid 0.6793
# Accuracy cap NOT hit at Step 210 : 0.58 < 0.9
# LOSS train 0.6622 valid 0.6801
# Accuracy cap NOT hit at Step 211 : 0.562 < 0.9
# LOSS train 0.6930 valid 0.6841
# Accuracy cap NOT hit at Step 212 : 0.526 < 0.9
# LOSS train 0.6657 valid 0.6900
# Accuracy cap NOT hit at Step 213 : 0.514 < 0.9
# LOSS train 0.6471 valid 0.6962
# Accuracy cap NOT hit at Step 214 : 0.508 < 0.9
# LOSS train 0.6500 valid 0.7073
# Accuracy cap NOT hit at Step 215 : 0.504 < 0.9
# LOSS train 0.6441 valid 0.7179
# Accuracy cap NOT hit at Step 216 : 0.498 < 0.9
# LOSS train 0.6789 valid 0.7307
# Accuracy cap NOT hit at Step 217 : 0.498 < 0.9
# LOSS train 0.6725 valid 0.7427
# Accuracy cap NOT hit at Step 218 : 0.498 < 0.9
# LOSS train 0.7895 valid 0.7378
# Accuracy cap NOT hit at Step 219 : 0.498 < 0.9
# LOSS train 0.7441 valid 0.7270
# Accuracy cap NOT hit at Step 220 : 0.497 < 0.9
# LOSS train 0.6328 valid 0.7179
# Accuracy cap NOT hit at Step 221 : 0.5 < 0.9
# LOSS train 0.7126 valid 0.7064
# Accuracy cap NOT hit at Step 222 : 0.502 < 0.9
# LOSS train 0.5994 valid 0.6964
# Accuracy cap NOT hit at Step 223 : 0.512 < 0.9
# LOSS train 0.7725 valid 0.6850
# Accuracy cap NOT hit at Step 224 : 0.527 < 0.9
# LOSS train 0.7126 valid 0.6778
# Accuracy cap NOT hit at Step 225 : 0.561 < 0.9
# LOSS train 0.6861 valid 0.6794
# Accuracy cap NOT hit at Step 226 : 0.584 < 0.9
# LOSS train 0.6650 valid 0.6877
# Accuracy cap NOT hit at Step 227 : 0.572 < 0.9
# LOSS train 0.6934 valid 0.6978
# Accuracy cap NOT hit at Step 228 : 0.556 < 0.9
# LOSS train 0.7936 valid 0.6994
# Accuracy cap NOT hit at Step 229 : 0.545 < 0.9
# LOSS train 0.6813 valid 0.6943
# Accuracy cap NOT hit at Step 230 : 0.559 < 0.9
# LOSS train 0.6890 valid 0.6889
# Accuracy cap NOT hit at Step 231 : 0.566 < 0.9
# LOSS train 0.7264 valid 0.6825
# Accuracy cap NOT hit at Step 232 : 0.592 < 0.9
# LOSS train 0.7921 valid 0.6783
# Accuracy cap NOT hit at Step 233 : 0.578 < 0.9
# LOSS train 0.6654 valid 0.6804
# Accuracy cap NOT hit at Step 234 : 0.53 < 0.9
# LOSS train 0.6505 valid 0.6844
# Accuracy cap NOT hit at Step 235 : 0.513 < 0.9
# LOSS train 0.6701 valid 0.6937
# Accuracy cap NOT hit at Step 236 : 0.502 < 0.9
# LOSS train 0.6686 valid 0.6978
# Accuracy cap NOT hit at Step 237 : 0.501 < 0.9
# LOSS train 0.7015 valid 0.7001
# Accuracy cap NOT hit at Step 238 : 0.501 < 0.9
# LOSS train 0.6901 valid 0.7004
# Accuracy cap NOT hit at Step 239 : 0.502 < 0.9
# LOSS train 0.7185 valid 0.6920
# Accuracy cap NOT hit at Step 240 : 0.5 < 0.9
# LOSS train 0.6941 valid 0.6851
# Accuracy cap NOT hit at Step 241 : 0.527 < 0.9
# LOSS train 0.7054 valid 0.6802
# Accuracy cap NOT hit at Step 242 : 0.543 < 0.9
# LOSS train 0.6643 valid 0.6795
# Accuracy cap NOT hit at Step 243 : 0.581 < 0.9
# LOSS train 0.6911 valid 0.6798
# Accuracy cap NOT hit at Step 244 : 0.588 < 0.9
# LOSS train 0.7270 valid 0.6802
# Accuracy cap NOT hit at Step 245 : 0.587 < 0.9
# LOSS train 0.7142 valid 0.6794
# Accuracy cap NOT hit at Step 246 : 0.587 < 0.9
# LOSS train 0.7038 valid 0.6786
# Accuracy cap NOT hit at Step 247 : 0.577 < 0.9
# LOSS train 0.6888 valid 0.6786
# Accuracy cap NOT hit at Step 248 : 0.554 < 0.9
# LOSS train 0.7000 valid 0.6791
# Accuracy cap NOT hit at Step 249 : 0.535 < 0.9
# LOSS train 0.6677 valid 0.6806
# Accuracy cap NOT hit at Step 250 : 0.539 < 0.9
# EPOCH 2:
# LOSS train 0.6587 valid 0.6823
# Accuracy cap NOT hit at Step 251 : 0.532 < 0.9
# LOSS train 0.7447 valid 0.6844
# Accuracy cap NOT hit at Step 252 : 0.536 < 0.9
# LOSS train 0.6963 valid 0.6848
# Accuracy cap NOT hit at Step 253 : 0.537 < 0.9
# LOSS train 0.6699 valid 0.6852
# Accuracy cap NOT hit at Step 254 : 0.538 < 0.9
# LOSS train 0.6784 valid 0.6857
# Accuracy cap NOT hit at Step 255 : 0.537 < 0.9
# LOSS train 0.6832 valid 0.6849
# Accuracy cap NOT hit at Step 256 : 0.541 < 0.9
# LOSS train 0.7313 valid 0.6835
# Accuracy cap NOT hit at Step 257 : 0.537 < 0.9
# LOSS train 0.7104 valid 0.6820
# Accuracy cap NOT hit at Step 258 : 0.535 < 0.9
# LOSS train 0.6910 valid 0.6797
# Accuracy cap NOT hit at Step 259 : 0.537 < 0.9
# LOSS train 0.6607 valid 0.6784
# Accuracy cap NOT hit at Step 260 : 0.54 < 0.9
# LOSS train 0.6483 valid 0.6787
# Accuracy cap NOT hit at Step 261 : 0.524 < 0.9
# LOSS train 0.6475 valid 0.6802
# Accuracy cap NOT hit at Step 262 : 0.533 < 0.9
# LOSS train 0.7330 valid 0.6811
# Accuracy cap NOT hit at Step 263 : 0.524 < 0.9
# LOSS train 0.7294 valid 0.6795
# Accuracy cap NOT hit at Step 264 : 0.535 < 0.9
# LOSS train 0.6528 valid 0.6784
# Accuracy cap NOT hit at Step 265 : 0.541 < 0.9
# LOSS train 0.6884 valid 0.6771
# Accuracy cap NOT hit at Step 266 : 0.553 < 0.9
# LOSS train 0.6427 valid 0.6764
# Accuracy cap NOT hit at Step 267 : 0.562 < 0.9
# LOSS train 0.6757 valid 0.6761
# Accuracy cap NOT hit at Step 268 : 0.575 < 0.9
# LOSS train 0.6843 valid 0.6768
# Accuracy cap NOT hit at Step 269 : 0.571 < 0.9
# LOSS train 0.6873 valid 0.6775
# Accuracy cap NOT hit at Step 270 : 0.567 < 0.9
# LOSS train 0.7004 valid 0.6783
# Accuracy cap NOT hit at Step 271 : 0.567 < 0.9
# LOSS train 0.6762 valid 0.6793
# Accuracy cap NOT hit at Step 272 : 0.545 < 0.9
# LOSS train 0.7031 valid 0.6825
# Accuracy cap NOT hit at Step 273 : 0.535 < 0.9
# LOSS train 0.6313 valid 0.6831
# Accuracy cap NOT hit at Step 274 : 0.533 < 0.9
# LOSS train 0.6681 valid 0.6845
# Accuracy cap NOT hit at Step 275 : 0.521 < 0.9
# LOSS train 0.7016 valid 0.6869
# Accuracy cap NOT hit at Step 276 : 0.514 < 0.9
# LOSS train 0.6579 valid 0.6886
# Accuracy cap NOT hit at Step 277 : 0.515 < 0.9
# LOSS train 0.6517 valid 0.6879
# Accuracy cap NOT hit at Step 278 : 0.522 < 0.9
# LOSS train 0.6842 valid 0.6963
# Accuracy cap NOT hit at Step 279 : 0.509 < 0.9
# LOSS train 0.7577 valid 0.7036
# Accuracy cap NOT hit at Step 280 : 0.501 < 0.9
# LOSS train 0.6750 valid 0.7077
# Accuracy cap NOT hit at Step 281 : 0.502 < 0.9
# LOSS train 0.6291 valid 0.7286
# Accuracy cap NOT hit at Step 282 : 0.497 < 0.9
# LOSS train 0.6451 valid 0.7270
# Accuracy cap NOT hit at Step 283 : 0.497 < 0.9
# LOSS train 0.8539 valid 0.7328
# Accuracy cap NOT hit at Step 284 : 0.502 < 0.9
# LOSS train 0.6663 valid 0.7487
# Accuracy cap NOT hit at Step 285 : 0.505 < 0.9
# LOSS train 0.6052 valid 0.7501
# Accuracy cap NOT hit at Step 286 : 0.5 < 0.9
# LOSS train 0.6964 valid 0.7185
# Accuracy cap NOT hit at Step 287 : 0.499 < 0.9
# LOSS train 0.6342 valid 0.6950
# Accuracy cap NOT hit at Step 288 : 0.487 < 0.9
# LOSS train 0.6951 valid 0.6834
# Accuracy cap NOT hit at Step 289 : 0.532 < 0.9
# LOSS train 0.7776 valid 0.6843
# Accuracy cap NOT hit at Step 290 : 0.531 < 0.9
# LOSS train 0.7043 valid 0.6913
# Accuracy cap NOT hit at Step 291 : 0.504 < 0.9
# LOSS train 0.6634 valid 0.7002
# Accuracy cap NOT hit at Step 292 : 0.498 < 0.9
# LOSS train 0.7103 valid 0.7171
# Accuracy cap NOT hit at Step 293 : 0.5 < 0.9
# LOSS train 0.7296 valid 0.7562
# Accuracy cap NOT hit at Step 294 : 0.5 < 0.9
# LOSS train 0.6832 valid 0.7885
# Accuracy cap NOT hit at Step 295 : 0.5 < 0.9
# LOSS train 0.6881 valid 0.8201
# Accuracy cap NOT hit at Step 296 : 0.5 < 0.9
# LOSS train 0.6103 valid 0.8711
# Accuracy cap NOT hit at Step 297 : 0.5 < 0.9
# LOSS train 0.6528 valid 0.9025
# Accuracy cap NOT hit at Step 298 : 0.5 < 0.9
# LOSS train 0.6456 valid 0.9066
# Accuracy cap NOT hit at Step 299 : 0.5 < 0.9
# LOSS train 0.6248 valid 0.9269
# Accuracy cap NOT hit at Step 300 : 0.5 < 0.9
# LOSS train 0.6569 valid 0.9406
# Accuracy cap NOT hit at Step 301 : 0.5 < 0.9
# LOSS train 0.6870 valid 0.9308
# Accuracy cap NOT hit at Step 302 : 0.5 < 0.9
# LOSS train 0.6851 valid 0.8922
# Accuracy cap NOT hit at Step 303 : 0.501 < 0.9
# LOSS train 0.7487 valid 0.7024
# Accuracy cap NOT hit at Step 304 : 0.497 < 0.9
# LOSS train 0.7143 valid 0.8202
# Accuracy cap NOT hit at Step 305 : 0.579 < 0.9
# LOSS train 0.5973 valid 1.3292
# Accuracy cap NOT hit at Step 306 : 0.533 < 0.9
# LOSS train 0.5704 valid 1.7674
# Accuracy cap NOT hit at Step 307 : 0.519 < 0.9
# LOSS train 0.6817 valid 1.9960
# Accuracy cap NOT hit at Step 308 : 0.508 < 0.9
# LOSS train 0.7311 valid 2.2634
# Accuracy cap NOT hit at Step 309 : 0.506 < 0.9
# LOSS train 0.8335 valid 2.0555
# Accuracy cap NOT hit at Step 310 : 0.506 < 0.9
# LOSS train 0.6803 valid 1.7522
# Accuracy cap NOT hit at Step 311 : 0.51 < 0.9
# LOSS train 0.5058 valid 1.4584
# Accuracy cap NOT hit at Step 312 : 0.526 < 0.9
# LOSS train 0.7539 valid 1.1474
# Accuracy cap NOT hit at Step 313 : 0.535 < 0.9
# LOSS train 0.6872 valid 0.8776
# Accuracy cap NOT hit at Step 314 : 0.562 < 0.9
# LOSS train 0.6686 valid 0.6963
# Accuracy cap NOT hit at Step 315 : 0.601 < 0.9
# LOSS train 0.7476 valid 0.6897
# Accuracy cap NOT hit at Step 316 : 0.508 < 0.9
# LOSS train 0.7312 valid 0.8462
# Accuracy cap NOT hit at Step 317 : 0.5 < 0.9
# LOSS train 0.5795 valid 0.9797
# Accuracy cap NOT hit at Step 318 : 0.5 < 0.9
# LOSS train 0.6747 valid 1.0778
# Accuracy cap NOT hit at Step 319 : 0.5 < 0.9
# LOSS train 0.7097 valid 1.0873
# Accuracy cap NOT hit at Step 320 : 0.5 < 0.9
# LOSS train 0.7338 valid 1.0268
# Accuracy cap NOT hit at Step 321 : 0.5 < 0.9
# LOSS train 0.6802 valid 0.9724
# Accuracy cap NOT hit at Step 322 : 0.5 < 0.9
# LOSS train 0.6633 valid 0.9192
# Accuracy cap NOT hit at Step 323 : 0.5 < 0.9
# LOSS train 0.6609 valid 0.8716
# Accuracy cap NOT hit at Step 324 : 0.5 < 0.9
# LOSS train 0.6424 valid 0.8379
# Accuracy cap NOT hit at Step 325 : 0.5 < 0.9
# LOSS train 0.6136 valid 0.8038
# Accuracy cap NOT hit at Step 326 : 0.5 < 0.9
# LOSS train 0.6798 valid 0.7809
# Accuracy cap NOT hit at Step 327 : 0.5 < 0.9
# LOSS train 0.7795 valid 0.7749
# Accuracy cap NOT hit at Step 328 : 0.5 < 0.9
# LOSS train 0.6157 valid 0.7751
# Accuracy cap NOT hit at Step 329 : 0.5 < 0.9
# LOSS train 0.6396 valid 0.7719
# Accuracy cap NOT hit at Step 330 : 0.5 < 0.9
# LOSS train 0.6075 valid 0.7743
# Accuracy cap NOT hit at Step 331 : 0.5 < 0.9
# LOSS train 0.7650 valid 0.7959
# Accuracy cap NOT hit at Step 332 : 0.5 < 0.9
# LOSS train 0.7542 valid 0.7510
# Accuracy cap NOT hit at Step 333 : 0.497 < 0.9
# LOSS train 0.6739 valid 0.7122
# Accuracy cap NOT hit at Step 334 : 0.557 < 0.9
# LOSS train 0.7056 valid 0.7235
# Accuracy cap NOT hit at Step 335 : 0.541 < 0.9
# LOSS train 0.6868 valid 0.7076
# Accuracy cap NOT hit at Step 336 : 0.529 < 0.9
# LOSS train 0.6401 valid 0.6995
# Accuracy cap NOT hit at Step 337 : 0.531 < 0.9
# LOSS train 0.6108 valid 0.6905
# Accuracy cap NOT hit at Step 338 : 0.534 < 0.9
# LOSS train 0.6836 valid 0.6900
# Accuracy cap NOT hit at Step 339 : 0.536 < 0.9
# LOSS train 0.7790 valid 0.6998
# Accuracy cap NOT hit at Step 340 : 0.542 < 0.9
# LOSS train 0.7295 valid 0.7286
# Accuracy cap NOT hit at Step 341 : 0.531 < 0.9
# LOSS train 0.6308 valid 0.7583
# Accuracy cap NOT hit at Step 342 : 0.527 < 0.9
# LOSS train 0.7018 valid 0.7712
# Accuracy cap NOT hit at Step 343 : 0.525 < 0.9
# LOSS train 0.6418 valid 0.7582
# Accuracy cap NOT hit at Step 344 : 0.529 < 0.9
# LOSS train 0.6803 valid 0.7464
# Accuracy cap NOT hit at Step 345 : 0.534 < 0.9
# LOSS train 0.7269 valid 0.7273
# Accuracy cap NOT hit at Step 346 : 0.541 < 0.9
# LOSS train 0.7363 valid 0.7058
# Accuracy cap NOT hit at Step 347 : 0.549 < 0.9
# LOSS train 0.6019 valid 0.6873
# Accuracy cap NOT hit at Step 348 : 0.568 < 0.9
# LOSS train 0.6633 valid 0.6782
# Accuracy cap NOT hit at Step 349 : 0.577 < 0.9
# LOSS train 0.6819 valid 0.6716
# Accuracy cap NOT hit at Step 350 : 0.586 < 0.9
# LOSS train 0.6296 valid 0.6691
# Accuracy cap NOT hit at Step 351 : 0.566 < 0.9
# LOSS train 0.6827 valid 0.6741
# Accuracy cap NOT hit at Step 352 : 0.528 < 0.9
# LOSS train 0.6611 valid 0.6761
# Accuracy cap NOT hit at Step 353 : 0.533 < 0.9
# LOSS train 0.6521 valid 0.6796
# Accuracy cap NOT hit at Step 354 : 0.526 < 0.9
# LOSS train 0.7154 valid 0.6943
# Accuracy cap NOT hit at Step 355 : 0.503 < 0.9
# LOSS train 0.6759 valid 0.7188
# Accuracy cap NOT hit at Step 356 : 0.488 < 0.9
# LOSS train 0.6562 valid 0.7412
# Accuracy cap NOT hit at Step 357 : 0.492 < 0.9
# LOSS train 0.6372 valid 0.7718
# Accuracy cap NOT hit at Step 358 : 0.495 < 0.9
# LOSS train 0.6000 valid 0.7967
# Accuracy cap NOT hit at Step 359 : 0.497 < 0.9
# LOSS train 0.5706 valid 0.8668
# Accuracy cap NOT hit at Step 360 : 0.499 < 0.9
# LOSS train 0.5993 valid 0.9544
# Accuracy cap NOT hit at Step 361 : 0.5 < 0.9
# LOSS train 0.6000 valid 1.0829
# Accuracy cap NOT hit at Step 362 : 0.5 < 0.9
# LOSS train 0.6581 valid 1.1989
# Accuracy cap NOT hit at Step 363 : 0.5 < 0.9
# LOSS train 0.7046 valid 1.2706
# Accuracy cap NOT hit at Step 364 : 0.5 < 0.9
# LOSS train 0.5959 valid 1.3546
# Accuracy cap NOT hit at Step 365 : 0.5 < 0.9
# LOSS train 0.5740 valid 1.4595
# Accuracy cap NOT hit at Step 366 : 0.5 < 0.9
# LOSS train 0.6994 valid 1.4658
# Accuracy cap NOT hit at Step 367 : 0.5 < 0.9
# LOSS train 0.7198 valid 1.3698
# Accuracy cap NOT hit at Step 368 : 0.5 < 0.9
# LOSS train 0.6727 valid 1.1241
# Accuracy cap NOT hit at Step 369 : 0.499 < 0.9
# LOSS train 0.6581 valid 0.8093
# Accuracy cap NOT hit at Step 370 : 0.487 < 0.9
# LOSS train 0.6454 valid 0.6908
# Accuracy cap NOT hit at Step 371 : 0.529 < 0.9
# LOSS train 0.6397 valid 0.6960
# Accuracy cap NOT hit at Step 372 : 0.528 < 0.9
# LOSS train 0.6960 valid 0.6713
# Accuracy cap NOT hit at Step 373 : 0.568 < 0.9
# LOSS train 0.6881 valid 0.6617
# Accuracy cap NOT hit at Step 374 : 0.577 < 0.9
# LOSS train 0.7821 valid 0.6750
# Accuracy cap NOT hit at Step 375 : 0.571 < 0.9
# LOSS train 0.5945 valid 0.6657
# Accuracy cap NOT hit at Step 376 : 0.594 < 0.9
# LOSS train 0.6866 valid 0.6460
# Accuracy cap NOT hit at Step 377 : 0.614 < 0.9
# LOSS train 0.6313 valid 0.6539
# Accuracy cap NOT hit at Step 378 : 0.606 < 0.9
# LOSS train 0.6957 valid 0.6741
# Accuracy cap NOT hit at Step 379 : 0.56 < 0.9
# LOSS train 0.7166 valid 0.8526
# Accuracy cap NOT hit at Step 380 : 0.494 < 0.9
# LOSS train 0.5710 valid 1.1082
# Accuracy cap NOT hit at Step 381 : 0.5 < 0.9
# LOSS train 0.7048 valid 0.9225
# Accuracy cap NOT hit at Step 382 : 0.497 < 0.9
# LOSS train 0.7363 valid 0.6898
# Accuracy cap NOT hit at Step 383 : 0.518 < 0.9
# LOSS train 0.6109 valid 0.6324
# Accuracy cap NOT hit at Step 384 : 0.624 < 0.9
# LOSS train 0.6302 valid 0.6536
# Accuracy cap NOT hit at Step 385 : 0.583 < 0.9
# LOSS train 0.6572 valid 0.6777
# Accuracy cap NOT hit at Step 386 : 0.57 < 0.9
# LOSS train 0.5958 valid 0.7118
# Accuracy cap NOT hit at Step 387 : 0.535 < 0.9
# LOSS train 0.5929 valid 0.7182
# Accuracy cap NOT hit at Step 388 : 0.524 < 0.9
# LOSS train 0.6627 valid 0.7269
# Accuracy cap NOT hit at Step 389 : 0.52 < 0.9
# LOSS train 0.6700 valid 0.7422
# Accuracy cap NOT hit at Step 390 : 0.516 < 0.9
# LOSS train 0.5927 valid 0.8179
# Accuracy cap NOT hit at Step 391 : 0.49 < 0.9
# LOSS train 0.6717 valid 0.7864
# Accuracy cap NOT hit at Step 392 : 0.5 < 0.9
# LOSS train 0.6674 valid 0.7759
# Accuracy cap NOT hit at Step 393 : 0.51 < 0.9
# LOSS train 0.5397 valid 0.6949
# Accuracy cap NOT hit at Step 394 : 0.555 < 0.9
# LOSS train 0.6423 valid 0.6468
# Accuracy cap NOT hit at Step 395 : 0.611 < 0.9
# LOSS train 0.6180 valid 0.6496
# Accuracy cap NOT hit at Step 396 : 0.578 < 0.9
# LOSS train 0.5750 valid 0.8780
# Accuracy cap NOT hit at Step 397 : 0.483 < 0.9
# LOSS train 0.6090 valid 1.4831
# Accuracy cap NOT hit at Step 398 : 0.5 < 0.9
# LOSS train 0.6416 valid 1.4962
# Accuracy cap NOT hit at Step 399 : 0.5 < 0.9
# LOSS train 0.6182 valid 1.4005
# Accuracy cap NOT hit at Step 400 : 0.5 < 0.9
# LOSS train 0.6361 valid 1.3725
# Accuracy cap NOT hit at Step 401 : 0.5 < 0.9
# LOSS train 0.6925 valid 1.3851
# Accuracy cap NOT hit at Step 402 : 0.5 < 0.9
# LOSS train 0.6748 valid 1.4490
# Accuracy cap NOT hit at Step 403 : 0.5 < 0.9
# LOSS train 0.5896 valid 1.5520
# Accuracy cap NOT hit at Step 404 : 0.5 < 0.9
# LOSS train 0.6234 valid 1.6033
# Accuracy cap NOT hit at Step 405 : 0.5 < 0.9
# LOSS train 0.5491 valid 1.6505
# Accuracy cap NOT hit at Step 406 : 0.5 < 0.9
# LOSS train 0.5983 valid 1.7233
# Accuracy cap NOT hit at Step 407 : 0.5 < 0.9
# LOSS train 0.8181 valid 1.6219
# Accuracy cap NOT hit at Step 408 : 0.5 < 0.9
# LOSS train 0.7221 valid 1.4060
# Accuracy cap NOT hit at Step 409 : 0.5 < 0.9
# LOSS train 0.5488 valid 1.2611
# Accuracy cap NOT hit at Step 410 : 0.5 < 0.9
# LOSS train 0.6674 valid 1.2058
# Accuracy cap NOT hit at Step 411 : 0.5 < 0.9
# LOSS train 0.7009 valid 1.1723
# Accuracy cap NOT hit at Step 412 : 0.5 < 0.9
# LOSS train 0.6616 valid 1.1285
# Accuracy cap NOT hit at Step 413 : 0.5 < 0.9
# LOSS train 0.6953 valid 1.0811
# Accuracy cap NOT hit at Step 414 : 0.5 < 0.9
# LOSS train 0.7005 valid 1.0869
# Accuracy cap NOT hit at Step 415 : 0.5 < 0.9
# LOSS train 0.6777 valid 1.1243
# Accuracy cap NOT hit at Step 416 : 0.5 < 0.9
# LOSS train 0.5684 valid 1.2082
# Accuracy cap NOT hit at Step 417 : 0.5 < 0.9
# LOSS train 0.7309 valid 0.8443
# Accuracy cap NOT hit at Step 418 : 0.492 < 0.9
# LOSS train 0.6624 valid 0.6809
# Accuracy cap NOT hit at Step 419 : 0.569 < 0.9
# LOSS train 0.5686 valid 1.0985
# Accuracy cap NOT hit at Step 420 : 0.409 < 0.9
# LOSS train 0.6301 valid 1.5484
# Accuracy cap NOT hit at Step 421 : 0.421 < 0.9
# LOSS train 0.5499 valid 1.3052
# Accuracy cap NOT hit at Step 422 : 0.423 < 0.9
# LOSS train 0.6759 valid 1.0527
# Accuracy cap NOT hit at Step 423 : 0.426 < 0.9
# LOSS train 0.6256 valid 0.8651
# Accuracy cap NOT hit at Step 424 : 0.449 < 0.9
# LOSS train 0.6510 valid 0.7738
# Accuracy cap NOT hit at Step 425 : 0.471 < 0.9
# LOSS train 0.5556 valid 0.6997
# Accuracy cap NOT hit at Step 426 : 0.55 < 0.9
# LOSS train 0.6182 valid 0.6444
# Accuracy cap NOT hit at Step 427 : 0.629 < 0.9
# LOSS train 0.5760 valid 0.6234
# Accuracy cap NOT hit at Step 428 : 0.649 < 0.9
# LOSS train 0.5463 valid 0.6285
# Accuracy cap NOT hit at Step 429 : 0.624 < 0.9
# LOSS train 0.6844 valid 0.6275
# Accuracy cap NOT hit at Step 430 : 0.629 < 0.9
# LOSS train 0.7103 valid 0.6251
# Accuracy cap NOT hit at Step 431 : 0.653 < 0.9
# LOSS train 0.7929 valid 0.6479
# Accuracy cap NOT hit at Step 432 : 0.6 < 0.9
# LOSS train 0.5134 valid 0.6481
# Accuracy cap NOT hit at Step 433 : 0.602 < 0.9
# LOSS train 0.6946 valid 0.7368
# Accuracy cap NOT hit at Step 434 : 0.493 < 0.9
# LOSS train 0.6572 valid 0.8235
# Accuracy cap NOT hit at Step 435 : 0.482 < 0.9
# LOSS train 0.6669 valid 0.9497
# Accuracy cap NOT hit at Step 436 : 0.491 < 0.9
# LOSS train 0.6410 valid 0.8568
# Accuracy cap NOT hit at Step 437 : 0.488 < 0.9
# LOSS train 0.6235 valid 0.6398
# Accuracy cap NOT hit at Step 438 : 0.587 < 0.9
# LOSS train 0.5630 valid 0.6530
# Accuracy cap NOT hit at Step 439 : 0.591 < 0.9
# LOSS train 0.6704 valid 0.6511
# Accuracy cap NOT hit at Step 440 : 0.585 < 0.9
# LOSS train 0.6180 valid 0.6368
# Accuracy cap NOT hit at Step 441 : 0.599 < 0.9
# LOSS train 0.6779 valid 0.6323
# Accuracy cap NOT hit at Step 442 : 0.629 < 0.9
# LOSS train 0.4767 valid 0.6385
# Accuracy cap NOT hit at Step 443 : 0.64 < 0.9
# LOSS train 0.6637 valid 0.6423
# Accuracy cap NOT hit at Step 444 : 0.645 < 0.9
# LOSS train 0.6189 valid 0.6368
# Accuracy cap NOT hit at Step 445 : 0.656 < 0.9
# LOSS train 0.6366 valid 0.6386
# Accuracy cap NOT hit at Step 446 : 0.665 < 0.9
# LOSS train 0.6831 valid 0.6472
# Accuracy cap NOT hit at Step 447 : 0.657 < 0.9
# LOSS train 0.6118 valid 0.6715
# Accuracy cap NOT hit at Step 448 : 0.619 < 0.9
# LOSS train 0.7150 valid 0.6600
# Accuracy cap NOT hit at Step 449 : 0.61 < 0.9
# LOSS train 0.6619 valid 0.6726
# Accuracy cap NOT hit at Step 450 : 0.59 < 0.9
# LOSS train 0.6124 valid 0.7058
# Accuracy cap NOT hit at Step 451 : 0.517 < 0.9
# LOSS train 0.7544 valid 0.7276
# Accuracy cap NOT hit at Step 452 : 0.487 < 0.9
# LOSS train 0.5902 valid 0.7462
# Accuracy cap NOT hit at Step 453 : 0.478 < 0.9
# LOSS train 0.7339 valid 0.8082
# Accuracy cap NOT hit at Step 454 : 0.448 < 0.9
# LOSS train 0.6572 valid 1.0853
# Accuracy cap NOT hit at Step 455 : 0.427 < 0.9
# LOSS train 0.6667 valid 1.5912
# Accuracy cap NOT hit at Step 456 : 0.448 < 0.9
# LOSS train 0.6662 valid 2.1992
# Accuracy cap NOT hit at Step 457 : 0.471 < 0.9
# LOSS train 0.6585 valid 2.8622
# Accuracy cap NOT hit at Step 458 : 0.484 < 0.9
# LOSS train 0.6331 valid 2.9566
# Accuracy cap NOT hit at Step 459 : 0.486 < 0.9
# LOSS train 0.6158 valid 2.6866
# Accuracy cap NOT hit at Step 460 : 0.492 < 0.9
# LOSS train 0.6134 valid 2.7587
# Accuracy cap NOT hit at Step 461 : 0.495 < 0.9
# LOSS train 0.5819 valid 2.6738
# Accuracy cap NOT hit at Step 462 : 0.496 < 0.9
# LOSS train 0.6969 valid 2.1851
# Accuracy cap NOT hit at Step 463 : 0.491 < 0.9
# LOSS train 0.5726 valid 1.4882
# Accuracy cap NOT hit at Step 464 : 0.491 < 0.9
# LOSS train 0.7501 valid 1.2657
# Accuracy cap NOT hit at Step 465 : 0.485 < 0.9
# LOSS train 0.7335 valid 0.9931
# Accuracy cap NOT hit at Step 466 : 0.47 < 0.9
# LOSS train 0.6837 valid 0.7607
# Accuracy cap NOT hit at Step 467 : 0.497 < 0.9
# LOSS train 0.6375 valid 0.6675
# Accuracy cap NOT hit at Step 468 : 0.575 < 0.9
# LOSS train 0.6546 valid 0.6512
# Accuracy cap NOT hit at Step 469 : 0.622 < 0.9
# LOSS train 0.6453 valid 0.6575
# Accuracy cap NOT hit at Step 470 : 0.627 < 0.9
# LOSS train 0.6376 valid 0.6416
# Accuracy cap NOT hit at Step 471 : 0.655 < 0.9
# LOSS train 0.6820 valid 0.6401
# Accuracy cap NOT hit at Step 472 : 0.658 < 0.9
# LOSS train 0.6655 valid 0.6686
# Accuracy cap NOT hit at Step 473 : 0.59 < 0.9
# LOSS train 0.6584 valid 0.6591
# Accuracy cap NOT hit at Step 474 : 0.602 < 0.9
# LOSS train 0.6063 valid 0.6642
# Accuracy cap NOT hit at Step 475 : 0.587 < 0.9
# LOSS train 0.7129 valid 0.7100
# Accuracy cap NOT hit at Step 476 : 0.503 < 0.9
# LOSS train 0.6522 valid 0.6232
# Accuracy cap NOT hit at Step 477 : 0.645 < 0.9
# LOSS train 0.5628 valid 0.6825
# Accuracy cap NOT hit at Step 478 : 0.556 < 0.9
# LOSS train 0.6416 valid 0.7334
# Accuracy cap NOT hit at Step 479 : 0.527 < 0.9
# LOSS train 0.6959 valid 1.2343
# Accuracy cap NOT hit at Step 480 : 0.451 < 0.9
# LOSS train 0.5834 valid 2.1265
# Accuracy cap NOT hit at Step 481 : 0.468 < 0.9
# LOSS train 0.6518 valid 2.5192
# Accuracy cap NOT hit at Step 482 : 0.478 < 0.9
# LOSS train 0.5952 valid 2.5113
# Accuracy cap NOT hit at Step 483 : 0.479 < 0.9
# LOSS train 0.6156 valid 2.1477
# Accuracy cap NOT hit at Step 484 : 0.469 < 0.9
# LOSS train 0.7137 valid 1.4238
# Accuracy cap NOT hit at Step 485 : 0.428 < 0.9
# LOSS train 0.6786 valid 1.0570
# Accuracy cap NOT hit at Step 486 : 0.431 < 0.9
# LOSS train 0.7126 valid 0.9838
# Accuracy cap NOT hit at Step 487 : 0.439 < 0.9
# LOSS train 0.6524 valid 0.9114
# Accuracy cap NOT hit at Step 488 : 0.432 < 0.9
# LOSS train 0.6414 valid 0.8044
# Accuracy cap NOT hit at Step 489 : 0.494 < 0.9
# LOSS train 0.6218 valid 0.7398
# Accuracy cap NOT hit at Step 490 : 0.532 < 0.9
# LOSS train 0.5995 valid 0.6803
# Accuracy cap NOT hit at Step 491 : 0.589 < 0.9
# LOSS train 0.6300 valid 0.6345
# Accuracy cap NOT hit at Step 492 : 0.656 < 0.9
# LOSS train 0.6241 valid 0.6640
# Accuracy cap NOT hit at Step 493 : 0.578 < 0.9
# LOSS train 0.6345 valid 0.9006
# Accuracy cap NOT hit at Step 494 : 0.479 < 0.9
# LOSS train 0.4622 valid 1.3253
# Accuracy cap NOT hit at Step 495 : 0.499 < 0.9
# LOSS train 0.5737 valid 1.6108
# Accuracy cap NOT hit at Step 496 : 0.5 < 0.9
# LOSS train 0.6089 valid 2.0573
# Accuracy cap NOT hit at Step 497 : 0.5 < 0.9
# LOSS train 0.6398 valid 2.3510
# Accuracy cap NOT hit at Step 498 : 0.5 < 0.9
# LOSS train 0.5461 valid 2.3968
# Accuracy cap NOT hit at Step 499 : 0.5 < 0.9
# LOSS train 0.5805 valid 2.4185
# Accuracy cap NOT hit at Step 500 : 0.5 < 0.9
# EPOCH 3:
# LOSS train 0.4861 valid 2.3559
# Accuracy cap NOT hit at Step 501 : 0.5 < 0.9
# LOSS train 0.8148 valid 2.3819
# Accuracy cap NOT hit at Step 502 : 0.5 < 0.9
# LOSS train 0.7382 valid 2.2325
# Accuracy cap NOT hit at Step 503 : 0.5 < 0.9
# LOSS train 0.6493 valid 2.2201
# Accuracy cap NOT hit at Step 504 : 0.5 < 0.9
# LOSS train 0.6584 valid 2.2540
# Accuracy cap NOT hit at Step 505 : 0.5 < 0.9
# LOSS train 0.6266 valid 2.2771
# Accuracy cap NOT hit at Step 506 : 0.5 < 0.9
# LOSS train 0.5701 valid 2.2890
# Accuracy cap NOT hit at Step 507 : 0.5 < 0.9
# LOSS train 0.6080 valid 2.2387
# Accuracy cap NOT hit at Step 508 : 0.5 < 0.9
# LOSS train 0.6097 valid 2.1273
# Accuracy cap NOT hit at Step 509 : 0.5 < 0.9
# LOSS train 0.5948 valid 1.8161
# Accuracy cap NOT hit at Step 510 : 0.5 < 0.9
# LOSS train 0.5674 valid 1.5546
# Accuracy cap NOT hit at Step 511 : 0.5 < 0.9
# LOSS train 0.6689 valid 1.4174
# Accuracy cap NOT hit at Step 512 : 0.5 < 0.9
# LOSS train 0.6579 valid 1.3424
# Accuracy cap NOT hit at Step 513 : 0.497 < 0.9
# LOSS train 0.6461 valid 1.0082
# Accuracy cap NOT hit at Step 514 : 0.475 < 0.9
# LOSS train 0.5522 valid 1.1479
# Accuracy cap NOT hit at Step 515 : 0.491 < 0.9
# LOSS train 0.5430 valid 1.3245
# Accuracy cap NOT hit at Step 516 : 0.499 < 0.9
# LOSS train 0.6262 valid 1.7207
# Accuracy cap NOT hit at Step 517 : 0.5 < 0.9
# LOSS train 0.6526 valid 1.8858
# Accuracy cap NOT hit at Step 518 : 0.5 < 0.9
# LOSS train 0.5758 valid 1.9231
# Accuracy cap NOT hit at Step 519 : 0.5 < 0.9
# LOSS train 0.5772 valid 1.8141
# Accuracy cap NOT hit at Step 520 : 0.5 < 0.9
# LOSS train 0.7433 valid 1.9480
# Accuracy cap NOT hit at Step 521 : 0.5 < 0.9
# LOSS train 0.7663 valid 1.7240
# Accuracy cap NOT hit at Step 522 : 0.5 < 0.9
# LOSS train 0.5528 valid 1.4854
# Accuracy cap NOT hit at Step 523 : 0.5 < 0.9
# LOSS train 0.5908 valid 1.2499
# Accuracy cap NOT hit at Step 524 : 0.5 < 0.9
# LOSS train 0.5998 valid 1.1725
# Accuracy cap NOT hit at Step 525 : 0.5 < 0.9
# LOSS train 0.5923 valid 1.0676
# Accuracy cap NOT hit at Step 526 : 0.495 < 0.9
# LOSS train 0.6072 valid 1.2202
# Accuracy cap NOT hit at Step 527 : 0.5 < 0.9
# LOSS train 0.5608 valid 1.0873
# Accuracy cap NOT hit at Step 528 : 0.494 < 0.9
# LOSS train 0.6551 valid 0.9605
# Accuracy cap NOT hit at Step 529 : 0.479 < 0.9
# LOSS train 0.5348 valid 0.6465
# Accuracy cap NOT hit at Step 530 : 0.565 < 0.9
# LOSS train 0.5981 valid 0.6309
# Accuracy cap NOT hit at Step 531 : 0.615 < 0.9
# LOSS train 0.7061 valid 0.6272
# Accuracy cap NOT hit at Step 532 : 0.619 < 0.9
# LOSS train 0.7132 valid 0.7377
# Accuracy cap NOT hit at Step 533 : 0.563 < 0.9
# LOSS train 0.7044 valid 1.7071
# Accuracy cap NOT hit at Step 534 : 0.459 < 0.9
# LOSS train 0.6827 valid 4.2229
# Accuracy cap NOT hit at Step 535 : 0.49 < 0.9
# LOSS train 0.5767 valid 6.7535
# Accuracy cap NOT hit at Step 536 : 0.487 < 0.9
# LOSS train 0.6677 valid 7.0814
# Accuracy cap NOT hit at Step 537 : 0.481 < 0.9
# LOSS train 0.6717 valid 6.2079
# Accuracy cap NOT hit at Step 538 : 0.473 < 0.9
# LOSS train 0.5378 valid 5.3639
# Accuracy cap NOT hit at Step 539 : 0.474 < 0.9
# LOSS train 0.7026 valid 4.5599
# Accuracy cap NOT hit at Step 540 : 0.473 < 0.9
# LOSS train 0.7027 valid 4.7405
# Accuracy cap NOT hit at Step 541 : 0.475 < 0.9
# LOSS train 0.5592 valid 4.5731
# Accuracy cap NOT hit at Step 542 : 0.473 < 0.9
# LOSS train 0.6384 valid 3.5970
# Accuracy cap NOT hit at Step 543 : 0.456 < 0.9
# LOSS train 0.6466 valid 2.3221
# Accuracy cap NOT hit at Step 544 : 0.441 < 0.9
# LOSS train 0.5816 valid 1.4371
# Accuracy cap NOT hit at Step 545 : 0.43 < 0.9
# LOSS train 0.6399 valid 0.9868
# Accuracy cap NOT hit at Step 546 : 0.467 < 0.9
# LOSS train 0.6090 valid 0.6789
# Accuracy cap NOT hit at Step 547 : 0.616 < 0.9
# LOSS train 0.5880 valid 0.6158
# Accuracy cap NOT hit at Step 548 : 0.615 < 0.9
# LOSS train 0.5244 valid 0.9569
# Accuracy cap NOT hit at Step 549 : 0.472 < 0.9
# LOSS train 0.5711 valid 1.5081
# Accuracy cap NOT hit at Step 550 : 0.5 < 0.9
# LOSS train 0.5220 valid 2.0057
# Accuracy cap NOT hit at Step 551 : 0.5 < 0.9
# LOSS train 0.5665 valid 2.1419
# Accuracy cap NOT hit at Step 552 : 0.5 < 0.9
# LOSS train 0.5785 valid 1.9830
# Accuracy cap NOT hit at Step 553 : 0.5 < 0.9
# LOSS train 0.6077 valid 1.2945
# Accuracy cap NOT hit at Step 554 : 0.488 < 0.9
# LOSS train 0.6001 valid 0.6181
# Accuracy cap NOT hit at Step 555 : 0.632 < 0.9
# LOSS train 0.5502 valid 0.5989
# Accuracy cap NOT hit at Step 556 : 0.681 < 0.9
# LOSS train 0.5505 valid 0.6462
# Accuracy cap NOT hit at Step 557 : 0.613 < 0.9
# LOSS train 0.8206 valid 0.7204
# Accuracy cap NOT hit at Step 558 : 0.585 < 0.9
# LOSS train 0.7318 valid 0.8113
# Accuracy cap NOT hit at Step 559 : 0.545 < 0.9
# LOSS train 0.4859 valid 1.9001
# Accuracy cap NOT hit at Step 560 : 0.494 < 0.9
# LOSS train 0.5010 valid 2.7073
# Accuracy cap NOT hit at Step 561 : 0.5 < 0.9
# LOSS train 0.6000 valid 3.1380
# Accuracy cap NOT hit at Step 562 : 0.5 < 0.9
# LOSS train 0.5015 valid 3.3529
# Accuracy cap NOT hit at Step 563 : 0.5 < 0.9
# LOSS train 0.6702 valid 3.3317
# Accuracy cap NOT hit at Step 564 : 0.5 < 0.9
# LOSS train 0.6996 valid 3.3597
# Accuracy cap NOT hit at Step 565 : 0.5 < 0.9
# LOSS train 0.7583 valid 3.4858
# Accuracy cap NOT hit at Step 566 : 0.5 < 0.9
# LOSS train 0.6200 valid 3.3151
# Accuracy cap NOT hit at Step 567 : 0.5 < 0.9
# LOSS train 0.6876 valid 3.1338
# Accuracy cap NOT hit at Step 568 : 0.5 < 0.9
# LOSS train 0.5284 valid 3.0398
# Accuracy cap NOT hit at Step 569 : 0.5 < 0.9
# LOSS train 0.5761 valid 2.9466
# Accuracy cap NOT hit at Step 570 : 0.5 < 0.9
# LOSS train 0.5388 valid 2.9773
# Accuracy cap NOT hit at Step 571 : 0.5 < 0.9
# LOSS train 0.5373 valid 3.1864
# Accuracy cap NOT hit at Step 572 : 0.5 < 0.9
# LOSS train 0.7207 valid 3.1245
# Accuracy cap NOT hit at Step 573 : 0.5 < 0.9
# LOSS train 0.5510 valid 2.9552
# Accuracy cap NOT hit at Step 574 : 0.5 < 0.9
# LOSS train 0.9568 valid 2.0646
# Accuracy cap NOT hit at Step 575 : 0.495 < 0.9
# LOSS train 0.8110 valid 1.1611
# Accuracy cap NOT hit at Step 576 : 0.506 < 0.9
# LOSS train 0.5867 valid 0.7797
# Accuracy cap NOT hit at Step 577 : 0.506 < 0.9
# LOSS train 0.7106 valid 4.0276
# Accuracy cap NOT hit at Step 578 : 0.455 < 0.9
# LOSS train 0.7066 valid 8.0688
# Accuracy cap NOT hit at Step 579 : 0.482 < 0.9
# LOSS train 0.6417 valid 11.4429
# Accuracy cap NOT hit at Step 580 : 0.497 < 0.9
# LOSS train 0.6252 valid 14.9332
# Accuracy cap NOT hit at Step 581 : 0.499 < 0.9
# LOSS train 0.7029 valid 18.5258
# Accuracy cap NOT hit at Step 582 : 0.499 < 0.9
# LOSS train 0.6271 valid 18.4585
# Accuracy cap NOT hit at Step 583 : 0.499 < 0.9
# LOSS train 0.5848 valid 18.1972
# Accuracy cap NOT hit at Step 584 : 0.498 < 0.9
# LOSS train 0.5963 valid 16.6484
# Accuracy cap NOT hit at Step 585 : 0.498 < 0.9
# LOSS train 0.6776 valid 15.2264
# Accuracy cap NOT hit at Step 586 : 0.497 < 0.9
# LOSS train 0.5568 valid 12.0825
# Accuracy cap NOT hit at Step 587 : 0.497 < 0.9
# LOSS train 0.6175 valid 9.5161
# Accuracy cap NOT hit at Step 588 : 0.495 < 0.9
# LOSS train 0.6374 valid 6.7901
# Accuracy cap NOT hit at Step 589 : 0.489 < 0.9
# LOSS train 0.5620 valid 4.5731
# Accuracy cap NOT hit at Step 590 : 0.483 < 0.9
# LOSS train 0.5314 valid 2.9182
# Accuracy cap NOT hit at Step 591 : 0.455 < 0.9
# LOSS train 0.6101 valid 1.6490
# Accuracy cap NOT hit at Step 592 : 0.411 < 0.9
# LOSS train 0.6017 valid 0.9275
# Accuracy cap NOT hit at Step 593 : 0.441 < 0.9
# LOSS train 0.4606 valid 0.6700
# Accuracy cap NOT hit at Step 594 : 0.603 < 0.9
# LOSS train 0.6217 valid 0.6024
# Accuracy cap NOT hit at Step 595 : 0.692 < 0.9
# LOSS train 0.6162 valid 0.7824
# Accuracy cap NOT hit at Step 596 : 0.49 < 0.9
# LOSS train 0.5772 valid 1.0916
# Accuracy cap NOT hit at Step 597 : 0.457 < 0.9
# LOSS train 0.6422 valid 1.6507
# Accuracy cap NOT hit at Step 598 : 0.493 < 0.9
# LOSS train 0.5690 valid 2.0427
# Accuracy cap NOT hit at Step 599 : 0.499 < 0.9
# LOSS train 0.6002 valid 2.3591
# Accuracy cap NOT hit at Step 600 : 0.5 < 0.9
# LOSS train 0.5210 valid 3.0012
# Accuracy cap NOT hit at Step 601 : 0.5 < 0.9
# LOSS train 0.5152 valid 2.6680
# Accuracy cap NOT hit at Step 602 : 0.5 < 0.9
# LOSS train 0.7099 valid 1.7732
# Accuracy cap NOT hit at Step 603 : 0.492 < 0.9
# LOSS train 0.4583 valid 1.6213
# Accuracy cap NOT hit at Step 604 : 0.482 < 0.9
# LOSS train 0.6100 valid 0.8401
# Accuracy cap NOT hit at Step 605 : 0.485 < 0.9
# LOSS train 0.5425 valid 0.6046
# Accuracy cap NOT hit at Step 606 : 0.63 < 0.9
# LOSS train 0.5462 valid 0.6478
# Accuracy cap NOT hit at Step 607 : 0.606 < 0.9
# LOSS train 0.5268 valid 0.7235
# Accuracy cap NOT hit at Step 608 : 0.536 < 0.9
# LOSS train 0.4910 valid 0.9683
# Accuracy cap NOT hit at Step 609 : 0.425 < 0.9
# LOSS train 0.6008 valid 1.3252
# Accuracy cap NOT hit at Step 610 : 0.394 < 0.9
# LOSS train 0.6200 valid 1.2589
# Accuracy cap NOT hit at Step 611 : 0.405 < 0.9
# LOSS train 0.7744 valid 1.2591
# Accuracy cap NOT hit at Step 612 : 0.412 < 0.9
# LOSS train 0.5098 valid 1.1983
# Accuracy cap NOT hit at Step 613 : 0.422 < 0.9
# LOSS train 0.6927 valid 0.9660
# Accuracy cap NOT hit at Step 614 : 0.466 < 0.9
# LOSS train 0.8138 valid 0.7258
# Accuracy cap NOT hit at Step 615 : 0.565 < 0.9
# LOSS train 0.5226 valid 0.5680
# Accuracy cap NOT hit at Step 616 : 0.686 < 0.9
# LOSS train 0.5374 valid 0.8352
# Accuracy cap NOT hit at Step 617 : 0.448 < 0.9
# LOSS train 0.5228 valid 1.4754
# Accuracy cap NOT hit at Step 618 : 0.494 < 0.9
# LOSS train 0.6306 valid 2.4549
# Accuracy cap NOT hit at Step 619 : 0.5 < 0.9
# LOSS train 0.4790 valid 2.7839
# Accuracy cap NOT hit at Step 620 : 0.5 < 0.9
# LOSS train 0.5241 valid 2.9166
# Accuracy cap NOT hit at Step 621 : 0.5 < 0.9
# LOSS train 0.5615 valid 3.0517
# Accuracy cap NOT hit at Step 622 : 0.5 < 0.9
# LOSS train 0.7292 valid 3.1570
# Accuracy cap NOT hit at Step 623 : 0.5 < 0.9
# LOSS train 0.5338 valid 2.9040
# Accuracy cap NOT hit at Step 624 : 0.5 < 0.9
# LOSS train 0.5885 valid 2.7725
# Accuracy cap NOT hit at Step 625 : 0.5 < 0.9
# LOSS train 0.5861 valid 2.4032
# Accuracy cap NOT hit at Step 626 : 0.5 < 0.9
# LOSS train 0.5382 valid 1.8249
# Accuracy cap NOT hit at Step 627 : 0.498 < 0.9
# LOSS train 0.5613 valid 1.0152
# Accuracy cap NOT hit at Step 628 : 0.474 < 0.9
# LOSS train 0.5341 valid 0.6368
# Accuracy cap NOT hit at Step 629 : 0.599 < 0.9
# LOSS train 0.5126 valid 0.5474
# Accuracy cap NOT hit at Step 630 : 0.717 < 0.9
# LOSS train 0.6331 valid 0.5542
# Accuracy cap NOT hit at Step 631 : 0.713 < 0.9
# LOSS train 0.5473 valid 0.5577
# Accuracy cap NOT hit at Step 632 : 0.713 < 0.9
# LOSS train 0.6172 valid 0.5381
# Accuracy cap NOT hit at Step 633 : 0.724 < 0.9
# LOSS train 0.5642 valid 0.5603
# Accuracy cap NOT hit at Step 634 : 0.665 < 0.9
# LOSS train 0.5000 valid 0.8243
# Accuracy cap NOT hit at Step 635 : 0.449 < 0.9
# LOSS train 0.5413 valid 1.0318
# Accuracy cap NOT hit at Step 636 : 0.445 < 0.9
# LOSS train 0.7316 valid 0.8597
# Accuracy cap NOT hit at Step 637 : 0.447 < 0.9
# LOSS train 0.5584 valid 0.8537
# Accuracy cap NOT hit at Step 638 : 0.447 < 0.9
# LOSS train 0.6681 valid 1.1348
# Accuracy cap NOT hit at Step 639 : 0.455 < 0.9
# LOSS train 0.5724 valid 1.7479
# Accuracy cap NOT hit at Step 640 : 0.497 < 0.9
# LOSS train 0.5840 valid 2.4311
# Accuracy cap NOT hit at Step 641 : 0.5 < 0.9
# LOSS train 0.4831 valid 2.9576
# Accuracy cap NOT hit at Step 642 : 0.5 < 0.9
# LOSS train 0.5252 valid 3.4447
# Accuracy cap NOT hit at Step 643 : 0.5 < 0.9
# LOSS train 0.6500 valid 3.6954
# Accuracy cap NOT hit at Step 644 : 0.5 < 0.9
# LOSS train 0.4967 valid 3.5703
# Accuracy cap NOT hit at Step 645 : 0.5 < 0.9
# LOSS train 0.6921 valid 3.5533
# Accuracy cap NOT hit at Step 646 : 0.5 < 0.9
# LOSS train 0.7621 valid 3.6938
# Accuracy cap NOT hit at Step 647 : 0.5 < 0.9
# LOSS train 0.5663 valid 4.0456
# Accuracy cap NOT hit at Step 648 : 0.5 < 0.9
# LOSS train 0.5097 valid 4.3009
# Accuracy cap NOT hit at Step 649 : 0.5 < 0.9
# LOSS train 0.5056 valid 4.7054
# Accuracy cap NOT hit at Step 650 : 0.5 < 0.9
# LOSS train 0.4718 valid 4.8239
# Accuracy cap NOT hit at Step 651 : 0.5 < 0.9
# LOSS train 0.5447 valid 4.4987
# Accuracy cap NOT hit at Step 652 : 0.5 < 0.9
# LOSS train 0.4648 valid 4.2014
# Accuracy cap NOT hit at Step 653 : 0.5 < 0.9
# LOSS train 0.5023 valid 4.5770
# Accuracy cap NOT hit at Step 654 : 0.5 < 0.9
# LOSS train 0.5389 valid 4.5553
# Accuracy cap NOT hit at Step 655 : 0.5 < 0.9
# LOSS train 0.4241 valid 5.2594
# Accuracy cap NOT hit at Step 656 : 0.5 < 0.9
# LOSS train 0.4547 valid 5.4383
# Accuracy cap NOT hit at Step 657 : 0.5 < 0.9
# LOSS train 0.4192 valid 5.3034
# Accuracy cap NOT hit at Step 658 : 0.5 < 0.9
# LOSS train 0.5180 valid 4.6193
# Accuracy cap NOT hit at Step 659 : 0.497 < 0.9
# LOSS train 0.6184 valid 3.5011
# Accuracy cap NOT hit at Step 660 : 0.488 < 0.9
# LOSS train 0.5266 valid 2.5791
# Accuracy cap NOT hit at Step 661 : 0.469 < 0.9
# LOSS train 0.3518 valid 1.3342
# Accuracy cap NOT hit at Step 662 : 0.446 < 0.9
# LOSS train 0.3703 valid 0.9850
# Accuracy cap NOT hit at Step 663 : 0.499 < 0.9
# LOSS train 0.5454 valid 0.7434
# Accuracy cap NOT hit at Step 664 : 0.64 < 0.9
# LOSS train 0.3274 valid 1.2337
# Accuracy cap NOT hit at Step 665 : 0.552 < 0.9
# LOSS train 0.7146 valid 3.0861
# Accuracy cap NOT hit at Step 666 : 0.457 < 0.9
# LOSS train 0.4706 valid 4.7901
# Accuracy cap NOT hit at Step 667 : 0.452 < 0.9
# LOSS train 0.5582 valid 7.5522
# Accuracy cap NOT hit at Step 668 : 0.469 < 0.9
# LOSS train 0.4225 valid 7.9391
# Accuracy cap NOT hit at Step 669 : 0.463 < 0.9
# LOSS train 0.5895 valid 7.1963
# Accuracy cap NOT hit at Step 670 : 0.451 < 0.9
# LOSS train 0.4136 valid 6.0141
# Accuracy cap NOT hit at Step 671 : 0.419 < 0.9
# LOSS train 0.5062 valid 4.2488
# Accuracy cap NOT hit at Step 672 : 0.393 < 0.9
# LOSS train 0.5065 valid 2.2991
# Accuracy cap NOT hit at Step 673 : 0.385 < 0.9
# LOSS train 0.6269 valid 0.9266
# Accuracy cap NOT hit at Step 674 : 0.51 < 0.9
# LOSS train 0.5240 valid 0.5407
# Accuracy cap NOT hit at Step 675 : 0.725 < 0.9
# LOSS train 0.6031 valid 0.9824
# Accuracy cap NOT hit at Step 676 : 0.487 < 0.9
# LOSS train 0.6060 valid 1.1438
# Accuracy cap NOT hit at Step 677 : 0.464 < 0.9
# LOSS train 0.6065 valid 0.7354
# Accuracy cap NOT hit at Step 678 : 0.583 < 0.9
# LOSS train 0.5028 valid 0.7601
# Accuracy cap NOT hit at Step 679 : 0.564 < 0.9
# LOSS train 0.4760 valid 0.6637
# Accuracy cap NOT hit at Step 680 : 0.599 < 0.9
# LOSS train 0.5212 valid 0.5671
# Accuracy cap NOT hit at Step 681 : 0.672 < 0.9
# LOSS train 0.4191 valid 0.5097
# Accuracy cap NOT hit at Step 682 : 0.738 < 0.9
# LOSS train 0.6841 valid 0.5443
# Accuracy cap NOT hit at Step 683 : 0.721 < 0.9
# LOSS train 0.5628 valid 1.0366
# Accuracy cap NOT hit at Step 684 : 0.525 < 0.9
# LOSS train 0.4942 valid 2.4974
# Accuracy cap NOT hit at Step 685 : 0.394 < 0.9
# LOSS train 0.5006 valid 4.1031
# Accuracy cap NOT hit at Step 686 : 0.405 < 0.9
# LOSS train 0.5687 valid 3.6102
# Accuracy cap NOT hit at Step 687 : 0.4 < 0.9
# LOSS train 0.6471 valid 2.8985
# Accuracy cap NOT hit at Step 688 : 0.423 < 0.9
# LOSS train 0.4403 valid 3.0478
# Accuracy cap NOT hit at Step 689 : 0.451 < 0.9
# ...
# Accuracy cap NOT hit at Step 1204 : 0.481 < 0.9
# LOSS train 0.3831 valid 19.9069
# Accuracy cap NOT hit at Step 1205 : 0.487 < 0.9
# LOSS train 0.2952 valid 21.6193
# Accuracy cap NOT hit at Step 1206 : 0.491 < 0.9
# LOSS train 0.5859 valid 21.2378
# Accuracy cap NOT hit at Step 1207 : 0.484 < 0.9
# LOSS train 0.3169 valid 19.6471
# Accuracy cap NOT hit at Step 1208 : 0.48 < 0.9
# LOSS train 0.3618 valid 17.8725
# Accuracy cap NOT hit at Step 1209 : 0.473 < 0.9
# LOSS train 0.4839 valid 15.2433
# Accuracy cap NOT hit at Step 1210 : 0.464 < 0.9
# LOSS train 0.4644 valid 11.2783
# Accuracy cap NOT hit at Step 1211 : 0.456 < 0.9
# LOSS train 0.4480 valid 8.4060
# Accuracy cap NOT hit at Step 1212 : 0.43 < 0.9
# LOSS train 0.4410 valid 6.0429
# Accuracy cap NOT hit at Step 1213 : 0.403 < 0.9
# LOSS train 0.4206 valid 4.8785
# Accuracy cap NOT hit at Step 1214 : 0.392 < 0.9
# LOSS train 0.3388 valid 4.2258
# Accuracy cap NOT hit at Step 1215 : 0.399 < 0.9
# LOSS train 0.2951 valid 3.0052
# Accuracy cap NOT hit at Step 1216 : 0.386 < 0.9
# LOSS train 0.4418 valid 1.6902
# Accuracy cap NOT hit at Step 1217 : 0.42 < 0.9
# LOSS train 0.2784 valid 0.9093
# Accuracy cap NOT hit at Step 1218 : 0.529 < 0.9
# LOSS train 0.2827 valid 0.5908
# Accuracy cap NOT hit at Step 1219 : 0.68 < 0.9
# LOSS train 0.3602 valid 0.4802
# Accuracy cap NOT hit at Step 1220 : 0.765 < 0.9
# LOSS train 0.4617 valid 0.4733
# Accuracy cap NOT hit at Step 1221 : 0.765 < 0.9
# LOSS train 0.4702 valid 0.6341
# Accuracy cap NOT hit at Step 1222 : 0.633 < 0.9
# LOSS train 0.3288 valid 0.6514
# Accuracy cap NOT hit at Step 1223 : 0.632 < 0.9
# LOSS train 0.2704 valid 0.6490
# Accuracy cap NOT hit at Step 1224 : 0.638 < 0.9
# LOSS train 0.4866 valid 0.6511
# Accuracy cap NOT hit at Step 1225 : 0.647 < 0.9
# LOSS train 0.3070 valid 0.7196
# Accuracy cap NOT hit at Step 1226 : 0.612 < 0.9
# LOSS train 0.1766 valid 0.6805
# Accuracy cap NOT hit at Step 1227 : 0.649 < 0.9
# LOSS train 0.4477 valid 0.5006
# Accuracy cap NOT hit at Step 1228 : 0.748 < 0.9
# LOSS train 0.4255 valid 0.4609
# Accuracy cap NOT hit at Step 1229 : 0.771 < 0.9
# LOSS train 0.4232 valid 0.3243
# Accuracy cap NOT hit at Step 1230 : 0.862 < 0.9
# LOSS train 0.4240 valid 0.4495
# Accuracy cap NOT hit at Step 1231 : 0.787 < 0.9
# LOSS train 0.4851 valid 1.0246
# Accuracy cap NOT hit at Step 1232 : 0.492 < 0.9
# LOSS train 0.4404 valid 2.1497
# Accuracy cap NOT hit at Step 1233 : 0.447 < 0.9
# LOSS train 0.3703 valid 3.2327
# Accuracy cap NOT hit at Step 1234 : 0.465 < 0.9
# LOSS train 0.2350 valid 4.2287
# Accuracy cap NOT hit at Step 1235 : 0.481 < 0.9
# LOSS train 0.3752 valid 5.1804
# Accuracy cap NOT hit at Step 1236 : 0.49 < 0.9
# LOSS train 0.5449 valid 6.6746
# Accuracy cap NOT hit at Step 1237 : 0.496 < 0.9
# LOSS train 0.3610 valid 6.4916
# Accuracy cap NOT hit at Step 1238 : 0.488 < 0.9
# LOSS train 0.3135 valid 3.5044
# Accuracy cap NOT hit at Step 1239 : 0.451 < 0.9
# LOSS train 0.6149 valid 0.9135
# Accuracy cap NOT hit at Step 1240 : 0.626 < 0.9
# LOSS train 0.2642 valid 0.3243
# Accuracy cap NOT hit at Step 1241 : 0.859 < 0.9
# LOSS train 0.4648 valid 0.5952
# Accuracy cap NOT hit at Step 1242 : 0.725 < 0.9
# LOSS train 0.2889 valid 1.1976
# Accuracy cap NOT hit at Step 1243 : 0.494 < 0.9
# LOSS train 0.3748 valid 2.5960
# Accuracy cap NOT hit at Step 1244 : 0.38 < 0.9
# LOSS train 0.3846 valid 4.5495
# Accuracy cap NOT hit at Step 1245 : 0.385 < 0.9
# LOSS train 0.3458 valid 7.0814
# Accuracy cap NOT hit at Step 1246 : 0.425 < 0.9
# LOSS train 0.4479 valid 10.0264
# Accuracy cap NOT hit at Step 1247 : 0.459 < 0.9
# LOSS train 0.4459 valid 11.5737
# Accuracy cap NOT hit at Step 1248 : 0.466 < 0.9
# LOSS train 0.3915 valid 12.0216
# Accuracy cap NOT hit at Step 1249 : 0.469 < 0.9
# LOSS train 0.3370 valid 10.6361
# Accuracy cap NOT hit at Step 1250 : 0.464 < 0.9
# EPOCH 6:
# LOSS train 0.3474 valid 2.3044
# Accuracy cap NOT hit at Step 1251 : 0.478 < 0.9
# LOSS train 0.4689 valid 2.1346
# Accuracy cap NOT hit at Step 1252 : 0.449 < 0.9
# LOSS train 0.4241 valid 6.9207
# Accuracy cap NOT hit at Step 1253 : 0.493 < 0.9
# LOSS train 0.2197 valid 8.7508
# Accuracy cap NOT hit at Step 1254 : 0.5 < 0.9
# LOSS train 0.4110 valid 9.3255
# Accuracy cap NOT hit at Step 1255 : 0.5 < 0.9
# LOSS train 0.5474 valid 9.6541
# Accuracy cap NOT hit at Step 1256 : 0.501 < 0.9
# LOSS train 0.3807 valid 9.7034
# Accuracy cap NOT hit at Step 1257 : 0.501 < 0.9
# LOSS train 0.2641 valid 9.1181
# Accuracy cap NOT hit at Step 1258 : 0.501 < 0.9
# LOSS train 0.6347 valid 7.8644
# Accuracy cap NOT hit at Step 1259 : 0.501 < 0.9
# LOSS train 0.3021 valid 7.0902
# Accuracy cap NOT hit at Step 1260 : 0.501 < 0.9
# LOSS train 0.3293 valid 6.6357
# Accuracy cap NOT hit at Step 1261 : 0.501 < 0.9
# LOSS train 0.3005 valid 5.9120
# Accuracy cap NOT hit at Step 1262 : 0.5 < 0.9
# LOSS train 0.4386 valid 5.0919
# Accuracy cap NOT hit at Step 1263 : 0.499 < 0.9
# LOSS train 0.1852 valid 4.4788
# Accuracy cap NOT hit at Step 1264 : 0.498 < 0.9
# LOSS train 0.4483 valid 4.3634
# Accuracy cap NOT hit at Step 1265 : 0.498 < 0.9
# LOSS train 0.6944 valid 4.2133
# Accuracy cap NOT hit at Step 1266 : 0.498 < 0.9
# LOSS train 0.9743 valid 0.4134
# Accuracy cap NOT hit at Step 1267 : 0.824 < 0.9
# LOSS train 0.3820 valid 6.7463
# Accuracy cap NOT hit at Step 1268 : 0.389 < 0.9
# LOSS train 0.2915 valid 20.0538
# Accuracy cap NOT hit at Step 1269 : 0.472 < 0.9
# LOSS train 0.2764 valid 33.8034
# Accuracy cap NOT hit at Step 1270 : 0.488 < 0.9
# LOSS train 0.4221 valid 45.8226
# Accuracy cap NOT hit at Step 1271 : 0.497 < 0.9
# LOSS train 0.2486 valid 56.0293
# Accuracy cap NOT hit at Step 1272 : 0.499 < 0.9
# LOSS train 0.4690 valid 55.6525
# Accuracy cap NOT hit at Step 1273 : 0.499 < 0.9
# LOSS train 0.4087 valid 47.8682
# Accuracy cap NOT hit at Step 1274 : 0.499 < 0.9
# LOSS train 0.5343 valid 37.5772
# Accuracy cap NOT hit at Step 1275 : 0.496 < 0.9
# LOSS train 0.4546 valid 29.9193
# Accuracy cap NOT hit at Step 1276 : 0.493 < 0.9
# LOSS train 0.4182 valid 22.4569
# Accuracy cap NOT hit at Step 1277 : 0.483 < 0.9
# LOSS train 0.3666 valid 16.2580
# Accuracy cap NOT hit at Step 1278 : 0.478 < 0.9
# LOSS train 0.4574 valid 12.4676
# Accuracy cap NOT hit at Step 1279 : 0.467 < 0.9
# LOSS train 0.5245 valid 7.5258
# Accuracy cap NOT hit at Step 1280 : 0.436 < 0.9
# LOSS train 0.9680 valid 4.0902
# Accuracy cap NOT hit at Step 1281 : 0.402 < 0.9
# LOSS train 0.2879 valid 1.6432
# Accuracy cap NOT hit at Step 1282 : 0.407 < 0.9
# LOSS train 0.3199 valid 0.6536
# Accuracy cap NOT hit at Step 1283 : 0.646 < 0.9
# LOSS train 0.2507 valid 0.4382
# Accuracy cap NOT hit at Step 1284 : 0.794 < 0.9
# LOSS train 0.3630 valid 0.3736
# Accuracy cap NOT hit at Step 1285 : 0.845 < 0.9
# LOSS train 0.4126 valid 0.3294
# Accuracy cap NOT hit at Step 1286 : 0.876 < 0.9
# LOSS train 0.3182 valid 0.3249
# Accuracy cap NOT hit at Step 1287 : 0.866 < 0.9
# LOSS train 0.3309 valid 0.3373
# Accuracy cap NOT hit at Step 1288 : 0.862 < 0.9
# LOSS train 0.3069 valid 0.3477
# Accuracy cap NOT hit at Step 1289 : 0.856 < 0.9
# LOSS train 0.2669 valid 0.3743
# Accuracy cap NOT hit at Step 1290 : 0.841 < 0.9
# LOSS train 0.3592 valid 0.3696
# Accuracy cap NOT hit at Step 1291 : 0.835 < 0.9
# LOSS train 0.2745 valid 0.3806
# Accuracy cap NOT hit at Step 1292 : 0.826 < 0.9
# LOSS train 0.2499 valid 0.3796
# Accuracy cap NOT hit at Step 1293 : 0.814 < 0.9
# LOSS train 0.3917 valid 0.3361
# Accuracy cap NOT hit at Step 1294 : 0.853 < 0.9
# LOSS train 0.3885 valid 0.3188
# Accuracy cap NOT hit at Step 1295 : 0.865 < 0.9
# LOSS train 0.2394 valid 0.3110
# Accuracy cap NOT hit at Step 1296 : 0.866 < 0.9
# LOSS train 0.2560 valid 0.3162
# Accuracy cap NOT hit at Step 1297 : 0.875 < 0.9
# LOSS train 0.5240 valid 0.3554
# Accuracy cap NOT hit at Step 1298 : 0.857 < 0.9
# LOSS train 0.3157 valid 0.3610
# Accuracy cap NOT hit at Step 1299 : 0.852 < 0.9
# LOSS train 0.3101 valid 0.3610
# Accuracy cap NOT hit at Step 1300 : 0.857 < 0.9
# LOSS train 0.3836 valid 0.3675
# Accuracy cap NOT hit at Step 1301 : 0.853 < 0.9
# LOSS train 0.2944 valid 0.3641
# Accuracy cap NOT hit at Step 1302 : 0.853 < 0.9
# LOSS train 0.4439 valid 0.3462
# Accuracy cap NOT hit at Step 1303 : 0.858 < 0.9
# LOSS train 0.4305 valid 0.3339
# Accuracy cap NOT hit at Step 1304 : 0.859 < 0.9
# LOSS train 0.2130 valid 0.3247
# Accuracy cap NOT hit at Step 1305 : 0.862 < 0.9
# LOSS train 0.2120 valid 0.3400
# Accuracy cap NOT hit at Step 1306 : 0.851 < 0.9
# LOSS train 0.4499 valid 0.3460
# Accuracy cap NOT hit at Step 1307 : 0.853 < 0.9
# LOSS train 0.3723 valid 0.4335
# Accuracy cap NOT hit at Step 1308 : 0.814 < 0.9
# LOSS train 0.2206 valid 0.7083
# Accuracy cap NOT hit at Step 1309 : 0.618 < 0.9
# LOSS train 0.3151 valid 1.4940
# Accuracy cap NOT hit at Step 1310 : 0.428 < 0.9
# LOSS train 0.3857 valid 2.3331
# Accuracy cap NOT hit at Step 1311 : 0.444 < 0.9
# LOSS train 0.3490 valid 2.9161
# Accuracy cap NOT hit at Step 1312 : 0.455 < 0.9
# LOSS train 0.2856 valid 3.3592
# Accuracy cap NOT hit at Step 1313 : 0.47 < 0.9
# LOSS train 0.3799 valid 3.5993
# Accuracy cap NOT hit at Step 1314 : 0.47 < 0.9
# LOSS train 0.4151 valid 3.6195
# Accuracy cap NOT hit at Step 1315 : 0.466 < 0.9
# LOSS train 0.3172 valid 3.5402
# Accuracy cap NOT hit at Step 1316 : 0.456 < 0.9
# LOSS train 0.3820 valid 3.0193
# Accuracy cap NOT hit at Step 1317 : 0.448 < 0.9
# LOSS train 0.7214 valid 0.6177
# Accuracy cap NOT hit at Step 1318 : 0.681 < 0.9
# LOSS train 0.3003 valid 0.3541
# Accuracy cap NOT hit at Step 1319 : 0.842 < 0.9
# LOSS train 0.4671 valid 0.8804
# Accuracy cap NOT hit at Step 1320 : 0.587 < 0.9
# LOSS train 0.3495 valid 1.5665
# Accuracy cap NOT hit at Step 1321 : 0.441 < 0.9
# LOSS train 0.4523 valid 1.7235
# Accuracy cap NOT hit at Step 1322 : 0.417 < 0.9
# LOSS train 0.2647 valid 1.6888
# Accuracy cap NOT hit at Step 1323 : 0.412 < 0.9
# LOSS train 0.5793 valid 2.6838
# Accuracy cap NOT hit at Step 1324 : 0.345 < 0.9
# LOSS train 0.2023 valid 3.4531
# Accuracy cap NOT hit at Step 1325 : 0.342 < 0.9
# LOSS train 0.2320 valid 4.0526
# Accuracy cap NOT hit at Step 1326 : 0.347 < 0.9
# LOSS train 0.5505 valid 4.9552
# Accuracy cap NOT hit at Step 1327 : 0.37 < 0.9
# LOSS train 0.4423 valid 5.1520
# Accuracy cap NOT hit at Step 1328 : 0.373 < 0.9
# LOSS train 0.4174 valid 5.5912
# Accuracy cap NOT hit at Step 1329 : 0.38 < 0.9
# LOSS train 0.3416 valid 6.0477
# Accuracy cap NOT hit at Step 1330 : 0.391 < 0.9
# LOSS train 0.3944 valid 5.9464
# Accuracy cap NOT hit at Step 1331 : 0.396 < 0.9
# LOSS train 0.3139 valid 5.4056
# Accuracy cap NOT hit at Step 1332 : 0.393 < 0.9
# LOSS train 0.3394 valid 4.6826
# Accuracy cap NOT hit at Step 1333 : 0.383 < 0.9
# LOSS train 0.4795 valid 3.5755
# Accuracy cap NOT hit at Step 1334 : 0.388 < 0.9
# LOSS train 0.4282 valid 2.2483
# Accuracy cap NOT hit at Step 1335 : 0.399 < 0.9
# LOSS train 0.3969 valid 1.0934
# Accuracy cap NOT hit at Step 1336 : 0.492 < 0.9
# LOSS train 0.4425 valid 0.5056
# Accuracy cap NOT hit at Step 1337 : 0.711 < 0.9
# LOSS train 0.3279 valid 0.3729
# Accuracy cap NOT hit at Step 1338 : 0.826 < 0.9
# LOSS train 0.5334 valid 1.1566
# Accuracy cap NOT hit at Step 1339 : 0.522 < 0.9
# LOSS train 0.2727 valid 2.2072
# Accuracy cap NOT hit at Step 1340 : 0.473 < 0.9
# LOSS train 0.2349 valid 2.7294
# Accuracy cap NOT hit at Step 1341 : 0.472 < 0.9
# LOSS train 0.3251 valid 3.1561
# Accuracy cap NOT hit at Step 1342 : 0.472 < 0.9
# LOSS train 0.2976 valid 3.4670
# Accuracy cap NOT hit at Step 1343 : 0.476 < 0.9
# LOSS train 0.3875 valid 3.6593
# Accuracy cap NOT hit at Step 1344 : 0.479 < 0.9
# LOSS train 0.3361 valid 3.5984
# Accuracy cap NOT hit at Step 1345 : 0.479 < 0.9
# LOSS train 0.2356 valid 3.5550
# Accuracy cap NOT hit at Step 1346 : 0.474 < 0.9
# LOSS train 0.3893 valid 3.5366
# Accuracy cap NOT hit at Step 1347 : 0.47 < 0.9
# LOSS train 0.3337 valid 3.7013
# Accuracy cap NOT hit at Step 1348 : 0.472 < 0.9
# LOSS train 0.2379 valid 3.9120
# Accuracy cap NOT hit at Step 1349 : 0.474 < 0.9
# LOSS train 0.1768 valid 3.8491
# Accuracy cap NOT hit at Step 1350 : 0.471 < 0.9
# LOSS train 0.2231 valid 4.0707
# Accuracy cap NOT hit at Step 1351 : 0.473 < 0.9
# LOSS train 0.4902 valid 4.3259
# Accuracy cap NOT hit at Step 1352 : 0.473 < 0.9
# LOSS train 0.2352 valid 4.8375
# Accuracy cap NOT hit at Step 1353 : 0.476 < 0.9
# LOSS train 0.3256 valid 5.2414
# Accuracy cap NOT hit at Step 1354 : 0.482 < 0.9
# LOSS train 0.3913 valid 5.3031
# Accuracy cap NOT hit at Step 1355 : 0.48 < 0.9
# LOSS train 0.3440 valid 4.9037
# Accuracy cap NOT hit at Step 1356 : 0.475 < 0.9
# LOSS train 0.3149 valid 4.8559
# Accuracy cap NOT hit at Step 1357 : 0.477 < 0.9
# LOSS train 0.2411 valid 4.8062
# Accuracy cap NOT hit at Step 1358 : 0.475 < 0.9
# LOSS train 0.4073 valid 4.4967
# Accuracy cap NOT hit at Step 1359 : 0.472 < 0.9
# LOSS train 0.2037 valid 4.3885
# Accuracy cap NOT hit at Step 1360 : 0.472 < 0.9
# LOSS train 0.2071 valid 4.0345
# Accuracy cap NOT hit at Step 1361 : 0.466 < 0.9
# LOSS train 0.3854 valid 3.8434
# Accuracy cap NOT hit at Step 1362 : 0.461 < 0.9
# LOSS train 0.2790 valid 3.7181
# Accuracy cap NOT hit at Step 1363 : 0.458 < 0.9
# LOSS train 0.2376 valid 4.0307
# Accuracy cap NOT hit at Step 1364 : 0.465 < 0.9
# LOSS train 0.3425 valid 3.9851
# Accuracy cap NOT hit at Step 1365 : 0.467 < 0.9
# LOSS train 0.3106 valid 4.1902
# Accuracy cap NOT hit at Step 1366 : 0.47 < 0.9
# LOSS train 0.1388 valid 4.2527
# Accuracy cap NOT hit at Step 1367 : 0.472 < 0.9
# LOSS train 0.2568 valid 3.8727
# Accuracy cap NOT hit at Step 1368 : 0.469 < 0.9
# LOSS train 0.4005 valid 3.4872
# Accuracy cap NOT hit at Step 1369 : 0.463 < 0.9
# LOSS train 0.2534 valid 3.0490
# Accuracy cap NOT hit at Step 1370 : 0.454 < 0.9
# LOSS train 0.2540 valid 2.5934
# Accuracy cap NOT hit at Step 1371 : 0.441 < 0.9
# LOSS train 0.1827 valid 2.8947
# Accuracy cap NOT hit at Step 1372 : 0.446 < 0.9
# LOSS train 0.2149 valid 3.4133
# Accuracy cap NOT hit at Step 1373 : 0.459 < 0.9
# LOSS train 0.2104 valid 3.6065
# Accuracy cap NOT hit at Step 1374 : 0.462 < 0.9
# LOSS train 0.3405 valid 3.1992
# Accuracy cap NOT hit at Step 1375 : 0.449 < 0.9
# LOSS train 0.1817 valid 2.4445
# Accuracy cap NOT hit at Step 1376 : 0.453 < 0.9
# LOSS train 0.2510 valid 1.6716
# Accuracy cap NOT hit at Step 1377 : 0.47 < 0.9
# LOSS train 0.2677 valid 0.5075
# Accuracy cap NOT hit at Step 1378 : 0.734 < 0.9
# LOSS train 0.3600 valid 0.2785
# Accuracy cap NOT hit at Step 1379 : 0.889 < 0.9
# LOSS train 0.1786 valid 0.3659
# Accuracy cap NOT hit at Step 1380 : 0.83 < 0.9
# LOSS train 0.3322 valid 0.3898
# Accuracy cap NOT hit at Step 1381 : 0.819 < 0.9
# LOSS train 0.1653 valid 0.3462
# Accuracy cap NOT hit at Step 1382 : 0.848 < 0.9
# LOSS train 0.3340 valid 0.2873
# Accuracy cap NOT hit at Step 1383 : 0.881 < 0.9
# LOSS train 0.4811 valid 0.2416
# Accuracy cap hit at Step 1384 : 0.908 >= 0.9
# Training complete
# Loading dataset content for hard_6_blue_circles_times2_triangles_train.csv
# 100%|██████████| 8000/8000 [01:02<00:00, 127.07it/s]
#   1%|          | 7/1000 [00:00<00:15, 66.04it/s]
# Loading dataset content for hard_6_blue_circles_times2_triangles_test.csv
# 100%|██████████| 1000/1000 [00:12<00:00, 80.46it/s]
#   1%|▏         | 13/1000 [00:00<00:07, 127.62it/s]
# Loading dataset content for hard_6_blue_circles_times2_triangles_valid.csv
# 100%|██████████| 1000/1000 [00:07<00:00, 128.10it/s]
# Using cache found in /home/docker/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/docker/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/docker/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 100%|██████████| 1/1 [33:54<00:00, 2034.59s/it]
# {'train': {'accuracy': 0.932375, 'precision': 0.8978605935127675, 'recall': 0.97575, 'roc_auc': 0.9712909062499999, 'confusion matrix': {'TN': 3556, 'FP': 97, 'FN': 444, 'TP': 3903}}, 'test': {'accuracy': 0.928, 'precision': 0.8905109489051095, 'recall': 0.976, 'roc_auc': 0.967144, 'confusion matrix': {'TN': 440, 'FP': 12, 'FN': 60, 'TP': 488}}, 'valid': {'accuracy': 0.908, 'precision': 0.8604240282685512, 'recall': 0.974, 'roc_auc': 0.950916, 'confusion matrix': {'TN': 421, 'FP': 13, 'FN': 79, 'TP': 487}}}
