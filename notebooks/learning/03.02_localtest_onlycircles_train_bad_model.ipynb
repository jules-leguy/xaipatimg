# %%
import os

db_dir = os.environ["DATA"] + "PatImgXAI_data/dblocaltest0.1/"

train_dataset_filename = "rowcircles_train.csv"
test_dataset_filename = "rowcircles_test.csv"
valid_dataset_filename = "rowcircles_valid.csv"
model_dir = os.environ["DATA"] + "models/db_vlocaltest0.1/rowcircles_bad/"

device = "cuda:0"

# %%
from xaipatimg.ml.learning import train_resnet18_model

train_resnet18_model(db_dir, train_dataset_filename, valid_dataset_filename, model_dir, device=device, training_epochs=12)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:21<00:00, 166.66it/s]
# Train dataset statistics : [0.9718954563140869, 0.965693473815918, 0.9544402956962585] [0.10828889906406403, 0.10895111411809921, 0.13822771608829498]
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:23<00:00, 151.32it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 185.66it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# EPOCH 1:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 2.0734086829423903
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 2.0734086829423903 valid 0.6979039311408997
# EPOCH 2:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.7002556174993515
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.7002556174993515 valid 0.6932555437088013
# EPOCH 3:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.6933127629756928
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.6933127629756928 valid 0.6903892159461975
# EPOCH 4:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.6967563444375992
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.6967563444375992 valid 0.6901229619979858
# EPOCH 5:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.6898659378290176
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.6898659378290176 valid 0.7393513917922974
# EPOCH 6:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.6975502902269364
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.6975502902269364 valid 0.6841645836830139
# EPOCH 7:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.6775970882177353
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.6775970882177353 valid 0.7230859994888306
# EPOCH 8:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.6517695796489715
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.6517695796489715 valid 0.8828414082527161
# EPOCH 9:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.5998674523830414
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.5998674523830414 valid 0.5322233438491821
# EPOCH 10:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.4297691258788109
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.4297691258788109 valid 0.30742356181144714
# EPOCH 11:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.19597914366051555
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.19597914366051555 valid 0.251112699508667
# EPOCH 12:
# newbatch 0
# newbatch 1
# newbatch 2
# newbatch 3
# newbatch 4
# newbatch 5
# newbatch 6
# newbatch 7
# newbatch 8
# newbatch 9
# newbatch 10
# newbatch 11
# newbatch 12
# newbatch 13
# newbatch 14
# newbatch 15
# newbatch 16
# newbatch 17
# newbatch 18
# newbatch 19
# newbatch 20
# newbatch 21
# newbatch 22
# newbatch 23
# newbatch 24
# newbatch 25
# newbatch 26
# newbatch 27
# newbatch 28
# newbatch 29
# newbatch 30
# newbatch 31
# newbatch 32
# newbatch 33
# newbatch 34
# newbatch 35
# newbatch 36
# newbatch 37
# newbatch 38
# newbatch 39
# newbatch 40
# newbatch 41
# newbatch 42
# newbatch 43
# newbatch 44
# newbatch 45
# newbatch 46
# newbatch 47
# newbatch 48
# newbatch 49
# newbatch 50
# newbatch 51
# newbatch 52
# newbatch 53
# newbatch 54
# newbatch 55
# newbatch 56
# newbatch 57
# newbatch 58
# newbatch 59
# newbatch 60
# newbatch 61
# newbatch 62
# newbatch 63
# newbatch 64
# newbatch 65
# newbatch 66
# newbatch 67
# newbatch 68
# newbatch 69
# newbatch 70
# newbatch 71
# newbatch 72
# newbatch 73
# newbatch 74
# newbatch 75
# newbatch 76
# newbatch 77
# newbatch 78
# newbatch 79
# newbatch 80
# newbatch 81
# newbatch 82
# newbatch 83
# newbatch 84
# newbatch 85
# newbatch 86
# newbatch 87
# newbatch 88
# newbatch 89
# newbatch 90
# newbatch 91
# newbatch 92
# newbatch 93
# newbatch 94
# newbatch 95
# newbatch 96
# newbatch 97
# newbatch 98
# newbatch 99
#   batch 100 loss: 0.11625908276066184
# newbatch 100
# newbatch 101
# newbatch 102
# newbatch 103
# newbatch 104
# newbatch 105
# newbatch 106
# newbatch 107
# newbatch 108
# newbatch 109
# newbatch 110
# newbatch 111
# newbatch 112
# LOSS train 0.11625908276066184 valid 1.6867268085479736

# %%
from xaipatimg.ml.learning import compute_resnet18_model_scores

compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:25<00:00, 141.31it/s]
# Loading dataset content for rowcircles_test.csv
# 100%|██████████| 200/200 [00:01<00:00, 160.60it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 108.64it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# {'train': {'accuracy': 0.9388888888888889, 'precision': 0.9118873826903025, 'recall': 0.9716666666666667, 'roc_auc': 0.97835, 'confusion matrix': {'TN': 1631, 'FP': 51, 'FN': 169, 'TP': 1749}}, 'test': {'accuracy': 0.94, 'precision': 0.9074074074074074, 'recall': 0.98, 'roc_auc': 0.9846, 'confusion matrix': {'TN': 90, 'FP': 2, 'FN': 10, 'TP': 98}}, 'valid': {'accuracy': 0.905, 'precision': 0.8785046728971962, 'recall': 0.94, 'roc_auc': 0.964, 'confusion matrix': {'TN': 87, 'FP': 6, 'FN': 13, 'TP': 94}}}
# {'train': {'accuracy': 0.9388888888888889,
#   'precision': 0.9118873826903025,
#   'recall': 0.9716666666666667,
#   'roc_auc': 0.97835,
#   'confusion matrix': {'TN': 1631, 'FP': 51, 'FN': 169, 'TP': 1749}},
#  'test': {'accuracy': 0.94,
#   'precision': 0.9074074074074074,
#   'recall': 0.98,
#   'roc_auc': 0.9846,
#   'confusion matrix': {'TN': 90, 'FP': 2, 'FN': 10, 'TP': 98}},
#  'valid': {'accuracy': 0.905,
#   'precision': 0.8785046728971962,
#   'recall': 0.94,
#   'roc_auc': 0.964,
#   'confusion matrix': {'TN': 87, 'FP': 6, 'FN': 13, 'TP': 94}}}
