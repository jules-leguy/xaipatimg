# %%
import os

db_dir = os.environ["DATA"] + "PatImgXAI_data/dblocaltest0.1/"

train_dataset_filename = "rowcircles_train.csv"
test_dataset_filename = "rowcircles_test.csv"
valid_dataset_filename = "rowcircles_valid.csv"
model_dir = os.environ["DATA"] + "models/db_vlocaltest0.1/rowcircles/"

device = "cuda:0"

# %%
from xaipatimg.ml.learning import train_resnet18_model

train_resnet18_model(db_dir, train_dataset_filename, valid_dataset_filename, model_dir, device=device, training_epochs=40)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:21<00:00, 164.17it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from xaipatimg.ml.learning import train_resnet18_model
# ----> 3 train_resnet18_model(db_dir, train_dataset_filename, valid_dataset_filename, model_dir, device=device, training_epochs=40)
#
# File ~/Documents/postdoc/git_repos/xaipatimg/xaipatimg/ml/learning.py:166, in train_resnet18_model(db_dir, train_dataset_filename, valid_dataset_filename, model_dir, device, training_epochs, lr, momentum, weight_decay, batch_size, lr_step_size, lr_gamma, train_loss_write_period_logs)
#     163 os.makedirs(model_dir, exist_ok=True)
#     165 # Computing training dataset means and stds
# --> 166 means, stds = compute_mean_std_dataset(db_dir, train_dataset_filename, resnet18_preprocess_no_norm)
#     167 print("Train dataset statistics : " + str(means) + " " + str(stds))
#     169 # Writing training set statistics to file
#
# File ~/Documents/postdoc/git_repos/xaipatimg/xaipatimg/ml/learning.py:98, in compute_mean_std_dataset(db_dir, dataset_filename, preprocess_no_norm)
#      90 """
#      91 Compute the mean and std of the transformed dataset.
#      92 :param db_dir: root of the db
#    (...)
#      95 :return: tuple ([mean on every channel], [std on every channel])
#      96 """
#      97 dataset_no_norm = PatImgDataset(db_dir, dataset_filename, transform=preprocess_no_norm)
# ---> 98 alldata_no_norm = np.array([dataset_no_norm[i][0] for i in range(len(dataset_no_norm))])
#      99 means = [np.mean(x).astype(float) for x in
#     100          [alldata_no_norm[:, channel, :] for channel in range(alldata_no_norm.shape[1])]]
#     101 stds = [np.std(x).astype(float) for x in
#     102         [alldata_no_norm[:, channel, :] for channel in range(alldata_no_norm.shape[1])]]
#
# KeyboardInterrupt:

# %%
from xaipatimg.ml.learning import compute_resnet18_model_scores

compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:22<00:00, 161.76it/s]
# Loading dataset content for rowcircles_test.csv
# 100%|██████████| 200/200 [00:01<00:00, 165.39it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 135.04it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# {'train': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}}, 'test': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}, 'valid': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
# {'train': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}},
#  'test': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}},
#  'valid': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}

# %%
from xaipatimg.ml.learning import compute_resnet18_model_scores

compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:22<00:00, 161.76it/s]
# Loading dataset content for rowcircles_test.csv
# 100%|██████████| 200/200 [00:01<00:00, 165.39it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 135.04it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# {'train': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}}, 'test': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}, 'valid': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
# {'train': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}},
#  'test': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}},
#  'valid': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}

# %%
from xaipatimg.ml.learning import compute_resnet18_model_scores

compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:22<00:00, 161.76it/s]
# Loading dataset content for rowcircles_test.csv
# 100%|██████████| 200/200 [00:01<00:00, 165.39it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 135.04it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# {'train': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}}, 'test': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}, 'valid': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
# {'train': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}},
#  'test': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}},
#  'valid': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}

# %%
from xaipatimg.ml.learning import compute_resnet18_model_scores

compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:22<00:00, 161.76it/s]
# Loading dataset content for rowcircles_test.csv
# 100%|██████████| 200/200 [00:01<00:00, 165.39it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 135.04it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# {'train': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}}, 'test': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}, 'valid': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
# {'train': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}},
#  'test': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}},
#  'valid': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
