# %%
import os

db_dir = os.environ["DATA"] + "PatImgXAI_data/db2.0.0/"
model_dir_root = os.environ["DATA"] + "models/db2.0.0/"
devices = ["cuda:0", "cuda:1"]
TARGET_ACCURACY = 0.8
INTERVAL_BATCH = 1

# %%
# Number of images generated
NBGEN = 1000000

# Grid division of each image
X_DIVISIONS = 6
Y_DIVISIONS = 6

# Size of the images in pixels
img_size = (700, 700)

# Probability to generate a geometrical shape at each position in the grid
SHAPE_PROB = 0.5

# Define available shapes
SHAPES = ['circle', 'square', 'triangle']
COLORS  = ["#A33E9A", "#E0B000", "#0C90C0"]

# %%
from xaipatimg.datagen.gendataset import generic_rule_exist_row_with_only_shape, generic_rule_N_times_color_exactly, \
    generic_rule_shape_color_plus_shape_equals_N, generic_rule_exist_row_with_only_color_and_col_with_only_shape

rules_data = [
    {"name": "easy_1_6_blue", "gen_fun": generic_rule_N_times_color_exactly, "gen_kwargs": {"color": "#0C90C0", "N": 6, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}},
    {"name": "easy_2_row_circle", "gen_fun": generic_rule_exist_row_with_only_shape, "gen_kwargs": {"shape": "circle", "y_division": Y_DIVISIONS}},
    # {"name": "easy_3_7_purple", "gen_fun": generic_rule_N_times_color_exactly, "gen_kwargs": {"color": "#A33E9A", "N": 7, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}},
    # {"name": "easy_4_row_triangle", "gen_fun": generic_rule_exist_row_with_only_shape, "gen_kwargs": {"shape": "triangle", "y_division": Y_DIVISIONS}},
    # {"name": "easy_5_7_yellow", "gen_fun": generic_rule_N_times_color_exactly, "gen_kwargs": {"color": "#E0B000", "N": 5, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}},
    # {"name": "easy_6_row_square", "gen_fun": generic_rule_exist_row_with_only_shape, "gen_kwargs": {"shape": "square", "y_division": Y_DIVISIONS}},
    #
    # {"name": "hard_1_blue_square_plus_circle_8", "gen_fun": generic_rule_shape_color_plus_shape_equals_N, "gen_kwargs": {"color1": "#0C90C0", "shape1": "square", "shape2": "circle", "N": 8, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}},
    # {"name": "hard_2_row_purple_col_triangle", "gen_fun": generic_rule_exist_row_with_only_color_and_col_with_only_shape, "gen_kwargs": {"color": "#A33E9A", "shape": "triangle" ,"x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}},
    # {"name": "hard_3_yellow_circle_plus_triangle_9", "gen_fun": generic_rule_shape_color_plus_shape_equals_N, "gen_kwargs": {"color1": "#E0B000", "shape1": "circle", "shape2": "triangle", "N": 9, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}},
    # {"name": "hard_4_row_yellow_col_circle", "gen_fun": generic_rule_exist_row_with_only_color_and_col_with_only_shape, "gen_kwargs": {"color": "#E0B000", "shape": "circle" ,"x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}},
    # {"name": "hard_5_purple_triangle_plus_square_7", "gen_fun": generic_rule_shape_color_plus_shape_equals_N, "gen_kwargs": {"color1": "#A33E9A", "shape1": "triangle", "shape2": "square", "N": 7, "x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}},
    # {"name": "hard_6_row_blue_col_square", "gen_fun": generic_rule_exist_row_with_only_color_and_col_with_only_shape, "gen_kwargs": {"color": "#0C90C0", "shape": "square" ,"x_division": X_DIVISIONS, "y_division": Y_DIVISIONS}},
]

# %%
from xaipatimg.ml.learning import train_resnet18_model, compute_resnet18_model_scores


def _train_model(db_dir, train_dataset_filename, valid_dataset_filename, test_dataset_filename, model_dir, target_accuracy, interval_batch, device):
    train_resnet18_model(db_dir, train_dataset_filename, valid_dataset_filename, model_dir, target_accuracy=target_accuracy,
                         interval_batch=interval_batch, device=device)
    compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)

# %%
from tqdm import tqdm
from joblib import Parallel, delayed

for rule_idx in tqdm(range(0, len(rules_data), 2)):
    Parallel(n_jobs=len(devices))(delayed(_train_model)(
        db_dir, # db_dir
        rules_data[rule_idx + offset]["name"] + "_train.csv", # train_dataset_filename
        rules_data[rule_idx + offset]["name"] + "_valid.csv", # valid_dataset_filename
        rules_data[rule_idx + offset]["name"] + "_test.csv", # test_dataset_filename
        os.path.join(model_dir_root, rules_data[rule_idx + offset]["name"]), # model_dir
        TARGET_ACCURACY, # target_accuracy,
        INTERVAL_BATCH, # interval_batch
        devices[offset]) for offset in [0, 1])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset content for easy_1_6_blue_train.csv
# Loading dataset content for easy_2_row_circle_train.csv
# 100%|██████████| 8000/8000 [01:03<00:00, 126.31it/s]
#  95%|█████████▍| 7587/8000 [01:01<00:03, 126.40it/s]
# Loading dataset content for easy_1_6_blue_valid.csv
# 100%|██████████| 8000/8000 [01:04<00:00, 123.89it/s]
#   1%|          | 11/1000 [00:00<00:09, 105.17it/s]
# Loading dataset content for easy_2_row_circle_valid.csv
# 100%|██████████| 1000/1000 [00:10<00:00, 97.78it/s]
# Using cache found in /home/docker/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/docker/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/docker/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
#  74%|███████▍  | 740/1000 [00:07<00:02, 98.93it/s]
# EPOCH 1:
#  92%|█████████▏| 915/1000 [00:09<00:00, 94.05it/s]
# LOSS train 0.7611 valid 8.3387
# Accuracy cap NOT hit at Step 1 : 0.5 < 0.8
#  97%|█████████▋| 974/1000 [00:11<00:00, 56.44it/s]
# LOSS train 5.7109 valid 16.7289
# Accuracy cap NOT hit at Step 2 : 0.5 < 0.8
# 100%|██████████| 1000/1000 [00:11<00:00, 84.77it/s]
# Using cache found in /home/docker/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/docker/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/docker/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# EPOCH 1:
# LOSS train 10.1425 valid 14.2983
# Accuracy cap NOT hit at Step 3 : 0.5 < 0.8
# LOSS train 4.2308 valid 79.5724
# Accuracy cap NOT hit at Step 4 : 0.5 < 0.8
# LOSS train 0.7636 valid 8.5569
# Accuracy cap NOT hit at Step 1 : 0.5 < 0.8
# LOSS train 12.0602 valid 215.3828
# Accuracy cap NOT hit at Step 5 : 0.5 < 0.8
# LOSS train 4.5931 valid 5.9198
# Accuracy cap NOT hit at Step 2 : 0.5 < 0.8
# LOSS train 15.0057 valid 405.9255
# Accuracy cap NOT hit at Step 6 : 0.5 < 0.8
# LOSS train 2.3994 valid 90.2850
# Accuracy cap NOT hit at Step 3 : 0.5 < 0.8
# LOSS train 6.9014 valid 3850.1704
# Accuracy cap NOT hit at Step 7 : 0.5 < 0.8
# LOSS train 22.4140 valid 879.5223
# Accuracy cap NOT hit at Step 4 : 0.5 < 0.8
# LOSS train 11.0876 valid 8710.8361
# Accuracy cap NOT hit at Step 8 : 0.5 < 0.8
# LOSS train 23.6601 valid 19176.9807
# Accuracy cap NOT hit at Step 5 : 0.5 < 0.8
# LOSS train 16.5667 valid 11943.7954
# Accuracy cap NOT hit at Step 9 : 0.5 < 0.8
# LOSS train 15.5576 valid 55821.6498
# Accuracy cap NOT hit at Step 6 : 0.5 < 0.8
# LOSS train 12.0576 valid 4689.2268
# Accuracy cap NOT hit at Step 10 : 0.5 < 0.8
# LOSS train 8.6035 valid 39518.0826
# Accuracy cap NOT hit at Step 7 : 0.5 < 0.8
# LOSS train 5.6444 valid 5578.6112
# Accuracy cap NOT hit at Step 11 : 0.5 < 0.8
# LOSS train 6.8228 valid 76244.3022
# Accuracy cap NOT hit at Step 8 : 0.5 < 0.8
# LOSS train 0.6082 valid 7987.5149
# Accuracy cap NOT hit at Step 12 : 0.5 < 0.8
# LOSS train 7.9630 valid 46398.6912
# Accuracy cap NOT hit at Step 9 : 0.5 < 0.8
# LOSS train 4.6180 valid 6761.8149
# Accuracy cap NOT hit at Step 13 : 0.5 < 0.8
# LOSS train 4.7566 valid 15061.7184
# Accuracy cap NOT hit at Step 10 : 0.5 < 0.8
# LOSS train 5.5516 valid 3143.7103
# Accuracy cap NOT hit at Step 14 : 0.5 < 0.8
# LOSS train 3.9259 valid 6892.3517
# Accuracy cap NOT hit at Step 11 : 0.5 < 0.8
# LOSS train 3.0206 valid 1611.2222
# Accuracy cap NOT hit at Step 15 : 0.5 < 0.8
# LOSS train 1.0827 valid 6477.4040
# Accuracy cap NOT hit at Step 12 : 0.5 < 0.8
# LOSS train 3.6134 valid 965.4178
# Accuracy cap NOT hit at Step 16 : 0.5 < 0.8
# LOSS train 3.3217 valid 1636.3366
# Accuracy cap NOT hit at Step 13 : 0.5 < 0.8
# LOSS train 2.5554 valid 338.5086
# Accuracy cap NOT hit at Step 17 : 0.5 < 0.8
# LOSS train 3.5950 valid 3393.2729
# Accuracy cap NOT hit at Step 14 : 0.5 < 0.8
# LOSS train 0.7574 valid 93.4956
# Accuracy cap NOT hit at Step 18 : 0.5 < 0.8
# LOSS train 2.1677 valid 2930.1151
# Accuracy cap NOT hit at Step 15 : 0.5 < 0.8
# LOSS train 0.7033 valid 20.4247
# Accuracy cap NOT hit at Step 19 : 0.498 < 0.8
# LOSS train 2.0464 valid 1449.9746
# Accuracy cap NOT hit at Step 16 : 0.5 < 0.8
# LOSS train 0.6261 valid 3.6112
# Accuracy cap NOT hit at Step 20 : 0.419 < 0.8
# LOSS train 2.0859 valid 642.0372
# Accuracy cap NOT hit at Step 17 : 0.5 < 0.8
# LOSS train 0.7548 valid 4.3190
# Accuracy cap NOT hit at Step 21 : 0.5 < 0.8
# LOSS train 0.9629 valid 1131.9808
# Accuracy cap NOT hit at Step 18 : 0.5 < 0.8
# LOSS train 0.9909 valid 3.2754
# Accuracy cap NOT hit at Step 22 : 0.5 < 0.8
# LOSS train 1.8493 valid 979.5092
# Accuracy cap NOT hit at Step 19 : 0.5 < 0.8
# LOSS train 0.6763 valid 1.9801
# Accuracy cap NOT hit at Step 23 : 0.5 < 0.8
# LOSS train 1.3606 valid 392.4207
# Accuracy cap NOT hit at Step 20 : 0.5 < 0.8
# LOSS train 0.9558 valid 1.2340
# Accuracy cap NOT hit at Step 24 : 0.5 < 0.8
# LOSS train 0.7630 valid 131.1693
# Accuracy cap NOT hit at Step 21 : 0.5 < 0.8
# LOSS train 0.8605 valid 0.9221
# Accuracy cap NOT hit at Step 25 : 0.5 < 0.8
# LOSS train 0.8855 valid 297.3224
# Accuracy cap NOT hit at Step 22 : 0.5 < 0.8
# LOSS train 0.8765 valid 0.8435
# Accuracy cap NOT hit at Step 26 : 0.5 < 0.8
# LOSS train 0.7514 valid 335.4380
# Accuracy cap NOT hit at Step 23 : 0.5 < 0.8
# LOSS train 0.8220 valid 0.7853
# Accuracy cap NOT hit at Step 27 : 0.509 < 0.8
# LOSS train 0.7121 valid 309.9287
# Accuracy cap NOT hit at Step 24 : 0.5 < 0.8
# LOSS train 0.8212 valid 0.7636
# Accuracy cap NOT hit at Step 28 : 0.503 < 0.8
# LOSS train 1.0590 valid 202.8082
# Accuracy cap NOT hit at Step 25 : 0.501 < 0.8
# LOSS train 0.8265 valid 0.7502
# Accuracy cap NOT hit at Step 29 : 0.501 < 0.8
# LOSS train 1.3352 valid 28.5845
# Accuracy cap NOT hit at Step 26 : 0.501 < 0.8
# LOSS train 0.6588 valid 0.7279
# Accuracy cap NOT hit at Step 30 : 0.5 < 0.8
# LOSS train 0.7369 valid 83.8706
# Accuracy cap NOT hit at Step 27 : 0.5 < 0.8
# LOSS train 0.6959 valid 0.7080
# Accuracy cap NOT hit at Step 31 : 0.5 < 0.8
# LOSS train 0.7666 valid 135.6591
# Accuracy cap NOT hit at Step 28 : 0.5 < 0.8
# LOSS train 0.6995 valid 0.6986
# Accuracy cap NOT hit at Step 32 : 0.5 < 0.8
# LOSS train 0.6797 valid 0.6920
# Accuracy cap NOT hit at Step 33 : 0.495 < 0.8
# LOSS train 1.3313 valid 109.7132
# Accuracy cap NOT hit at Step 29 : 0.5 < 0.8
# LOSS train 0.6708 valid 0.6882
# Accuracy cap NOT hit at Step 34 : 0.614 < 0.8
# LOSS train 1.5963 valid 50.1103
# Accuracy cap NOT hit at Step 30 : 0.5 < 0.8
# LOSS train 0.7272 valid 0.6886
# Accuracy cap NOT hit at Step 35 : 0.499 < 0.8
# LOSS train 1.0225 valid 14.4393
# Accuracy cap NOT hit at Step 31 : 0.5 < 0.8
# LOSS train 0.6566 valid 0.7057
# Accuracy cap NOT hit at Step 36 : 0.486 < 0.8
# LOSS train 0.8067 valid 39.5085
# Accuracy cap NOT hit at Step 32 : 0.5 < 0.8
# LOSS train 0.7756 valid 0.7032
# Accuracy cap NOT hit at Step 37 : 0.484 < 0.8
# LOSS train 1.0435 valid 39.6821
# Accuracy cap NOT hit at Step 33 : 0.5 < 0.8
# LOSS train 0.6321 valid 0.7108
# Accuracy cap NOT hit at Step 38 : 0.489 < 0.8
# LOSS train 0.8361 valid 32.5954
# Accuracy cap NOT hit at Step 34 : 0.5 < 0.8
# LOSS train 0.6907 valid 0.7171
# Accuracy cap NOT hit at Step 39 : 0.496 < 0.8
# LOSS train 0.8732 valid 19.1157
# Accuracy cap NOT hit at Step 35 : 0.5 < 0.8
# LOSS train 0.7737 valid 0.7251
# Accuracy cap NOT hit at Step 40 : 0.5 < 0.8
# LOSS train 0.9719 valid 3.9434
# Accuracy cap NOT hit at Step 36 : 0.5 < 0.8
# LOSS train 0.7803 valid 0.7189
# Accuracy cap NOT hit at Step 41 : 0.497 < 0.8
# LOSS train 0.6597 valid 3.7692
# Accuracy cap NOT hit at Step 37 : 0.492 < 0.8
# LOSS train 0.7039 valid 0.7088
# Accuracy cap NOT hit at Step 42 : 0.499 < 0.8
# LOSS train 0.6609 valid 9.0165
# Accuracy cap NOT hit at Step 38 : 0.499 < 0.8
# LOSS train 0.7386 valid 0.6962
# Accuracy cap NOT hit at Step 43 : 0.478 < 0.8
# LOSS train 0.9487 valid 6.7593
# Accuracy cap NOT hit at Step 39 : 0.5 < 0.8
# LOSS train 0.6733 valid 0.6965
# Accuracy cap NOT hit at Step 44 : 0.511 < 0.8
# LOSS train 0.8248 valid 2.8845
# Accuracy cap NOT hit at Step 40 : 0.5 < 0.8
# LOSS train 0.6667 valid 0.7179
# Accuracy cap NOT hit at Step 45 : 0.535 < 0.8
# LOSS train 0.7977 valid 1.2203
# Accuracy cap NOT hit at Step 41 : 0.51 < 0.8
# LOSS train 0.7106 valid 0.7555
# Accuracy cap NOT hit at Step 46 : 0.502 < 0.8
# LOSS train 0.7080 valid 1.8791
# Accuracy cap NOT hit at Step 42 : 0.503 < 0.8
# LOSS train 0.6662 valid 0.7970
# Accuracy cap NOT hit at Step 47 : 0.5 < 0.8
# LOSS train 0.7446 valid 1.4912
# Accuracy cap NOT hit at Step 43 : 0.507 < 0.8
# LOSS train 0.7039 valid 0.8578
# Accuracy cap NOT hit at Step 48 : 0.5 < 0.8
# LOSS train 0.6757 valid 1.2014
# Accuracy cap NOT hit at Step 44 : 0.506 < 0.8
# LOSS train 0.9413 valid 0.8417
# Accuracy cap NOT hit at Step 49 : 0.5 < 0.8
# LOSS train 0.6768 valid 1.0327
# Accuracy cap NOT hit at Step 45 : 0.505 < 0.8
# LOSS train 0.7624 valid 0.7533
# Accuracy cap NOT hit at Step 50 : 0.505 < 0.8
# LOSS train 0.6736 valid 0.9587
# Accuracy cap NOT hit at Step 46 : 0.508 < 0.8
# LOSS train 0.7131 valid 0.7168
# Accuracy cap NOT hit at Step 51 : 0.486 < 0.8
# LOSS train 0.6923 valid 0.8293
# Accuracy cap NOT hit at Step 47 : 0.505 < 0.8
# LOSS train 0.6925 valid 0.7992
# Accuracy cap NOT hit at Step 52 : 0.499 < 0.8
# LOSS train 0.6869 valid 0.7485
# Accuracy cap NOT hit at Step 48 : 0.504 < 0.8
# LOSS train 0.7260 valid 0.9030
# Accuracy cap NOT hit at Step 53 : 0.5 < 0.8
# LOSS train 0.6975 valid 0.7053
# Accuracy cap NOT hit at Step 49 : 0.503 < 0.8
# LOSS train 0.7406 valid 0.8923
# Accuracy cap NOT hit at Step 54 : 0.5 < 0.8
# LOSS train 0.6827 valid 0.6924
# Accuracy cap NOT hit at Step 50 : 0.516 < 0.8
# LOSS train 0.6944 valid 0.8329
# Accuracy cap NOT hit at Step 55 : 0.5 < 0.8
# LOSS train 0.6953 valid 0.6944
# Accuracy cap NOT hit at Step 51 : 0.504 < 0.8
# LOSS train 0.7715 valid 0.7569
# Accuracy cap NOT hit at Step 56 : 0.489 < 0.8
# LOSS train 0.6839 valid 0.6940
# Accuracy cap NOT hit at Step 52 : 0.502 < 0.8
# LOSS train 0.6907 valid 0.7755
# Accuracy cap NOT hit at Step 57 : 0.508 < 0.8
# LOSS train 0.6966 valid 0.7205
# Accuracy cap NOT hit at Step 53 : 0.502 < 0.8
# LOSS train 0.7793 valid 0.8333
# Accuracy cap NOT hit at Step 58 : 0.516 < 0.8
# LOSS train 0.6861 valid 0.7753
# Accuracy cap NOT hit at Step 54 : 0.511 < 0.8
# LOSS train 0.7167 valid 0.8419
# Accuracy cap NOT hit at Step 59 : 0.505 < 0.8
# LOSS train 0.8364 valid 0.7369
# Accuracy cap NOT hit at Step 55 : 0.504 < 0.8
# LOSS train 0.6812 valid 0.8659
# Accuracy cap NOT hit at Step 60 : 0.516 < 0.8
# LOSS train 0.7650 valid 0.7031
# Accuracy cap NOT hit at Step 56 : 0.499 < 0.8
# LOSS train 0.6843 valid 0.8512
# Accuracy cap NOT hit at Step 61 : 0.537 < 0.8
# LOSS train 0.6981 valid 0.7412
# Accuracy cap NOT hit at Step 57 : 0.5 < 0.8
# LOSS train 0.7372 valid 0.8034
# Accuracy cap NOT hit at Step 62 : 0.519 < 0.8
# LOSS train 0.7537 valid 0.7365
# Accuracy cap NOT hit at Step 58 : 0.498 < 0.8
# LOSS train 0.6782 valid 0.7720
# Accuracy cap NOT hit at Step 63 : 0.515 < 0.8
# LOSS train 0.7136 valid 0.7154
# Accuracy cap NOT hit at Step 59 : 0.479 < 0.8
# LOSS train 0.6761 valid 0.7814
# Accuracy cap NOT hit at Step 64 : 0.507 < 0.8
# LOSS train 0.6932 valid 0.6958
# Accuracy cap NOT hit at Step 60 : 0.495 < 0.8
# LOSS train 0.6459 valid 0.7953
# Accuracy cap NOT hit at Step 65 : 0.504 < 0.8
# LOSS train 0.6965 valid 0.6977
# Accuracy cap NOT hit at Step 61 : 0.514 < 0.8
# LOSS train 0.7379 valid 0.7706
# Accuracy cap NOT hit at Step 66 : 0.5 < 0.8
# LOSS train 0.6834 valid 0.7119
# Accuracy cap NOT hit at Step 62 : 0.507 < 0.8
# LOSS train 0.7334 valid 0.7338
# Accuracy cap NOT hit at Step 67 : 0.5 < 0.8
# LOSS train 0.6777 valid 0.7296
# Accuracy cap NOT hit at Step 63 : 0.5 < 0.8
# LOSS train 0.6571 valid 0.7184
# Accuracy cap NOT hit at Step 68 : 0.5 < 0.8
# LOSS train 0.6901 valid 0.7431
# Accuracy cap NOT hit at Step 64 : 0.496 < 0.8
# LOSS train 0.7034 valid 0.7149
# Accuracy cap NOT hit at Step 69 : 0.5 < 0.8
# LOSS train 0.7361 valid 0.7381
# Accuracy cap NOT hit at Step 65 : 0.509 < 0.8
# LOSS train 0.6618 valid 0.7137
# Accuracy cap NOT hit at Step 70 : 0.5 < 0.8
# LOSS train 0.7219 valid 0.7184
# Accuracy cap NOT hit at Step 66 : 0.515 < 0.8
# LOSS train 0.7718 valid 0.7041
# Accuracy cap NOT hit at Step 71 : 0.5 < 0.8
# LOSS train 0.7642 valid 0.6961
# Accuracy cap NOT hit at Step 72 : 0.499 < 0.8
# LOSS train 0.7004 valid 0.6974
# Accuracy cap NOT hit at Step 67 : 0.503 < 0.8
# LOSS train 0.7055 valid 0.6920
# Accuracy cap NOT hit at Step 73 : 0.539 < 0.8
# LOSS train 0.7071 valid 0.7048
# Accuracy cap NOT hit at Step 68 : 0.505 < 0.8
# LOSS train 0.7043 valid 0.6934
# Accuracy cap NOT hit at Step 74 : 0.491 < 0.8
# LOSS train 0.7015 valid 0.7297
# Accuracy cap NOT hit at Step 69 : 0.494 < 0.8
# LOSS train 0.6911 valid 0.6987
# Accuracy cap NOT hit at Step 75 : 0.499 < 0.8
# LOSS train 0.7573 valid 0.7297
# Accuracy cap NOT hit at Step 70 : 0.496 < 0.8
# LOSS train 0.6815 valid 0.7065
# Accuracy cap NOT hit at Step 76 : 0.5 < 0.8
# LOSS train 0.7343 valid 0.7158
# Accuracy cap NOT hit at Step 71 : 0.491 < 0.8
# LOSS train 0.7505 valid 0.7102
# Accuracy cap NOT hit at Step 77 : 0.5 < 0.8
# LOSS train 0.6624 valid 0.7116
# Accuracy cap NOT hit at Step 72 : 0.494 < 0.8
# LOSS train 0.7031 valid 0.7121
# Accuracy cap NOT hit at Step 78 : 0.5 < 0.8
# LOSS train 0.7368 valid 0.6952
# Accuracy cap NOT hit at Step 73 : 0.5 < 0.8
# LOSS train 0.7099 valid 0.7118
# Accuracy cap NOT hit at Step 79 : 0.5 < 0.8
# LOSS train 0.6786 valid 0.7118
# Accuracy cap NOT hit at Step 74 : 0.494 < 0.8
# LOSS train 0.7629 valid 0.7065
# Accuracy cap NOT hit at Step 80 : 0.494 < 0.8
# LOSS train 0.7342 valid 0.7192
# Accuracy cap NOT hit at Step 75 : 0.499 < 0.8
# LOSS train 0.7117 valid 0.7019
# Accuracy cap NOT hit at Step 81 : 0.492 < 0.8
# LOSS train 0.6847 valid 0.7124
# Accuracy cap NOT hit at Step 76 : 0.511 < 0.8
# LOSS train 0.6836 valid 0.6998
# Accuracy cap NOT hit at Step 82 : 0.489 < 0.8
# LOSS train 0.7197 valid 0.7075
# Accuracy cap NOT hit at Step 77 : 0.493 < 0.8
# LOSS train 0.7222 valid 0.6971
# Accuracy cap NOT hit at Step 83 : 0.497 < 0.8
# LOSS train 0.6876 valid 0.7131
# Accuracy cap NOT hit at Step 78 : 0.501 < 0.8
# LOSS train 0.6910 valid 0.6955
# Accuracy cap NOT hit at Step 84 : 0.491 < 0.8
# LOSS train 0.7180 valid 0.7186
# Accuracy cap NOT hit at Step 79 : 0.5 < 0.8
# LOSS train 0.7189 valid 0.6944
# Accuracy cap NOT hit at Step 85 : 0.517 < 0.8
# LOSS train 0.7160 valid 0.7185
# Accuracy cap NOT hit at Step 80 : 0.5 < 0.8
# LOSS train 0.6854 valid 0.6945
# Accuracy cap NOT hit at Step 86 : 0.538 < 0.8
# LOSS train 0.7179 valid 0.7146
# Accuracy cap NOT hit at Step 81 : 0.5 < 0.8
# LOSS train 0.6863 valid 0.6941
# Accuracy cap NOT hit at Step 87 : 0.551 < 0.8
# LOSS train 0.7525 valid 0.7056
# Accuracy cap NOT hit at Step 82 : 0.5 < 0.8
# LOSS train 0.7225 valid 0.6933
# Accuracy cap NOT hit at Step 88 : 0.543 < 0.8
# LOSS train 0.7090 valid 0.6987
# Accuracy cap NOT hit at Step 83 : 0.496 < 0.8
# LOSS train 0.6910 valid 0.6927
# Accuracy cap NOT hit at Step 89 : 0.552 < 0.8
# LOSS train 0.7111 valid 0.7052
# Accuracy cap NOT hit at Step 84 : 0.511 < 0.8
# LOSS train 0.7130 valid 0.6921
# Accuracy cap NOT hit at Step 90 : 0.528 < 0.8
# LOSS train 0.7033 valid 0.7130
# Accuracy cap NOT hit at Step 85 : 0.515 < 0.8
# LOSS train 0.6874 valid 0.6919
# Accuracy cap NOT hit at Step 91 : 0.541 < 0.8
# LOSS train 0.7268 valid 0.7114
# Accuracy cap NOT hit at Step 86 : 0.513 < 0.8
# LOSS train 0.6987 valid 0.6919
# Accuracy cap NOT hit at Step 92 : 0.528 < 0.8
# LOSS train 0.6810 valid 0.7073
# Accuracy cap NOT hit at Step 87 : 0.504 < 0.8
# LOSS train 0.6926 valid 0.6922
# Accuracy cap NOT hit at Step 93 : 0.514 < 0.8
# LOSS train 0.6784 valid 0.7032
# Accuracy cap NOT hit at Step 88 : 0.508 < 0.8
# LOSS train 0.6878 valid 0.6928
# Accuracy cap NOT hit at Step 94 : 0.492 < 0.8
# LOSS train 0.7257 valid 0.6966
# Accuracy cap NOT hit at Step 89 : 0.515 < 0.8
# LOSS train 0.7086 valid 0.6927
# Accuracy cap NOT hit at Step 95 : 0.505 < 0.8
# LOSS train 0.7167 valid 0.7094
# Accuracy cap NOT hit at Step 90 : 0.517 < 0.8
# LOSS train 0.6705 valid 0.6934
# Accuracy cap NOT hit at Step 96 : 0.492 < 0.8
# LOSS train 0.6995 valid 0.7217
# Accuracy cap NOT hit at Step 91 : 0.487 < 0.8
# LOSS train 0.7014 valid 0.6947
# Accuracy cap NOT hit at Step 97 : 0.497 < 0.8
# LOSS train 0.6772 valid 0.7337
# Accuracy cap NOT hit at Step 92 : 0.496 < 0.8
# LOSS train 0.6509 valid 0.6979
# Accuracy cap NOT hit at Step 98 : 0.5 < 0.8
# LOSS train 0.6432 valid 0.7481
# Accuracy cap NOT hit at Step 93 : 0.5 < 0.8
# LOSS train 0.6809 valid 0.7025
# Accuracy cap NOT hit at Step 99 : 0.5 < 0.8
# LOSS train 0.8770 valid 0.7377
# Accuracy cap NOT hit at Step 94 : 0.5 < 0.8
# LOSS train 0.7312 valid 0.7052
# Accuracy cap NOT hit at Step 100 : 0.5 < 0.8
# LOSS train 0.7858 valid 0.7134
# Accuracy cap NOT hit at Step 95 : 0.498 < 0.8
# LOSS train 0.7450 valid 0.7047
# Accuracy cap NOT hit at Step 101 : 0.5 < 0.8
# LOSS train 0.6454 valid 0.7048
# Accuracy cap NOT hit at Step 96 : 0.498 < 0.8
# LOSS train 0.7650 valid 0.7009
# Accuracy cap NOT hit at Step 102 : 0.5 < 0.8
# LOSS train 0.6641 valid 0.7036
# Accuracy cap NOT hit at Step 97 : 0.498 < 0.8
# LOSS train 0.6947 valid 0.6972
# Accuracy cap NOT hit at Step 103 : 0.5 < 0.8
# LOSS train 0.6741 valid 0.7046
# Accuracy cap NOT hit at Step 98 : 0.501 < 0.8
# LOSS train 0.7019 valid 0.6940
# Accuracy cap NOT hit at Step 104 : 0.494 < 0.8
# LOSS train 0.7057 valid 0.7055
# Accuracy cap NOT hit at Step 99 : 0.5 < 0.8
# LOSS train 0.6867 valid 0.6932
# Accuracy cap NOT hit at Step 105 : 0.51 < 0.8
# LOSS train 0.6989 valid 0.7072
# Accuracy cap NOT hit at Step 100 : 0.504 < 0.8
# LOSS train 0.6832 valid 0.6960
# Accuracy cap NOT hit at Step 106 : 0.5 < 0.8
# LOSS train 0.7067 valid 0.7065
# Accuracy cap NOT hit at Step 101 : 0.502 < 0.8
# LOSS train 0.6841 valid 0.7023
# Accuracy cap NOT hit at Step 107 : 0.5 < 0.8
# LOSS train 0.7145 valid 0.7057
# Accuracy cap NOT hit at Step 102 : 0.505 < 0.8
# LOSS train 0.6931 valid 0.7091
# Accuracy cap NOT hit at Step 108 : 0.5 < 0.8
# LOSS train 0.6905 valid 0.7044
# Accuracy cap NOT hit at Step 103 : 0.501 < 0.8
# LOSS train 0.7611 valid 0.7122
# Accuracy cap NOT hit at Step 109 : 0.5 < 0.8
# LOSS train 0.6762 valid 0.7019
# Accuracy cap NOT hit at Step 104 : 0.504 < 0.8
# LOSS train 0.8008 valid 0.7098
# Accuracy cap NOT hit at Step 110 : 0.5 < 0.8
# LOSS train 0.6871 valid 0.7013
# Accuracy cap NOT hit at Step 105 : 0.503 < 0.8
# LOSS train 0.7270 valid 0.7051
# Accuracy cap NOT hit at Step 111 : 0.5 < 0.8
# LOSS train 0.7087 valid 0.6989
# Accuracy cap NOT hit at Step 106 : 0.508 < 0.8
# LOSS train 0.7217 valid 0.7021
# Accuracy cap NOT hit at Step 112 : 0.5 < 0.8
# LOSS train 0.6747 valid 0.6984
# Accuracy cap NOT hit at Step 107 : 0.511 < 0.8
# LOSS train 0.7272 valid 0.6967
# Accuracy cap NOT hit at Step 113 : 0.499 < 0.8
# LOSS train 0.6916 valid 0.6963
# Accuracy cap NOT hit at Step 108 : 0.511 < 0.8
# LOSS train 0.7241 valid 0.6933
# Accuracy cap NOT hit at Step 114 : 0.533 < 0.8
# LOSS train 0.7024 valid 0.6944
# Accuracy cap NOT hit at Step 109 : 0.503 < 0.8
# LOSS train 0.6882 valid 0.6937
# Accuracy cap NOT hit at Step 115 : 0.495 < 0.8
# LOSS train 0.6721 valid 0.6938
# Accuracy cap NOT hit at Step 110 : 0.496 < 0.8
# LOSS train 0.7050 valid 0.6983
# Accuracy cap NOT hit at Step 116 : 0.501 < 0.8
# LOSS train 0.6991 valid 0.6969
# Accuracy cap NOT hit at Step 111 : 0.509 < 0.8
# LOSS train 0.6828 valid 0.7049
# Accuracy cap NOT hit at Step 117 : 0.502 < 0.8
# LOSS train 0.6856 valid 0.6986
# Accuracy cap NOT hit at Step 112 : 0.523 < 0.8
# LOSS train 0.6523 valid 0.7161
# Accuracy cap NOT hit at Step 118 : 0.5 < 0.8
# LOSS train 0.7074 valid 0.6998
# Accuracy cap NOT hit at Step 113 : 0.515 < 0.8
# LOSS train 0.7108 valid 0.7271
# Accuracy cap NOT hit at Step 119 : 0.5 < 0.8
# LOSS train 0.6813 valid 0.7022
# Accuracy cap NOT hit at Step 114 : 0.508 < 0.8
# LOSS train 0.8433 valid 0.7270
# Accuracy cap NOT hit at Step 120 : 0.5 < 0.8
# LOSS train 0.7060 valid 0.7024
# Accuracy cap NOT hit at Step 115 : 0.506 < 0.8
# LOSS train 0.7720 valid 0.7204
# Accuracy cap NOT hit at Step 121 : 0.5 < 0.8
# LOSS train 0.6983 valid 0.7010
# Accuracy cap NOT hit at Step 116 : 0.5 < 0.8
# LOSS train 0.7654 valid 0.7107
# Accuracy cap NOT hit at Step 122 : 0.5 < 0.8
# LOSS train 0.7093 valid 0.7007
# Accuracy cap NOT hit at Step 117 : 0.5 < 0.8
# LOSS train 0.7777 valid 0.6997
# Accuracy cap NOT hit at Step 123 : 0.5 < 0.8
# LOSS train 0.7100 valid 0.6978
# Accuracy cap NOT hit at Step 118 : 0.51 < 0.8
# LOSS train 0.7288 valid 0.6934
# Accuracy cap NOT hit at Step 124 : 0.529 < 0.8
# LOSS train 0.7178 valid 0.6978
# Accuracy cap NOT hit at Step 119 : 0.509 < 0.8
# LOSS train 0.7008 valid 0.6948
# Accuracy cap NOT hit at Step 125 : 0.502 < 0.8
# LOSS train 0.7282 valid 0.6980
# Accuracy cap NOT hit at Step 120 : 0.505 < 0.8
# LOSS train 0.6999 valid 0.7014
# Accuracy cap NOT hit at Step 126 : 0.5 < 0.8
# LOSS train 0.7098 valid 0.7105
# Accuracy cap NOT hit at Step 127 : 0.5 < 0.8
# LOSS train 0.6922 valid 0.6975
# Accuracy cap NOT hit at Step 121 : 0.494 < 0.8
# LOSS train 0.7051 valid 0.7188
# Accuracy cap NOT hit at Step 128 : 0.5 < 0.8
# LOSS train 0.6922 valid 0.6993
# Accuracy cap NOT hit at Step 122 : 0.502 < 0.8
# LOSS train 0.6888 valid 0.7260
# Accuracy cap NOT hit at Step 129 : 0.5 < 0.8
# LOSS train 0.7250 valid 0.7001
# Accuracy cap NOT hit at Step 123 : 0.503 < 0.8
# LOSS train 0.7626 valid 0.7267
# Accuracy cap NOT hit at Step 130 : 0.5 < 0.8
# LOSS train 0.7522 valid 0.7105
# Accuracy cap NOT hit at Step 124 : 0.503 < 0.8
# LOSS train 0.7039 valid 0.7247
# Accuracy cap NOT hit at Step 131 : 0.5 < 0.8
# LOSS train 0.7432 valid 0.7242
# Accuracy cap NOT hit at Step 125 : 0.501 < 0.8
# LOSS train 0.6879 valid 0.7216
# Accuracy cap NOT hit at Step 132 : 0.5 < 0.8
# LOSS train 0.7329 valid 0.7248
# Accuracy cap NOT hit at Step 126 : 0.5 < 0.8
# LOSS train 0.6742 valid 0.7180
# Accuracy cap NOT hit at Step 133 : 0.5 < 0.8
# LOSS train 0.6071 valid 0.7338
# Accuracy cap NOT hit at Step 127 : 0.5 < 0.8
# LOSS train 0.6777 valid 0.7161
# Accuracy cap NOT hit at Step 134 : 0.5 < 0.8
# LOSS train 0.7380 valid 0.7344
# Accuracy cap NOT hit at Step 128 : 0.5 < 0.8
# LOSS train 0.6953 valid 0.7140
# Accuracy cap NOT hit at Step 135 : 0.5 < 0.8
# LOSS train 0.7751 valid 0.7178
# Accuracy cap NOT hit at Step 129 : 0.501 < 0.8
# LOSS train 0.7535 valid 0.7082
# Accuracy cap NOT hit at Step 136 : 0.5 < 0.8
# LOSS train 0.7640 valid 0.7012
# Accuracy cap NOT hit at Step 130 : 0.497 < 0.8
# LOSS train 0.7092 valid 0.7020
# Accuracy cap NOT hit at Step 137 : 0.503 < 0.8
# LOSS train 0.6496 valid 0.7046
# Accuracy cap NOT hit at Step 131 : 0.496 < 0.8
# LOSS train 0.6732 valid 0.6991
# Accuracy cap NOT hit at Step 138 : 0.499 < 0.8
# LOSS train 0.6973 valid 0.7157
# Accuracy cap NOT hit at Step 132 : 0.509 < 0.8
# LOSS train 0.7128 valid 0.6961
# Accuracy cap NOT hit at Step 139 : 0.499 < 0.8
# LOSS train 0.6716 valid 0.7345
# Accuracy cap NOT hit at Step 133 : 0.502 < 0.8
# LOSS train 0.6955 valid 0.6948
# Accuracy cap NOT hit at Step 140 : 0.49 < 0.8
# LOSS train 0.8669 valid 0.7286
# Accuracy cap NOT hit at Step 134 : 0.501 < 0.8
# LOSS train 0.6828 valid 0.6945
# Accuracy cap NOT hit at Step 141 : 0.487 < 0.8
# LOSS train 0.7114 valid 0.7183
# Accuracy cap NOT hit at Step 135 : 0.504 < 0.8
# LOSS train 0.6873 valid 0.6952
# Accuracy cap NOT hit at Step 142 : 0.497 < 0.8
# LOSS train 0.6666 valid 0.7113
# Accuracy cap NOT hit at Step 136 : 0.506 < 0.8
# LOSS train 0.6938 valid 0.6964
# Accuracy cap NOT hit at Step 143 : 0.501 < 0.8
# LOSS train 0.6715 valid 0.7059
# Accuracy cap NOT hit at Step 137 : 0.497 < 0.8
# LOSS train 0.6824 valid 0.6991
# Accuracy cap NOT hit at Step 144 : 0.5 < 0.8
# LOSS train 0.7723 valid 0.6977
# Accuracy cap NOT hit at Step 138 : 0.498 < 0.8
# LOSS train 0.7055 valid 0.7006
# Accuracy cap NOT hit at Step 145 : 0.5 < 0.8
# LOSS train 0.7131 valid 0.6991
# Accuracy cap NOT hit at Step 139 : 0.506 < 0.8
# LOSS train 0.6869 valid 0.7022
# Accuracy cap NOT hit at Step 146 : 0.5 < 0.8
# LOSS train 0.7106 valid 0.6999
# Accuracy cap NOT hit at Step 140 : 0.496 < 0.8
# LOSS train 0.6851 valid 0.7042
# Accuracy cap NOT hit at Step 147 : 0.5 < 0.8
# LOSS train 0.7044 valid 0.6976
# Accuracy cap NOT hit at Step 141 : 0.515 < 0.8
# LOSS train 0.6558 valid 0.7083
# Accuracy cap NOT hit at Step 148 : 0.5 < 0.8
# LOSS train 0.6982 valid 0.6944
# Accuracy cap NOT hit at Step 142 : 0.515 < 0.8
# LOSS train 0.7044 valid 0.7110
# Accuracy cap NOT hit at Step 149 : 0.5 < 0.8
# LOSS train 0.6900 valid 0.6953
# Accuracy cap NOT hit at Step 143 : 0.509 < 0.8
# LOSS train 0.7012 valid 0.7121
# Accuracy cap NOT hit at Step 150 : 0.5 < 0.8
# LOSS train 0.6906 valid 0.6984
# Accuracy cap NOT hit at Step 144 : 0.505 < 0.8
# LOSS train 0.6955 valid 0.7130
# Accuracy cap NOT hit at Step 151 : 0.5 < 0.8
# LOSS train 0.7065 valid 0.6977
# Accuracy cap NOT hit at Step 145 : 0.502 < 0.8
# LOSS train 0.6701 valid 0.7139
# Accuracy cap NOT hit at Step 152 : 0.5 < 0.8
# LOSS train 0.6904 valid 0.7055
# Accuracy cap NOT hit at Step 146 : 0.501 < 0.8
# LOSS train 0.7416 valid 0.7104
# Accuracy cap NOT hit at Step 153 : 0.5 < 0.8
# LOSS train 0.6878 valid 0.7192
# Accuracy cap NOT hit at Step 147 : 0.495 < 0.8
# LOSS train 0.6838 valid 0.7071
# Accuracy cap NOT hit at Step 154 : 0.5 < 0.8
# LOSS train 0.7148 valid 0.7331
# Accuracy cap NOT hit at Step 148 : 0.495 < 0.8
# LOSS train 0.6679 valid 0.7057
# Accuracy cap NOT hit at Step 155 : 0.499 < 0.8
# LOSS train 0.7153 valid 0.7559
# Accuracy cap NOT hit at Step 149 : 0.494 < 0.8
# LOSS train 0.6945 valid 0.7029
# Accuracy cap NOT hit at Step 156 : 0.496 < 0.8
# LOSS train 0.6995 valid 0.7938
# Accuracy cap NOT hit at Step 150 : 0.513 < 0.8
# LOSS train 0.6681 valid 0.7018
# Accuracy cap NOT hit at Step 157 : 0.497 < 0.8
# LOSS train 0.6961 valid 0.8060
# Accuracy cap NOT hit at Step 151 : 0.501 < 0.8
# LOSS train 0.7141 valid 0.6998
# Accuracy cap NOT hit at Step 158 : 0.491 < 0.8
# LOSS train 0.7017 valid 0.8196
# Accuracy cap NOT hit at Step 152 : 0.49 < 0.8
# LOSS train 0.7175 valid 0.6969
# Accuracy cap NOT hit at Step 159 : 0.497 < 0.8
# LOSS train 0.8850 valid 0.7666
# Accuracy cap NOT hit at Step 153 : 0.491 < 0.8
# LOSS train 0.6999 valid 0.6953
# Accuracy cap NOT hit at Step 160 : 0.507 < 0.8
# LOSS train 0.7775 valid 0.7023
# Accuracy cap NOT hit at Step 154 : 0.491 < 0.8
# LOSS train 0.7048 valid 0.6950
# Accuracy cap NOT hit at Step 161 : 0.504 < 0.8
# LOSS train 0.6891 valid 0.7159
# Accuracy cap NOT hit at Step 155 : 0.497 < 0.8
# LOSS train 0.7045 valid 0.6954
# Accuracy cap NOT hit at Step 162 : 0.497 < 0.8
# LOSS train 0.7256 valid 0.7547
# Accuracy cap NOT hit at Step 156 : 0.502 < 0.8
# LOSS train 0.7194 valid 0.6963
# Accuracy cap NOT hit at Step 163 : 0.5 < 0.8
# LOSS train 0.6772 valid 0.7847
# Accuracy cap NOT hit at Step 157 : 0.496 < 0.8
# LOSS train 0.6916 valid 0.6974
# Accuracy cap NOT hit at Step 164 : 0.501 < 0.8
# LOSS train 0.6646 valid 0.8191
# Accuracy cap NOT hit at Step 158 : 0.496 < 0.8
# LOSS train 0.6987 valid 0.6971
# Accuracy cap NOT hit at Step 165 : 0.501 < 0.8
# LOSS train 0.6991 valid 0.8244
# Accuracy cap NOT hit at Step 159 : 0.497 < 0.8
# LOSS train 0.6986 valid 0.6969
# Accuracy cap NOT hit at Step 166 : 0.503 < 0.8
# LOSS train 0.8717 valid 0.7827
# Accuracy cap NOT hit at Step 160 : 0.495 < 0.8
# LOSS train 0.7002 valid 0.6960
# Accuracy cap NOT hit at Step 167 : 0.506 < 0.8
# LOSS train 0.7705 valid 0.7293
# Accuracy cap NOT hit at Step 161 : 0.497 < 0.8
# LOSS train 0.6952 valid 0.6951
# Accuracy cap NOT hit at Step 168 : 0.491 < 0.8
# LOSS train 0.6670 valid 0.7028
# Accuracy cap NOT hit at Step 162 : 0.513 < 0.8
# LOSS train 0.6977 valid 0.6945
# Accuracy cap NOT hit at Step 169 : 0.499 < 0.8
# LOSS train 0.7091 valid 0.7008
# Accuracy cap NOT hit at Step 163 : 0.51 < 0.8
# LOSS train 0.6953 valid 0.6944
# Accuracy cap NOT hit at Step 170 : 0.51 < 0.8
# LOSS train 0.6995 valid 0.7035
# Accuracy cap NOT hit at Step 164 : 0.5 < 0.8
# LOSS train 0.6899 valid 0.6948
# Accuracy cap NOT hit at Step 171 : 0.491 < 0.8
# LOSS train 0.7530 valid 0.6985
# Accuracy cap NOT hit at Step 165 : 0.491 < 0.8
# LOSS train 0.6942 valid 0.6953
# Accuracy cap NOT hit at Step 172 : 0.496 < 0.8
# LOSS train 0.6933 valid 0.6966
# Accuracy cap NOT hit at Step 166 : 0.491 < 0.8
# LOSS train 0.7104 valid 0.6959
# Accuracy cap NOT hit at Step 173 : 0.493 < 0.8
# LOSS train 0.6753 valid 0.6954
# Accuracy cap NOT hit at Step 167 : 0.503 < 0.8
# LOSS train 0.6761 valid 0.6976
# Accuracy cap NOT hit at Step 174 : 0.501 < 0.8
# LOSS train 0.6689 valid 0.7050
# Accuracy cap NOT hit at Step 168 : 0.519 < 0.8
# LOSS train 0.6990 valid 0.6987
# Accuracy cap NOT hit at Step 175 : 0.5 < 0.8
# LOSS train 0.6827 valid 0.7211
# Accuracy cap NOT hit at Step 169 : 0.516 < 0.8
# LOSS train 0.6898 valid 0.7002
# Accuracy cap NOT hit at Step 176 : 0.5 < 0.8
# LOSS train 0.7025 valid 0.7247
# Accuracy cap NOT hit at Step 170 : 0.506 < 0.8
# LOSS train 0.6900 valid 0.7016
# Accuracy cap NOT hit at Step 177 : 0.5 < 0.8
# LOSS train 0.7020 valid 0.7248
# Accuracy cap NOT hit at Step 171 : 0.502 < 0.8
# LOSS train 0.6732 valid 0.7036
# Accuracy cap NOT hit at Step 178 : 0.5 < 0.8
# LOSS train 0.7492 valid 0.7173
# Accuracy cap NOT hit at Step 172 : 0.501 < 0.8
# LOSS train 0.6688 valid 0.7073
# Accuracy cap NOT hit at Step 179 : 0.5 < 0.8
# LOSS train 0.8039 valid 0.7029
# Accuracy cap NOT hit at Step 173 : 0.508 < 0.8
# LOSS train 0.6981 valid 0.7094
# Accuracy cap NOT hit at Step 180 : 0.5 < 0.8
# LOSS train 0.6956 valid 0.7048
# Accuracy cap NOT hit at Step 174 : 0.512 < 0.8
# LOSS train 0.7294 valid 0.7092
# Accuracy cap NOT hit at Step 181 : 0.5 < 0.8
# LOSS train 0.7146 valid 0.7237
# Accuracy cap NOT hit at Step 175 : 0.513 < 0.8
# LOSS train 0.7155 valid 0.7073
# Accuracy cap NOT hit at Step 182 : 0.5 < 0.8
# LOSS train 0.7093 valid 0.7398
# Accuracy cap NOT hit at Step 176 : 0.499 < 0.8
# LOSS train 0.7146 valid 0.7040
# Accuracy cap NOT hit at Step 183 : 0.5 < 0.8
# LOSS train 0.7186 valid 0.7468
# Accuracy cap NOT hit at Step 177 : 0.497 < 0.8
# LOSS train 0.7051 valid 0.7002
# Accuracy cap NOT hit at Step 184 : 0.501 < 0.8
# LOSS train 0.7451 valid 0.7353
# Accuracy cap NOT hit at Step 178 : 0.521 < 0.8
# LOSS train 0.6798 valid 0.6978
# Accuracy cap NOT hit at Step 185 : 0.506 < 0.8
# LOSS train 0.6434 valid 0.7349
# Accuracy cap NOT hit at Step 179 : 0.504 < 0.8
# LOSS train 0.6738 valid 0.6970
# Accuracy cap NOT hit at Step 186 : 0.502 < 0.8
# LOSS train 0.7325 valid 0.7107
# Accuracy cap NOT hit at Step 180 : 0.523 < 0.8
# LOSS train 0.7056 valid 0.6960
# Accuracy cap NOT hit at Step 187 : 0.514 < 0.8
# LOSS train 0.6844 valid 0.7051
# Accuracy cap NOT hit at Step 181 : 0.532 < 0.8
# LOSS train 0.6851 valid 0.6956
# Accuracy cap NOT hit at Step 188 : 0.514 < 0.8
# LOSS train 0.7414 valid 0.7031
# Accuracy cap NOT hit at Step 182 : 0.517 < 0.8
# LOSS train 0.6928 valid 0.6951
# Accuracy cap NOT hit at Step 189 : 0.512 < 0.8
# LOSS train 0.7048 valid 0.6996
# Accuracy cap NOT hit at Step 183 : 0.51 < 0.8
# LOSS train 0.7071 valid 0.6942
# Accuracy cap NOT hit at Step 190 : 0.498 < 0.8
# LOSS train 0.6880 valid 0.6943
# Accuracy cap NOT hit at Step 191 : 0.497 < 0.8
# LOSS train 0.6852 valid 0.6984
# Accuracy cap NOT hit at Step 184 : 0.498 < 0.8
# LOSS train 0.7205 valid 0.6941
# Accuracy cap NOT hit at Step 192 : 0.496 < 0.8
# LOSS train 0.7305 valid 0.7063
# Accuracy cap NOT hit at Step 185 : 0.494 < 0.8
# LOSS train 0.6866 valid 0.6943
# Accuracy cap NOT hit at Step 193 : 0.502 < 0.8
# LOSS train 0.7070 valid 0.7142
# Accuracy cap NOT hit at Step 186 : 0.496 < 0.8
# LOSS train 0.7427 valid 0.7200
# Accuracy cap NOT hit at Step 187 : 0.503 < 0.8
# LOSS train 0.6749 valid 0.6959
# Accuracy cap NOT hit at Step 194 : 0.503 < 0.8
# LOSS train 0.7049 valid 0.6974
# Accuracy cap NOT hit at Step 195 : 0.501 < 0.8
# LOSS train 0.7863 valid 0.7034
# Accuracy cap NOT hit at Step 188 : 0.504 < 0.8
# LOSS train 0.6954 valid 0.6989
# Accuracy cap NOT hit at Step 196 : 0.5 < 0.8
# LOSS train 0.6754 valid 0.7003
# Accuracy cap NOT hit at Step 189 : 0.498 < 0.8
# LOSS train 0.7173 valid 0.6986
# Accuracy cap NOT hit at Step 197 : 0.5 < 0.8
# LOSS train 0.6546 valid 0.6993
# Accuracy cap NOT hit at Step 190 : 0.51 < 0.8
# LOSS train 0.7010 valid 0.7006
# Accuracy cap NOT hit at Step 191 : 0.5 < 0.8
# LOSS train 0.6950 valid 0.6974
# Accuracy cap NOT hit at Step 198 : 0.5 < 0.8
# LOSS train 0.7619 valid 0.6977
# Accuracy cap NOT hit at Step 192 : 0.492 < 0.8
# LOSS train 0.7035 valid 0.6959
# Accuracy cap NOT hit at Step 199 : 0.5 < 0.8
# LOSS train 0.6826 valid 0.6981
# Accuracy cap NOT hit at Step 193 : 0.508 < 0.8
# LOSS train 0.7026 valid 0.6940
# Accuracy cap NOT hit at Step 200 : 0.501 < 0.8
# LOSS train 0.6717 valid 0.7085
# Accuracy cap NOT hit at Step 194 : 0.513 < 0.8
# LOSS train 0.6861 valid 0.6931
# Accuracy cap NOT hit at Step 201 : 0.495 < 0.8
# LOSS train 0.7218 valid 0.7132
# Accuracy cap NOT hit at Step 195 : 0.502 < 0.8
# LOSS train 0.6888 valid 0.6925
# Accuracy cap NOT hit at Step 202 : 0.532 < 0.8
# LOSS train 0.6728 valid 0.7178
# Accuracy cap NOT hit at Step 196 : 0.5 < 0.8
# LOSS train 0.6831 valid 0.6926
# Accuracy cap NOT hit at Step 203 : 0.521 < 0.8
# LOSS train 0.7189 valid 0.7159
# Accuracy cap NOT hit at Step 197 : 0.5 < 0.8
# LOSS train 0.6898 valid 0.6928
# Accuracy cap NOT hit at Step 204 : 0.523 < 0.8
# LOSS train 0.6929 valid 0.6930
# Accuracy cap NOT hit at Step 205 : 0.523 < 0.8
# LOSS train 0.7203 valid 0.7125
# Accuracy cap NOT hit at Step 198 : 0.5 < 0.8
# LOSS train 0.6976 valid 0.6938
# Accuracy cap NOT hit at Step 206 : 0.517 < 0.8
# LOSS train 0.6728 valid 0.7126
# Accuracy cap NOT hit at Step 199 : 0.499 < 0.8
# LOSS train 0.6851 valid 0.6963
# Accuracy cap NOT hit at Step 207 : 0.499 < 0.8
# LOSS train 0.7859 valid 0.7099
# Accuracy cap NOT hit at Step 200 : 0.5 < 0.8
# LOSS train 0.6948 valid 0.6991
# Accuracy cap NOT hit at Step 208 : 0.5 < 0.8
# LOSS train 0.7116 valid 0.7110
# Accuracy cap NOT hit at Step 201 : 0.502 < 0.8
# LOSS train 0.7057 valid 0.7015
# Accuracy cap NOT hit at Step 209 : 0.5 < 0.8
# LOSS train 0.6721 valid 0.7175
# Accuracy cap NOT hit at Step 202 : 0.494 < 0.8
# LOSS train 0.6785 valid 0.7037
# Accuracy cap NOT hit at Step 210 : 0.5 < 0.8
# LOSS train 0.7631 valid 0.7157
# Accuracy cap NOT hit at Step 203 : 0.505 < 0.8
# LOSS train 0.6887 valid 0.7057
# Accuracy cap NOT hit at Step 211 : 0.5 < 0.8
# LOSS train 0.6875 valid 0.7190
# Accuracy cap NOT hit at Step 204 : 0.518 < 0.8
# LOSS train 0.7287 valid 0.7036
# Accuracy cap NOT hit at Step 212 : 0.5 < 0.8
# LOSS train 0.6916 valid 0.7207
# Accuracy cap NOT hit at Step 205 : 0.509 < 0.8
# LOSS train 0.6397 valid 0.7056
# Accuracy cap NOT hit at Step 213 : 0.5 < 0.8
# LOSS train 0.7049 valid 0.7153
# Accuracy cap NOT hit at Step 206 : 0.495 < 0.8
# LOSS train 0.6987 valid 0.7054
# Accuracy cap NOT hit at Step 214 : 0.5 < 0.8
# LOSS train 0.7230 valid 0.7066
# Accuracy cap NOT hit at Step 207 : 0.496 < 0.8
# LOSS train 0.7526 valid 0.7016
# Accuracy cap NOT hit at Step 215 : 0.5 < 0.8
# LOSS train 0.7030 valid 0.6986
# Accuracy cap NOT hit at Step 208 : 0.506 < 0.8
# LOSS train 0.6927 valid 0.6978
# Accuracy cap NOT hit at Step 216 : 0.5 < 0.8
# LOSS train 0.7155 valid 0.6932
# Accuracy cap NOT hit at Step 209 : 0.508 < 0.8
# LOSS train 0.6738 valid 0.6959
# Accuracy cap NOT hit at Step 217 : 0.5 < 0.8
# LOSS train 0.7018 valid 0.6957
# Accuracy cap NOT hit at Step 210 : 0.496 < 0.8
# LOSS train 0.6874 valid 0.6944
# Accuracy cap NOT hit at Step 218 : 0.5 < 0.8
# LOSS train 0.7243 valid 0.6975
# Accuracy cap NOT hit at Step 211 : 0.49 < 0.8
# LOSS train 0.6871 valid 0.6927
# Accuracy cap NOT hit at Step 219 : 0.524 < 0.8
# LOSS train 0.6658 valid 0.7018
# Accuracy cap NOT hit at Step 212 : 0.509 < 0.8
# LOSS train 0.7005 valid 0.6919
# Accuracy cap NOT hit at Step 220 : 0.528 < 0.8
# LOSS train 0.6728 valid 0.7062
# Accuracy cap NOT hit at Step 213 : 0.52 < 0.8
# LOSS train 0.6949 valid 0.6918
# Accuracy cap NOT hit at Step 221 : 0.524 < 0.8
# LOSS train 0.6993 valid 0.7082
# Accuracy cap NOT hit at Step 214 : 0.516 < 0.8
# LOSS train 0.6886 valid 0.6918
# Accuracy cap NOT hit at Step 222 : 0.513 < 0.8
# LOSS train 0.6875 valid 0.7130
# Accuracy cap NOT hit at Step 215 : 0.516 < 0.8
# LOSS train 0.6898 valid 0.6922
# Accuracy cap NOT hit at Step 223 : 0.511 < 0.8
# LOSS train 0.6743 valid 0.7127
# Accuracy cap NOT hit at Step 216 : 0.506 < 0.8
# LOSS train 0.6920 valid 0.6928
# Accuracy cap NOT hit at Step 224 : 0.51 < 0.8
# LOSS train 0.7137 valid 0.7106
# Accuracy cap NOT hit at Step 217 : 0.506 < 0.8
# LOSS train 0.6849 valid 0.6931
# Accuracy cap NOT hit at Step 225 : 0.508 < 0.8
# LOSS train 0.7402 valid 0.7041
# Accuracy cap NOT hit at Step 218 : 0.503 < 0.8
# LOSS train 0.6789 valid 0.6935
# Accuracy cap NOT hit at Step 226 : 0.503 < 0.8
# LOSS train 0.7071 valid 0.6996
# Accuracy cap NOT hit at Step 219 : 0.502 < 0.8
# LOSS train 0.6791 valid 0.6945
# Accuracy cap NOT hit at Step 227 : 0.501 < 0.8
# LOSS train 0.7311 valid 0.6975
# Accuracy cap NOT hit at Step 220 : 0.502 < 0.8
# LOSS train 0.6904 valid 0.6960
# Accuracy cap NOT hit at Step 228 : 0.502 < 0.8
# LOSS train 0.6675 valid 0.6988
# Accuracy cap NOT hit at Step 221 : 0.507 < 0.8
# LOSS train 0.7131 valid 0.6965
# Accuracy cap NOT hit at Step 229 : 0.502 < 0.8
# LOSS train 0.7021 valid 0.6991
# Accuracy cap NOT hit at Step 222 : 0.508 < 0.8
# LOSS train 0.6868 valid 0.6975
# Accuracy cap NOT hit at Step 230 : 0.501 < 0.8
# LOSS train 0.6761 valid 0.7031
# Accuracy cap NOT hit at Step 223 : 0.499 < 0.8
# LOSS train 0.7055 valid 0.6971
# Accuracy cap NOT hit at Step 231 : 0.502 < 0.8
# LOSS train 0.7063 valid 0.7087
# Accuracy cap NOT hit at Step 224 : 0.492 < 0.8
# LOSS train 0.7395 valid 0.6943
# Accuracy cap NOT hit at Step 232 : 0.511 < 0.8
# LOSS train 0.7357 valid 0.7035
# Accuracy cap NOT hit at Step 225 : 0.512 < 0.8
# LOSS train 0.6909 valid 0.6930
# Accuracy cap NOT hit at Step 233 : 0.51 < 0.8
# LOSS train 0.7089 valid 0.7037
# Accuracy cap NOT hit at Step 226 : 0.506 < 0.8
# LOSS train 0.6806 valid 0.6923
# Accuracy cap NOT hit at Step 234 : 0.522 < 0.8
# LOSS train 0.6999 valid 0.7078
# Accuracy cap NOT hit at Step 227 : 0.507 < 0.8
# LOSS train 0.7056 valid 0.6925
# Accuracy cap NOT hit at Step 235 : 0.512 < 0.8
# LOSS train 0.6668 valid 0.7120
# Accuracy cap NOT hit at Step 228 : 0.503 < 0.8
# LOSS train 0.6892 valid 0.6938
# Accuracy cap NOT hit at Step 236 : 0.52 < 0.8
# LOSS train 0.7078 valid 0.7151
# Accuracy cap NOT hit at Step 229 : 0.498 < 0.8
# LOSS train 0.6645 valid 0.6969
# Accuracy cap NOT hit at Step 237 : 0.497 < 0.8
# LOSS train 0.7644 valid 0.7166
# Accuracy cap NOT hit at Step 230 : 0.499 < 0.8
# LOSS train 0.6740 valid 0.7019
# Accuracy cap NOT hit at Step 238 : 0.497 < 0.8
# LOSS train 0.7152 valid 0.7204
# Accuracy cap NOT hit at Step 231 : 0.504 < 0.8
# LOSS train 0.7084 valid 0.7053
# Accuracy cap NOT hit at Step 239 : 0.499 < 0.8
# LOSS train 0.7291 valid 0.7323
# Accuracy cap NOT hit at Step 232 : 0.491 < 0.8
# LOSS train 0.6952 valid 0.7077
# Accuracy cap NOT hit at Step 240 : 0.498 < 0.8
# LOSS train 0.7362 valid 0.7442
# Accuracy cap NOT hit at Step 233 : 0.496 < 0.8
# LOSS train 0.7113 valid 0.7084
# Accuracy cap NOT hit at Step 241 : 0.497 < 0.8
# LOSS train 0.7710 valid 0.7444
# Accuracy cap NOT hit at Step 234 : 0.502 < 0.8
# LOSS train 0.7318 valid 0.7062
# Accuracy cap NOT hit at Step 242 : 0.501 < 0.8
# LOSS train 0.6984 valid 0.7456
# Accuracy cap NOT hit at Step 235 : 0.519 < 0.8
# LOSS train 0.6800 valid 0.7039
# Accuracy cap NOT hit at Step 243 : 0.497 < 0.8
# LOSS train 0.7726 valid 0.7206
# Accuracy cap NOT hit at Step 236 : 0.513 < 0.8
# LOSS train 0.7479 valid 0.6991
# Accuracy cap NOT hit at Step 244 : 0.499 < 0.8
# LOSS train 0.6897 valid 0.7002
# Accuracy cap NOT hit at Step 237 : 0.485 < 0.8
# LOSS train 0.7420 valid 0.6948
# Accuracy cap NOT hit at Step 245 : 0.526 < 0.8
# LOSS train 0.6995 valid 0.6948
# Accuracy cap NOT hit at Step 238 : 0.494 < 0.8
# LOSS train 0.6973 valid 0.6930
# Accuracy cap NOT hit at Step 246 : 0.523 < 0.8
# LOSS train 0.6884 valid 0.7100
# Accuracy cap NOT hit at Step 239 : 0.493 < 0.8
# LOSS train 0.6754 valid 0.6927
# Accuracy cap NOT hit at Step 247 : 0.515 < 0.8
# LOSS train 0.6309 valid 0.7512
# Accuracy cap NOT hit at Step 240 : 0.505 < 0.8
# LOSS train 0.6851 valid 0.6935
# Accuracy cap NOT hit at Step 248 : 0.501 < 0.8
# LOSS train 0.7715 valid 0.7779
# Accuracy cap NOT hit at Step 241 : 0.502 < 0.8
# LOSS train 0.6950 valid 0.6956
# Accuracy cap NOT hit at Step 249 : 0.512 < 0.8
# LOSS train 0.6551 valid 0.8083
# Accuracy cap NOT hit at Step 242 : 0.503 < 0.8
# LOSS train 0.7060 valid 0.6969
# Accuracy cap NOT hit at Step 250 : 0.51 < 0.8
# EPOCH 2:
# LOSS train 0.6972 valid 0.8317
# Accuracy cap NOT hit at Step 243 : 0.506 < 0.8
# LOSS train 0.7392 valid 0.6974
# Accuracy cap NOT hit at Step 251 : 0.512 < 0.8
# LOSS train 0.6813 valid 0.8362
# Accuracy cap NOT hit at Step 244 : 0.504 < 0.8
# LOSS train 0.6956 valid 0.6981
# Accuracy cap NOT hit at Step 252 : 0.509 < 0.8
# LOSS train 0.7440 valid 0.8368
# Accuracy cap NOT hit at Step 245 : 0.498 < 0.8
# LOSS train 0.6914 valid 0.6982
# Accuracy cap NOT hit at Step 253 : 0.51 < 0.8
# LOSS train 0.7056 valid 0.6971
# Accuracy cap NOT hit at Step 254 : 0.513 < 0.8
# LOSS train 0.7456 valid 0.8229
# Accuracy cap NOT hit at Step 246 : 0.499 < 0.8
# LOSS train 0.6996 valid 0.6958
# Accuracy cap NOT hit at Step 255 : 0.512 < 0.8
# LOSS train 0.7066 valid 0.7797
# Accuracy cap NOT hit at Step 247 : 0.496 < 0.8
# LOSS train 0.6980 valid 0.6935
# Accuracy cap NOT hit at Step 256 : 0.505 < 0.8
# LOSS train 0.6715 valid 0.7516
# Accuracy cap NOT hit at Step 248 : 0.497 < 0.8
# LOSS train 0.7027 valid 0.6925
# Accuracy cap NOT hit at Step 257 : 0.495 < 0.8
# LOSS train 0.6846 valid 0.7226
# Accuracy cap NOT hit at Step 249 : 0.508 < 0.8
# LOSS train 0.6946 valid 0.6926
# Accuracy cap NOT hit at Step 258 : 0.501 < 0.8
# LOSS train 0.6755 valid 0.7106
# Accuracy cap NOT hit at Step 250 : 0.508 < 0.8
# EPOCH 2:
# LOSS train 0.6842 valid 0.6937
# Accuracy cap NOT hit at Step 259 : 0.519 < 0.8
# LOSS train 0.7265 valid 0.7039
# Accuracy cap NOT hit at Step 251 : 0.513 < 0.8
# LOSS train 0.6912 valid 0.6957
# Accuracy cap NOT hit at Step 260 : 0.519 < 0.8
# LOSS train 0.6794 valid 0.7018
# Accuracy cap NOT hit at Step 252 : 0.514 < 0.8
# LOSS train 0.6971 valid 0.6996
# Accuracy cap NOT hit at Step 261 : 0.516 < 0.8
# LOSS train 0.6650 valid 0.7029
# Accuracy cap NOT hit at Step 253 : 0.507 < 0.8
# LOSS train 0.7089 valid 0.7033
# Accuracy cap NOT hit at Step 262 : 0.514 < 0.8
# LOSS train 0.6924 valid 0.7058
# Accuracy cap NOT hit at Step 254 : 0.506 < 0.8
# LOSS train 0.6768 valid 0.7086
# Accuracy cap NOT hit at Step 263 : 0.499 < 0.8
# LOSS train 0.6966 valid 0.7046
# Accuracy cap NOT hit at Step 255 : 0.502 < 0.8
# LOSS train 0.7128 valid 0.7098
# Accuracy cap NOT hit at Step 264 : 0.499 < 0.8
# LOSS train 0.7307 valid 0.7007
# Accuracy cap NOT hit at Step 256 : 0.504 < 0.8
# LOSS train 0.6933 valid 0.7118
# Accuracy cap NOT hit at Step 265 : 0.499 < 0.8
# LOSS train 0.7606 valid 0.6956
# Accuracy cap NOT hit at Step 257 : 0.505 < 0.8
# LOSS train 0.7120 valid 0.7097
# Accuracy cap NOT hit at Step 266 : 0.499 < 0.8
# LOSS train 0.7075 valid 0.6977
# Accuracy cap NOT hit at Step 258 : 0.503 < 0.8
# LOSS train 0.7358 valid 0.7031
# Accuracy cap NOT hit at Step 267 : 0.5 < 0.8
# LOSS train 0.7140 valid 0.7037
# Accuracy cap NOT hit at Step 259 : 0.507 < 0.8
# LOSS train 0.7495 valid 0.6963
# Accuracy cap NOT hit at Step 268 : 0.518 < 0.8
# LOSS train 0.7050 valid 0.7122
# Accuracy cap NOT hit at Step 260 : 0.495 < 0.8
# LOSS train 0.6930 valid 0.6928
# Accuracy cap NOT hit at Step 269 : 0.528 < 0.8
# LOSS train 0.7108 valid 0.7191
# Accuracy cap NOT hit at Step 261 : 0.503 < 0.8
# LOSS train 0.6716 valid 0.6922
# Accuracy cap NOT hit at Step 270 : 0.506 < 0.8
# LOSS train 0.6382 valid 0.7335
# Accuracy cap NOT hit at Step 262 : 0.494 < 0.8
# LOSS train 0.6990 valid 0.6935
# Accuracy cap NOT hit at Step 271 : 0.51 < 0.8
# LOSS train 0.6936 valid 0.7500
# Accuracy cap NOT hit at Step 263 : 0.5 < 0.8
# LOSS train 0.6683 valid 0.6973
# Accuracy cap NOT hit at Step 272 : 0.496 < 0.8
# LOSS train 0.6686 valid 0.7599
# Accuracy cap NOT hit at Step 264 : 0.5 < 0.8
# LOSS train 0.6907 valid 0.7012
# Accuracy cap NOT hit at Step 273 : 0.501 < 0.8
# LOSS train 0.7473 valid 0.7692
# Accuracy cap NOT hit at Step 265 : 0.5 < 0.8
# LOSS train 0.7062 valid 0.7031
# Accuracy cap NOT hit at Step 274 : 0.5 < 0.8
# LOSS train 0.6729 valid 0.7655
# Accuracy cap NOT hit at Step 266 : 0.5 < 0.8
# LOSS train 0.6987 valid 0.7032
# Accuracy cap NOT hit at Step 275 : 0.5 < 0.8
# LOSS train 0.7886 valid 0.7564
# Accuracy cap NOT hit at Step 267 : 0.5 < 0.8
# LOSS train 0.6782 valid 0.7038
# Accuracy cap NOT hit at Step 276 : 0.5 < 0.8
# LOSS train 0.8794 valid 0.7286
# Accuracy cap NOT hit at Step 268 : 0.492 < 0.8
# LOSS train 0.6391 valid 0.7066
# Accuracy cap NOT hit at Step 277 : 0.5 < 0.8
# LOSS train 0.7843 valid 0.7053
# Accuracy cap NOT hit at Step 269 : 0.505 < 0.8
# LOSS train 0.6973 valid 0.7072
# Accuracy cap NOT hit at Step 278 : 0.5 < 0.8
# LOSS train 0.7103 valid 0.6968
# Accuracy cap NOT hit at Step 270 : 0.498 < 0.8
# LOSS train 0.6636 valid 0.7077
# Accuracy cap NOT hit at Step 279 : 0.5 < 0.8
# LOSS train 0.6987 valid 0.6988
# Accuracy cap NOT hit at Step 271 : 0.5 < 0.8
# LOSS train 0.7169 valid 0.7056
# Accuracy cap NOT hit at Step 280 : 0.5 < 0.8
# LOSS train 0.7114 valid 0.7016
# Accuracy cap NOT hit at Step 272 : 0.5 < 0.8
# LOSS train 0.7208 valid 0.7010
# Accuracy cap NOT hit at Step 281 : 0.503 < 0.8
# LOSS train 0.7359 valid 0.7020
# Accuracy cap NOT hit at Step 273 : 0.5 < 0.8
# LOSS train 0.6946 valid 0.6972
# Accuracy cap NOT hit at Step 282 : 0.513 < 0.8
# LOSS train 0.6903 valid 0.7024
# Accuracy cap NOT hit at Step 274 : 0.5 < 0.8
# LOSS train 0.6990 valid 0.6945
# Accuracy cap NOT hit at Step 283 : 0.512 < 0.8
# LOSS train 0.6616 valid 0.7036
# Accuracy cap NOT hit at Step 275 : 0.501 < 0.8
# LOSS train 0.6768 valid 0.6925
# Accuracy cap NOT hit at Step 284 : 0.498 < 0.8
# LOSS train 0.7175 valid 0.7015
# Accuracy cap NOT hit at Step 276 : 0.5 < 0.8
# LOSS train 0.7010 valid 0.6922
# Accuracy cap NOT hit at Step 285 : 0.509 < 0.8
# LOSS train 0.6923 valid 0.7012
# Accuracy cap NOT hit at Step 277 : 0.501 < 0.8
# LOSS train 0.7022 valid 0.6921
# Accuracy cap NOT hit at Step 286 : 0.504 < 0.8
# LOSS train 0.6858 valid 0.6990
# Accuracy cap NOT hit at Step 278 : 0.503 < 0.8
# LOSS train 0.6395 valid 0.6919
# Accuracy cap NOT hit at Step 287 : 0.488 < 0.8
# LOSS train 0.6709 valid 0.6984
# Accuracy cap NOT hit at Step 279 : 0.503 < 0.8
# LOSS train 0.6717 valid 0.6931
# Accuracy cap NOT hit at Step 288 : 0.505 < 0.8
# LOSS train 0.7431 valid 0.6956
# Accuracy cap NOT hit at Step 280 : 0.5 < 0.8
# LOSS train 0.7603 valid 0.6948
# Accuracy cap NOT hit at Step 289 : 0.507 < 0.8
# LOSS train 0.6857 valid 0.6939
# Accuracy cap NOT hit at Step 281 : 0.508 < 0.8
# LOSS train 0.7352 valid 0.6944
# Accuracy cap NOT hit at Step 290 : 0.503 < 0.8
# LOSS train 0.7115 valid 0.6937
# Accuracy cap NOT hit at Step 282 : 0.509 < 0.8
# LOSS train 0.6101 valid 0.6950
# Accuracy cap NOT hit at Step 291 : 0.5 < 0.8
# LOSS train 0.6907 valid 0.6982
# Accuracy cap NOT hit at Step 283 : 0.493 < 0.8
# LOSS train 0.6354 valid 0.6960
# Accuracy cap NOT hit at Step 292 : 0.5 < 0.8
# LOSS train 0.7059 valid 0.7028
# Accuracy cap NOT hit at Step 284 : 0.492 < 0.8
# LOSS train 0.7190 valid 0.6961
# Accuracy cap NOT hit at Step 293 : 0.493 < 0.8
# LOSS train 0.6976 valid 0.7070
# Accuracy cap NOT hit at Step 285 : 0.498 < 0.8
# LOSS train 0.6935 valid 0.6960
# Accuracy cap NOT hit at Step 294 : 0.491 < 0.8
# LOSS train 0.7343 valid 0.7085
# Accuracy cap NOT hit at Step 286 : 0.502 < 0.8
# LOSS train 0.7296 valid 0.6948
# Accuracy cap NOT hit at Step 295 : 0.495 < 0.8
# LOSS train 0.7352 valid 0.7033
# Accuracy cap NOT hit at Step 287 : 0.498 < 0.8
# LOSS train 0.7351 valid 0.6994
# Accuracy cap NOT hit at Step 296 : 0.495 < 0.8
# LOSS train 0.7583 valid 0.6963
# Accuracy cap NOT hit at Step 288 : 0.493 < 0.8
# LOSS train 0.6799 valid 0.7047
# Accuracy cap NOT hit at Step 297 : 0.492 < 0.8
# LOSS train 0.6970 valid 0.6934
# Accuracy cap NOT hit at Step 289 : 0.519 < 0.8
# LOSS train 0.6872 valid 0.7123
# Accuracy cap NOT hit at Step 298 : 0.498 < 0.8
# LOSS train 0.6838 valid 0.6946
# Accuracy cap NOT hit at Step 290 : 0.502 < 0.8
# LOSS train 0.7091 valid 0.7249
# Accuracy cap NOT hit at Step 299 : 0.504 < 0.8
# LOSS train 0.6649 valid 0.7008
# Accuracy cap NOT hit at Step 291 : 0.502 < 0.8
# LOSS train 0.6990 valid 0.7308
# Accuracy cap NOT hit at Step 300 : 0.504 < 0.8
# LOSS train 0.6783 valid 0.7099
# Accuracy cap NOT hit at Step 292 : 0.5 < 0.8
# LOSS train 0.6750 valid 0.7298
# Accuracy cap NOT hit at Step 301 : 0.503 < 0.8
# LOSS train 0.6948 valid 0.7166
# Accuracy cap NOT hit at Step 293 : 0.5 < 0.8
# LOSS train 0.6962 valid 0.7317
# Accuracy cap NOT hit at Step 302 : 0.504 < 0.8
# LOSS train 0.7136 valid 0.7202
# ...
# Accuracy cap NOT hit at Step 871 : 0.505 < 0.8
# LOSS train 0.6411 valid 1.1422
# Accuracy cap NOT hit at Step 872 : 0.501 < 0.8
# LOSS train 0.7052 valid 1.3506
# Accuracy cap NOT hit at Step 873 : 0.5 < 0.8
# LOSS train 0.5881 valid 1.5363
# Accuracy cap NOT hit at Step 874 : 0.5 < 0.8
# LOSS train 0.6526 valid 1.5268
# Accuracy cap NOT hit at Step 875 : 0.5 < 0.8
# LOSS train 0.6969 valid 1.5278
# Accuracy cap NOT hit at Step 876 : 0.5 < 0.8
# LOSS train 0.6584 valid 1.4139
# Accuracy cap NOT hit at Step 877 : 0.5 < 0.8
# LOSS train 0.5976 valid 1.1733
# Accuracy cap NOT hit at Step 878 : 0.5 < 0.8
# LOSS train 0.8068 valid 0.7877
# Accuracy cap NOT hit at Step 879 : 0.537 < 0.8
# LOSS train 0.6403 valid 0.6217
# Accuracy cap NOT hit at Step 880 : 0.649 < 0.8
# LOSS train 0.5864 valid 0.6245
# Accuracy cap NOT hit at Step 881 : 0.635 < 0.8
# LOSS train 0.6406 valid 0.6692
# Accuracy cap NOT hit at Step 882 : 0.595 < 0.8
# LOSS train 0.5264 valid 0.7597
# Accuracy cap NOT hit at Step 883 : 0.565 < 0.8
# LOSS train 0.6376 valid 0.7936
# Accuracy cap NOT hit at Step 884 : 0.56 < 0.8
# LOSS train 0.6192 valid 0.7715
# Accuracy cap NOT hit at Step 885 : 0.574 < 0.8
# LOSS train 0.6846 valid 0.7825
# Accuracy cap NOT hit at Step 886 : 0.57 < 0.8
# LOSS train 0.6911 valid 0.8478
# Accuracy cap NOT hit at Step 887 : 0.548 < 0.8
# LOSS train 0.7474 valid 0.8396
# Accuracy cap NOT hit at Step 888 : 0.551 < 0.8
# LOSS train 0.5948 valid 0.8279
# Accuracy cap NOT hit at Step 889 : 0.553 < 0.8
# LOSS train 0.6177 valid 0.7577
# Accuracy cap NOT hit at Step 890 : 0.568 < 0.8
# LOSS train 0.5774 valid 0.6708
# Accuracy cap NOT hit at Step 891 : 0.618 < 0.8
# LOSS train 0.6498 valid 0.6412
# Accuracy cap NOT hit at Step 892 : 0.63 < 0.8
# LOSS train 0.6001 valid 0.6376
# Accuracy cap NOT hit at Step 893 : 0.639 < 0.8
# LOSS train 0.5394 valid 0.6613
# Accuracy cap NOT hit at Step 894 : 0.616 < 0.8
# LOSS train 0.6136 valid 0.7456
# Accuracy cap NOT hit at Step 895 : 0.58 < 0.8
# LOSS train 0.6119 valid 0.7712
# Accuracy cap NOT hit at Step 896 : 0.578 < 0.8
# LOSS train 0.5585 valid 0.7716
# Accuracy cap NOT hit at Step 897 : 0.582 < 0.8
# LOSS train 0.6475 valid 0.7103
# Accuracy cap NOT hit at Step 898 : 0.595 < 0.8
# LOSS train 0.5197 valid 0.6246
# Accuracy cap NOT hit at Step 899 : 0.663 < 0.8
# LOSS train 0.6652 valid 0.7383
# Accuracy cap NOT hit at Step 900 : 0.599 < 0.8
# LOSS train 0.6107 valid 1.0088
# Accuracy cap NOT hit at Step 901 : 0.518 < 0.8
# LOSS train 0.5906 valid 1.1917
# Accuracy cap NOT hit at Step 902 : 0.507 < 0.8
# LOSS train 0.5166 valid 1.1044
# Accuracy cap NOT hit at Step 903 : 0.513 < 0.8
# LOSS train 0.6848 valid 1.0058
# Accuracy cap NOT hit at Step 904 : 0.516 < 0.8
# LOSS train 0.6708 valid 0.7484
# Accuracy cap NOT hit at Step 905 : 0.588 < 0.8
# LOSS train 0.6215 valid 0.6265
# Accuracy cap NOT hit at Step 906 : 0.676 < 0.8
# LOSS train 0.5178 valid 0.6014
# Accuracy cap NOT hit at Step 907 : 0.685 < 0.8
# LOSS train 0.7224 valid 0.6299
# Accuracy cap NOT hit at Step 908 : 0.67 < 0.8
# LOSS train 0.6036 valid 0.6304
# Accuracy cap NOT hit at Step 909 : 0.668 < 0.8
# LOSS train 0.6774 valid 0.6736
# Accuracy cap NOT hit at Step 910 : 0.622 < 0.8
# LOSS train 0.5162 valid 0.7393
# Accuracy cap NOT hit at Step 911 : 0.589 < 0.8
# LOSS train 0.6389 valid 0.7233
# Accuracy cap NOT hit at Step 912 : 0.592 < 0.8
# LOSS train 0.5782 valid 0.7354
# Accuracy cap NOT hit at Step 913 : 0.576 < 0.8
# LOSS train 0.6817 valid 0.7992
# Accuracy cap NOT hit at Step 914 : 0.541 < 0.8
# LOSS train 0.5518 valid 0.8922
# Accuracy cap NOT hit at Step 915 : 0.523 < 0.8
# LOSS train 0.5724 valid 0.9878
# Accuracy cap NOT hit at Step 916 : 0.518 < 0.8
# LOSS train 0.6005 valid 1.0326
# Accuracy cap NOT hit at Step 917 : 0.517 < 0.8
# LOSS train 0.5556 valid 0.9133
# Accuracy cap NOT hit at Step 918 : 0.536 < 0.8
# LOSS train 0.5711 valid 0.8139
# Accuracy cap NOT hit at Step 919 : 0.561 < 0.8
# LOSS train 0.5882 valid 0.6880
# Accuracy cap NOT hit at Step 920 : 0.628 < 0.8
# LOSS train 0.6040 valid 0.5941
# Accuracy cap NOT hit at Step 921 : 0.701 < 0.8
# LOSS train 0.6213 valid 0.5688
# Accuracy cap NOT hit at Step 922 : 0.717 < 0.8
# LOSS train 0.7062 valid 0.5624
# Accuracy cap NOT hit at Step 923 : 0.723 < 0.8
# LOSS train 0.5732 valid 0.5638
# Accuracy cap NOT hit at Step 924 : 0.727 < 0.8
# LOSS train 0.6049 valid 0.6098
# Accuracy cap NOT hit at Step 925 : 0.663 < 0.8
# LOSS train 0.6887 valid 0.6381
# Accuracy cap NOT hit at Step 926 : 0.635 < 0.8
# LOSS train 0.6274 valid 0.5995
# Accuracy cap NOT hit at Step 927 : 0.682 < 0.8
# LOSS train 0.6344 valid 0.5889
# Accuracy cap NOT hit at Step 928 : 0.699 < 0.8
# LOSS train 0.5767 valid 0.5907
# Accuracy cap NOT hit at Step 929 : 0.69 < 0.8
# LOSS train 0.6667 valid 0.5896
# Accuracy cap NOT hit at Step 930 : 0.703 < 0.8
# LOSS train 0.5785 valid 0.5993
# Accuracy cap NOT hit at Step 931 : 0.687 < 0.8
# LOSS train 0.5165 valid 0.6051
# Accuracy cap NOT hit at Step 932 : 0.682 < 0.8
# LOSS train 0.5329 valid 0.6199
# Accuracy cap NOT hit at Step 933 : 0.666 < 0.8
# LOSS train 0.5544 valid 0.6339
# Accuracy cap NOT hit at Step 934 : 0.645 < 0.8
# LOSS train 0.6444 valid 0.6347
# Accuracy cap NOT hit at Step 935 : 0.648 < 0.8
# LOSS train 0.5479 valid 0.6118
# Accuracy cap NOT hit at Step 936 : 0.664 < 0.8
# LOSS train 0.7424 valid 0.5885
# Accuracy cap NOT hit at Step 937 : 0.7 < 0.8
# LOSS train 0.5579 valid 0.5973
# Accuracy cap NOT hit at Step 938 : 0.689 < 0.8
# LOSS train 0.6078 valid 0.6228
# Accuracy cap NOT hit at Step 939 : 0.663 < 0.8
# LOSS train 0.5386 valid 0.6157
# Accuracy cap NOT hit at Step 940 : 0.673 < 0.8
# LOSS train 0.6108 valid 0.6385
# Accuracy cap NOT hit at Step 941 : 0.657 < 0.8
# LOSS train 0.5890 valid 0.5859
# Accuracy cap NOT hit at Step 942 : 0.688 < 0.8
# LOSS train 0.7197 valid 0.5712
# Accuracy cap NOT hit at Step 943 : 0.721 < 0.8
# LOSS train 0.4495 valid 0.6544
# Accuracy cap NOT hit at Step 944 : 0.666 < 0.8
# LOSS train 0.5260 valid 0.6698
# Accuracy cap NOT hit at Step 945 : 0.663 < 0.8
# LOSS train 0.4875 valid 1.1090
# Accuracy cap NOT hit at Step 946 : 0.534 < 0.8
# LOSS train 0.5259 valid 1.5014
# Accuracy cap NOT hit at Step 947 : 0.509 < 0.8
# LOSS train 0.4575 valid 1.6627
# Accuracy cap NOT hit at Step 948 : 0.506 < 0.8
# LOSS train 0.6010 valid 1.5784
# Accuracy cap NOT hit at Step 949 : 0.51 < 0.8
# LOSS train 0.6358 valid 1.1625
# Accuracy cap NOT hit at Step 950 : 0.54 < 0.8
# LOSS train 0.5175 valid 0.6238
# Accuracy cap NOT hit at Step 951 : 0.678 < 0.8
# LOSS train 0.5475 valid 0.5596
# Accuracy cap NOT hit at Step 952 : 0.724 < 0.8
# LOSS train 0.7403 valid 0.6271
# Accuracy cap NOT hit at Step 953 : 0.657 < 0.8
# LOSS train 0.7608 valid 0.6198
# Accuracy cap NOT hit at Step 954 : 0.664 < 0.8
# LOSS train 0.9228 valid 0.6434
# Accuracy cap NOT hit at Step 955 : 0.647 < 0.8
# LOSS train 0.5456 valid 0.7063
# Accuracy cap NOT hit at Step 956 : 0.597 < 0.8
# LOSS train 0.6057 valid 0.7478
# Accuracy cap NOT hit at Step 957 : 0.571 < 0.8
# LOSS train 0.6209 valid 0.8227
# Accuracy cap NOT hit at Step 958 : 0.539 < 0.8
# LOSS train 0.6125 valid 0.8818
# Accuracy cap NOT hit at Step 959 : 0.522 < 0.8
# LOSS train 0.5812 valid 0.8338
# Accuracy cap NOT hit at Step 960 : 0.533 < 0.8
# LOSS train 0.5073 valid 0.8179
# Accuracy cap NOT hit at Step 961 : 0.538 < 0.8
# LOSS train 0.4968 valid 0.8064
# Accuracy cap NOT hit at Step 962 : 0.548 < 0.8
# LOSS train 0.6381 valid 0.7090
# Accuracy cap NOT hit at Step 963 : 0.588 < 0.8
# LOSS train 0.5492 valid 0.6364
# Accuracy cap NOT hit at Step 964 : 0.638 < 0.8
# LOSS train 0.4838 valid 0.5960
# Accuracy cap NOT hit at Step 965 : 0.672 < 0.8
# LOSS train 0.4982 valid 0.5656
# Accuracy cap NOT hit at Step 966 : 0.717 < 0.8
# LOSS train 0.6773 valid 0.5682
# Accuracy cap NOT hit at Step 967 : 0.711 < 0.8
# LOSS train 0.6822 valid 0.5716
# Accuracy cap NOT hit at Step 968 : 0.71 < 0.8
# LOSS train 0.5928 valid 0.5788
# Accuracy cap NOT hit at Step 969 : 0.714 < 0.8
# LOSS train 0.5474 valid 0.6001
# Accuracy cap NOT hit at Step 970 : 0.677 < 0.8
# LOSS train 0.5708 valid 0.6546
# Accuracy cap NOT hit at Step 971 : 0.611 < 0.8
# LOSS train 0.6118 valid 0.6977
# Accuracy cap NOT hit at Step 972 : 0.584 < 0.8
# LOSS train 0.5841 valid 0.7517
# Accuracy cap NOT hit at Step 973 : 0.559 < 0.8
# LOSS train 0.4976 valid 0.8156
# Accuracy cap NOT hit at Step 974 : 0.533 < 0.8
# LOSS train 0.5481 valid 0.9319
# Accuracy cap NOT hit at Step 975 : 0.519 < 0.8
# LOSS train 0.5715 valid 1.0134
# Accuracy cap NOT hit at Step 976 : 0.516 < 0.8
# LOSS train 0.5040 valid 1.1266
# Accuracy cap NOT hit at Step 977 : 0.513 < 0.8
# LOSS train 0.4826 valid 1.4533
# Accuracy cap NOT hit at Step 978 : 0.503 < 0.8
# LOSS train 0.5578 valid 1.5567
# Accuracy cap NOT hit at Step 979 : 0.503 < 0.8
# LOSS train 0.4842 valid 1.3130
# Accuracy cap NOT hit at Step 980 : 0.514 < 0.8
# LOSS train 0.5815 valid 0.8404
# Accuracy cap NOT hit at Step 981 : 0.584 < 0.8
# LOSS train 0.4241 valid 0.5784
# Accuracy cap NOT hit at Step 982 : 0.713 < 0.8
# LOSS train 0.6054 valid 0.5813
# Accuracy cap NOT hit at Step 983 : 0.709 < 0.8
# LOSS train 0.6824 valid 0.8322
# Accuracy cap NOT hit at Step 984 : 0.582 < 0.8
# LOSS train 0.6449 valid 0.9318
# Accuracy cap NOT hit at Step 985 : 0.556 < 0.8
# LOSS train 0.4916 valid 0.8851
# Accuracy cap NOT hit at Step 986 : 0.568 < 0.8
# LOSS train 0.6628 valid 0.7786
# Accuracy cap NOT hit at Step 987 : 0.588 < 0.8
# LOSS train 0.4685 valid 0.6359
# Accuracy cap NOT hit at Step 988 : 0.662 < 0.8
# LOSS train 0.8308 valid 0.5895
# Accuracy cap NOT hit at Step 989 : 0.69 < 0.8
# LOSS train 0.5758 valid 0.5607
# Accuracy cap NOT hit at Step 990 : 0.711 < 0.8
# LOSS train 0.4731 valid 0.5583
# Accuracy cap NOT hit at Step 991 : 0.716 < 0.8
# LOSS train 0.5288 valid 0.5936
# Accuracy cap NOT hit at Step 992 : 0.694 < 0.8
# LOSS train 0.4641 valid 0.6260
# Accuracy cap NOT hit at Step 993 : 0.658 < 0.8
# LOSS train 0.7533 valid 0.5909
# Accuracy cap NOT hit at Step 994 : 0.687 < 0.8
# LOSS train 0.5581 valid 0.5641
# Accuracy cap NOT hit at Step 995 : 0.718 < 0.8
# LOSS train 0.6151 valid 0.5436
# Accuracy cap NOT hit at Step 996 : 0.747 < 0.8
# LOSS train 0.6387 valid 0.5407
# Accuracy cap NOT hit at Step 997 : 0.743 < 0.8
# LOSS train 0.5248 valid 0.5681
# Accuracy cap NOT hit at Step 998 : 0.706 < 0.8
# LOSS train 0.5053 valid 0.6428
# Accuracy cap NOT hit at Step 999 : 0.643 < 0.8
# LOSS train 0.5280 valid 0.6247
# Accuracy cap NOT hit at Step 1000 : 0.663 < 0.8
# EPOCH 5:
# LOSS train 0.5682 valid 0.5501
# Accuracy cap NOT hit at Step 1001 : 0.734 < 0.8
# LOSS train 0.5537 valid 0.5557
# Accuracy cap NOT hit at Step 1002 : 0.713 < 0.8
# LOSS train 0.4539 valid 0.6047
# Accuracy cap NOT hit at Step 1003 : 0.681 < 0.8
# LOSS train 0.4502 valid 0.5854
# Accuracy cap NOT hit at Step 1004 : 0.692 < 0.8
# LOSS train 0.6356 valid 0.6081
# Accuracy cap NOT hit at Step 1005 : 0.672 < 0.8
# LOSS train 0.3973 valid 0.5971
# Accuracy cap NOT hit at Step 1006 : 0.682 < 0.8
# LOSS train 0.6504 valid 0.5363
# Accuracy cap NOT hit at Step 1007 : 0.736 < 0.8
# LOSS train 0.5333 valid 0.5102
# Accuracy cap NOT hit at Step 1008 : 0.764 < 0.8
# LOSS train 0.6082 valid 0.5420
# Accuracy cap NOT hit at Step 1009 : 0.743 < 0.8
# LOSS train 0.3640 valid 0.7047
# Accuracy cap NOT hit at Step 1010 : 0.625 < 0.8
# LOSS train 0.4793 valid 0.9283
# Accuracy cap NOT hit at Step 1011 : 0.556 < 0.8
# LOSS train 0.5892 valid 0.9320
# Accuracy cap NOT hit at Step 1012 : 0.554 < 0.8
# LOSS train 0.3812 valid 0.7128
# Accuracy cap NOT hit at Step 1013 : 0.626 < 0.8
# LOSS train 0.5562 valid 0.5754
# Accuracy cap NOT hit at Step 1014 : 0.712 < 0.8
# LOSS train 0.7090 valid 0.5238
# Accuracy cap NOT hit at Step 1015 : 0.76 < 0.8
# LOSS train 0.6379 valid 0.5318
# Accuracy cap NOT hit at Step 1016 : 0.735 < 0.8
# LOSS train 0.4821 valid 0.5827
# Accuracy cap NOT hit at Step 1017 : 0.71 < 0.8
# LOSS train 0.3106 valid 0.6825
# Accuracy cap NOT hit at Step 1018 : 0.649 < 0.8
# LOSS train 0.4831 valid 0.6808
# Accuracy cap NOT hit at Step 1019 : 0.657 < 0.8
# LOSS train 0.6828 valid 0.5914
# Accuracy cap NOT hit at Step 1020 : 0.697 < 0.8
# LOSS train 0.5593 valid 0.6006
# Accuracy cap NOT hit at Step 1021 : 0.687 < 0.8
# LOSS train 0.4504 valid 0.6065
# Accuracy cap NOT hit at Step 1022 : 0.693 < 0.8
# LOSS train 0.5472 valid 0.5253
# Accuracy cap NOT hit at Step 1023 : 0.737 < 0.8
# LOSS train 0.4411 valid 0.5176
# Accuracy cap NOT hit at Step 1024 : 0.739 < 0.8
# LOSS train 0.4287 valid 0.5292
# Accuracy cap NOT hit at Step 1025 : 0.735 < 0.8
# LOSS train 0.3556 valid 0.5177
# Accuracy cap NOT hit at Step 1026 : 0.736 < 0.8
# LOSS train 0.5009 valid 0.4992
# Accuracy cap NOT hit at Step 1027 : 0.773 < 0.8
# LOSS train 0.4884 valid 0.5657
# Accuracy cap NOT hit at Step 1028 : 0.741 < 0.8
# LOSS train 0.7926 valid 0.7120
# Accuracy cap NOT hit at Step 1029 : 0.655 < 0.8
# LOSS train 0.6190 valid 0.7572
# Accuracy cap NOT hit at Step 1030 : 0.635 < 0.8
# LOSS train 0.3775 valid 0.8451
# Accuracy cap NOT hit at Step 1031 : 0.59 < 0.8
# LOSS train 0.4788 valid 0.9157
# Accuracy cap NOT hit at Step 1032 : 0.568 < 0.8
# LOSS train 0.4595 valid 0.8322
# Accuracy cap NOT hit at Step 1033 : 0.595 < 0.8
# LOSS train 0.3584 valid 0.9357
# Accuracy cap NOT hit at Step 1034 : 0.57 < 0.8
# LOSS train 0.6590 valid 1.0253
# Accuracy cap NOT hit at Step 1035 : 0.56 < 0.8
# LOSS train 0.5435 valid 1.1862
# Accuracy cap NOT hit at Step 1036 : 0.55 < 0.8
# LOSS train 0.4182 valid 1.1097
# Accuracy cap NOT hit at Step 1037 : 0.568 < 0.8
# LOSS train 0.5359 valid 0.8913
# Accuracy cap NOT hit at Step 1038 : 0.617 < 0.8
# LOSS train 0.3760 valid 0.7284
# Accuracy cap NOT hit at Step 1039 : 0.665 < 0.8
# LOSS train 0.4016 valid 0.5809
# Accuracy cap NOT hit at Step 1040 : 0.74 < 0.8
# LOSS train 0.5077 valid 0.5009
# Accuracy cap NOT hit at Step 1041 : 0.786 < 0.8
# LOSS train 0.8988 valid 0.4599
# Accuracy cap NOT hit at Step 1042 : 0.795 < 0.8
# LOSS train 0.5456 valid 0.4328
# Accuracy cap NOT hit at Step 1043 : 0.797 < 0.8
# LOSS train 0.2589 valid 0.4559
# Accuracy cap NOT hit at Step 1044 : 0.774 < 0.8
# LOSS train 0.5419 valid 0.5640
# Accuracy cap NOT hit at Step 1045 : 0.688 < 0.8
# LOSS train 0.6330 valid 0.6113
# Accuracy cap NOT hit at Step 1046 : 0.66 < 0.8
# LOSS train 0.6024 valid 0.5860
# Accuracy cap NOT hit at Step 1047 : 0.679 < 0.8
# LOSS train 0.5785 valid 0.5289
# Accuracy cap NOT hit at Step 1048 : 0.731 < 0.8
# LOSS train 0.6524 valid 0.6771
# Accuracy cap NOT hit at Step 1049 : 0.667 < 0.8
# LOSS train 0.3768 valid 1.0973
# Accuracy cap NOT hit at Step 1050 : 0.56 < 0.8
# LOSS train 0.5349 valid 1.0166
# Accuracy cap NOT hit at Step 1051 : 0.586 < 0.8
# LOSS train 0.6364 valid 0.7301
# Accuracy cap NOT hit at Step 1052 : 0.659 < 0.8
# LOSS train 0.3129 valid 0.5619
# Accuracy cap NOT hit at Step 1053 : 0.737 < 0.8
# LOSS train 0.4247 valid 0.4606
# Accuracy cap hit at Step 1054 : 0.807 >= 0.8
# Training complete
# Loading dataset content for easy_2_row_circle_train.csv
# 100%|██████████| 8000/8000 [01:04<00:00, 124.37it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Loading dataset content for easy_2_row_circle_test.csv
# 100%|██████████| 1000/1000 [00:10<00:00, 94.00it/s]
#   1%|▏         | 13/1000 [00:00<00:07, 126.12it/s]
# Loading dataset content for easy_2_row_circle_valid.csv
# 100%|██████████| 1000/1000 [00:07<00:00, 125.14it/s]
# Using cache found in /home/docker/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/docker/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/docker/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 100%|██████████| 1/1 [27:04<00:00, 1624.86s/it]
# {'train': {'accuracy': 0.787375, 'precision': 0.7188273367599467, 'recall': 0.944, 'roc_auc': 0.8984461875, 'confusion matrix': {'TN': 2523, 'FP': 224, 'FN': 1477, 'TP': 3776}}, 'test': {'accuracy': 0.802, 'precision': 0.729483282674772, 'recall': 0.96, 'roc_auc': 0.9072880000000001, 'confusion matrix': {'TN': 322, 'FP': 20, 'FN': 178, 'TP': 480}}, 'valid': {'accuracy': 0.807, 'precision': 0.7372488408037094, 'recall': 0.954, 'roc_auc': 0.902436, 'confusion matrix': {'TN': 330, 'FP': 23, 'FN': 170, 'TP': 477}}}
