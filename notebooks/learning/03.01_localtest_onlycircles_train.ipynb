# %%
import os

db_dir = os.environ["DATA"] + "PatImgXAI_data/dblocaltest0.1/"

train_dataset_filename = "rowcircles_train.csv"
test_dataset_filename = "rowcircles_test.csv"
valid_dataset_filename = "rowcircles_valid.csv"
model_dir = os.environ["DATA"] + "models/db_vlocaltest0.1/rowcircles/"

device = "cuda:0"

# %%
from xaipatimg.ml.learning import train_resnet18_model

train_resnet18_model(db_dir, train_dataset_filename, valid_dataset_filename, model_dir, device=device, training_epochs=40, target_accuracy=0.8)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:19<00:00, 181.97it/s]
# Train dataset statistics : [0.9718954563140869, 0.965693473815918, 0.9544402956962585] [0.10828889906406403, 0.10895111411809921, 0.13822771608829498]
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:21<00:00, 169.40it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 174.35it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# EPOCH 1:
# LOSS train 1.5940 valid 0.6899
# Accuracy cap NOT hit at Step 113 : 0.5 < 0.8
# EPOCH 2:
# LOSS train 0.6995 valid 0.6909
# Accuracy cap NOT hit at Step 200 : 0.525 < 0.8
# LOSS train 0.6959 valid 0.6970
# Accuracy cap NOT hit at Step 226 : 0.505 < 0.8
# EPOCH 3:
# LOSS train 0.6937 valid 0.6849
# Accuracy cap NOT hit at Step 339 : 0.54 < 0.8
# EPOCH 4:
# LOSS train 0.6858 valid 0.6830
# Accuracy cap NOT hit at Step 400 : 0.535 < 0.8
# LOSS train 0.6815 valid 0.6942
# Accuracy cap NOT hit at Step 452 : 0.535 < 0.8
# EPOCH 5:
# LOSS train 0.6886 valid 0.6901
# Accuracy cap NOT hit at Step 565 : 0.55 < 0.8
# EPOCH 6:
# LOSS train 0.6860 valid 0.6988
# Accuracy cap NOT hit at Step 600 : 0.54 < 0.8
# LOSS train 0.6845 valid 0.6645
# Accuracy cap NOT hit at Step 678 : 0.535 < 0.8
# EPOCH 7:
# LOSS train 0.6694 valid 0.7787
# Accuracy cap NOT hit at Step 791 : 0.495 < 0.8
# EPOCH 8:
# LOSS train 0.6892 valid 0.6851
# Accuracy cap NOT hit at Step 800 : 0.58 < 0.8
# LOSS train 0.6534 valid 0.8006
# Accuracy cap NOT hit at Step 904 : 0.545 < 0.8
# EPOCH 9:
# LOSS train 0.6235 valid 0.8036
# Accuracy cap NOT hit at Step 1000 : 0.54 < 0.8
# LOSS train 0.5699 valid 0.5578
# Accuracy cap NOT hit at Step 1017 : 0.705 < 0.8
# EPOCH 10:
# LOSS train 0.4884 valid 0.7180
# Accuracy cap NOT hit at Step 1130 : 0.69 < 0.8
# EPOCH 11:
# LOSS train 0.3246 valid 0.3269
# Accuracy cap hit at Step 1200 : 0.9 >= 0.8
# Training complete

# %%
from xaipatimg.ml.learning import compute_resnet18_model_scores

compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:22<00:00, 161.76it/s]
# Loading dataset content for rowcircles_test.csv
# 100%|██████████| 200/200 [00:01<00:00, 165.39it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 135.04it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# {'train': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}}, 'test': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}, 'valid': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
# {'train': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}},
#  'test': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}},
#  'valid': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}

# %%
from xaipatimg.ml.learning import compute_resnet18_model_scores

compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:22<00:00, 161.76it/s]
# Loading dataset content for rowcircles_test.csv
# 100%|██████████| 200/200 [00:01<00:00, 165.39it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 135.04it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# {'train': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}}, 'test': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}, 'valid': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
# {'train': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}},
#  'test': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}},
#  'valid': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}

# %%
from xaipatimg.ml.learning import compute_resnet18_model_scores

compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:22<00:00, 161.76it/s]
# Loading dataset content for rowcircles_test.csv
# 100%|██████████| 200/200 [00:01<00:00, 165.39it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 135.04it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# {'train': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}}, 'test': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}, 'valid': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
# {'train': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}},
#  'test': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}},
#  'valid': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}

# %%
from xaipatimg.ml.learning import compute_resnet18_model_scores

compute_resnet18_model_scores(db_dir, train_dataset_filename, test_dataset_filename, valid_dataset_filename, model_dir, device=device)
# Out:
# Loading dataset content for rowcircles_train.csv
# 100%|██████████| 3600/3600 [00:22<00:00, 161.76it/s]
# Loading dataset content for rowcircles_test.csv
# 100%|██████████| 200/200 [00:01<00:00, 165.39it/s]
# Loading dataset content for rowcircles_valid.csv
# 100%|██████████| 200/200 [00:01<00:00, 135.04it/s]
# Using cache found in /home/jleguy/.cache/torch/hub/pytorch_vision_v0.10.0
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jleguy/anaconda3/envs/Pytorch_exp/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# {'train': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}}, 'test': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}, 'valid': {'accuracy': 1.0, 'precision': 1.0, 'recall': 1.0, 'roc_auc': 1.0, 'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
# {'train': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 1800, 'FP': 0, 'FN': 0, 'TP': 1800}},
#  'test': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}},
#  'valid': {'accuracy': 1.0,
#   'precision': 1.0,
#   'recall': 1.0,
#   'roc_auc': 1.0,
#   'confusion matrix': {'TN': 100, 'FP': 0, 'FN': 0, 'TP': 100}}}
